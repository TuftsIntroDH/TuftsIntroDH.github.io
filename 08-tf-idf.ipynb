# %% [markdown]
# ---
# title: "TF-IDF, with a recap of material covered so far"
# subtitle: "Stop me if I'm going too fast"
# author:
#   - name: Charles Pletcher
#     affiliations: Tufts University
#     orcid: 0000-0003-2734-5511
#     email: charles.pletcher@tufts.edu
# license:
#   code: MIT
# date: 2025-03-11
# ---
#
# ## TF-IDF - An Introduction
#
# Term Frequency — Inverse Document Frequency, or TF-IDF, is a powerful, if deceptively simple, way of determining keywords in a text. As its name suggests, it is comprised of two parts:
#
# ### Term Frequency (TF)
#
# The number of times that a term — typically, a token or a phrase — appears in a document. We can normalize this using various techniques. Generally speaking, we want to use the _relative_ frequency, or the raw frequency divided by the number of terms in the document.
#
# ### Document Frequency (DF)
#
# The number of documents in which a term appears. Again, there are common normalizations that we will typically perform, such as adding a small ε value to avoid dividing by zero.
#
# _Inverse_ document frequency, or IDF, is just the multiplicative inverse, or reciprocal, of DF.
#
# In practice, however, IDF is usually logarithmically scaled, i.e., $IDF=\log(n/DF)$ where $n$ is the number of documents in the corpus.
#
# ## Prefatory matters
#
# In order to get a sense of a basic implementation of TF-IDF, we first need some text to work with. To get some text, we'll need to review a few things about Python, and we'll need to learn how to use the `lxml` library to get text out of TEI XML files — the kinds of files that store much of the textual data and metadata that we use in digital humanities.
#
# ### Install `lxml`
#
# `%pip` (note the `%`) is a special command built into Jupyter notebooks that lets us use the Python package manager `pip`.
#
# To install a package, we just enter `%pip install` and then the package name in a code cell, like so:

# %%
# %pip install lxml
# Out:
# Collecting lxml
#   Downloading lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Downloading lxml-5.3.1-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 39.1 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-5.3.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import libraries
#
# With `lxml` installed, we now need to import the `etree` library, along with the `Path` constructor from the built-in `pathlib`.

# %%
from lxml import etree
from pathlib import Path

# %% [markdown]
# ### Initialize our path
#
# We'll use the `Path` constructor to grab the XML files that we need to parse:
#
# :::{tip}
# You can read more about **glob patterns** [here](https://code.visualstudio.com/docs/editor/glob-patterns).
# :::

# %%
files = Path("./xml/tlg0012").glob("**/*perseus*.xml")

# %% [markdown]
# ### Set up namespaces for TEI parsing
#
# We also need to define a few namespaces to make it easier to find what we need in the XML files.

# %%
TEI_NS = "http://www.tei-c.org/ns/1.0"
XML_NS = "http://www.w3.org/XML/1998/namespace"

NAMESPACES = {
    "tei": TEI_NS,
    "xml": XML_NS,
}

# %% [markdown]
# ### Process the files
#
# Now we're ready to iterate through the files and extract the text.

# %%
for file in files:
    # print the name of the file as a sanity check
    print(file)
    
    # etree.parse() reads the file and turns the raw XML into an object that we can use in Python
    tree = etree.parse(file)

    # xpath() is a method that applies **xpath expressions** to search through the XML.
    # This xpath expression says, "Find any `tei:div` element with a `subtype` of `'card'`.
    # Under that element, get any text." The second argument, `namespaces=`, tells the
    # method to use the supplied namespaces as shortcuts, so we don't have to type out
    # "http://www.tei-c.org/ns/1.0" every time we want an element in the TEI namespace.

    text = tree.xpath(f"//tei:div[@subtype='card']//text()", namespaces=NAMESPACES)

    # xpath() returns an array of matches, so we initialize an empty array to store the
    # results. We could use a list comprehension, but for now rewriting these
    # lines as a list comprehension is left as an exercise for the reader.
    cleaned_text = []

    # Now we iterate through each string returned by `xpath()`
    for t in text:
        # `strip()` removes leading and trailing whitespace; if all that's left is an empty
        # string, we don't care about it.
        if t.strip != "":
            cleaned_text.append(t.strip())

    # We make sure that we actually *have* text before writing just the text, without
    # TEI elements, to a separate file. No need to write an empty file, right?
    if len(cleaned_text) > 0:
        # A lot is happening here:
        #
        # 1. `str(file)` turns the `Path` object into a `str`
        # 2. `split("/")` splits the resulting string at every "/"
        # 3. `[-1]` takes the last element of the list returned by `split("/")`
        # 4. `replace(".xml", ".txt")` changes the extension of the file
        # 
        # So something like "xml/tlg0012/tlg001/tlg0012.tlg001.perseus-eng3.xml"
        # is transformed into "tlg0012.tlg001.perseus-eng3.txt".
        with open(str(file).split("/")[-1].replace(".xml", ".txt"), "w+") as f:
            # We write the text to the file, `join`-ing each element in
            # `cleaned_text` with a newline ("\n")
            f.write("\n".join(cleaned_text))
# Out:
# xml/tlg0012/tlg002/tlg0012.tlg002.perseus-eng3.xml
# xml/tlg0012/tlg002/tlg0012.tlg002.perseus-eng4.xml
# xml/tlg0012/tlg002/tlg0012.tlg002.perseus-grc2.xml
# xml/tlg0012/tlg001/tlg0012.tlg001.perseus-eng3.xml
# xml/tlg0012/tlg001/tlg0012.tlg001.perseus-eng4.xml
# xml/tlg0012/tlg001/tlg0012.tlg001.perseus-grc2.xml
# xml/tlg0012/tlg003/tlg0012.tlg003.perseus-eng1.xml
# xml/tlg0012/tlg003/tlg0012.tlg003.perseus-grc1.xml

# %% [markdown]
# ## TF-IDF in Action
#
# Now that we have our text files, we can start implementing some basic TF-IDF analysis.
#
# First, let's tokenize our text. In the past, we have used `split()` and regular expressions to handle tokenization, but we need to start getting serious about handling punctuation. Let's use the Natural Language Toolkit, or NLTK, instead.
#
# ### Install the NLTK

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/codespace/.local/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /home/codespace/.local/lib/python3.12/site-packages (from nltk) (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Download support files
#
# With the NLTK installed, we can now download the support files that it needs for tokenization.

# %%
import nltk

# download the files needed for tokenization
# the punkt tokenizer should be installed already,
# but let's download it just in case
nltk.download("punkt")
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ### Tokenize texts
#
# With the tokenizer downloaded, we can now read in and tokenize each text.

# %%
# Initialize the tokenizer
from nltk.tokenize import word_tokenize

# Initialize an empty dictionary to store the tokenized texts
tokenized_texts = {}

# Get a Path.glob() iterator for the .txt files that you've created in this directory.
# Can you figure out what the new `[1-4]` segment is doing?
text_files = Path(".").glob("tlg0012.tlg00*.perseus-eng[1-4].txt")

# Iterate through the text files, reading and tokenizing them one by one,
# then storing the list of tokens in our `tokenized_texts` dictionary —
# so we'll be getting a dictionary of lists.
for file in text_files:
    name = str(file)

    with open(file) as f:
        # Notice we're lowercasing the text. You don't *have*
        # to do this, but it helps eliminate some noise for
        # our purposes.
        text = f.read().lower()
        tokens = word_tokenize(text)

        # Let's just print the length of the tokens list to make
        # sure we're getting sane results. We'll use string interpolation
        # to identify which text we're working with.
        print(f"There are {len(tokens)} tokens in {name}.")

        # Store each file's `tokens` list in the `tokenized_texts`
        # dictionary, using the filename as the key.
        tokenized_texts[name] = tokens
# Out:
# There are 200625 tokens in tlg0012.tlg001.perseus-eng3.txt.
# There are 135463 tokens in tlg0012.tlg002.perseus-eng4.txt.
# There are 175611 tokens in tlg0012.tlg001.perseus-eng4.txt.
# There are 152631 tokens in tlg0012.tlg002.perseus-eng3.txt.

# %% [markdown]
# ### Count the tokens
#
# Now, we could count these tokens by hand, but why do that when Python gives us the `Counter` object?

# %%
from collections import Counter

# Using our `tokenized_texts` dictionary, we'll iterate
# through each key-value pair — remember, the keys are
# filenames and the values are lists of tokens.
# We'll get a count of the tokens by passing the list to
# `Counter`, then we'll change the value for that key to
# a dictionary with its own keys, `tokens` and `counts`.

for filename, tokens in tokenized_texts.items():
    counts = Counter(tokens)

    tokenized_texts[filename] = {"tokens": tokens, "counts": counts}

# %% [markdown]
# Now we can check to see what our frequencies look like.

# %%
tokenized_texts["tlg0012.tlg001.perseus-eng3.txt"]["counts"]["odysseus"]
# Out:
# 128

# %% [markdown]
# ### Calculate the document frequency for a given term
#
# Let's compare occurrences of the strings `"odysseus"` and `"achilles"` — we probably
# expect the former to "matter" more for the _Odysseus_, and the latter for the _Iliad_. Let's see if that's the case.

# %%
df_achilles = 0
df_odysseus = 0

# Calculate the DF for "odysseus" and "achilles".
# We iterate through the dictionary, and then simply
# count the number of files in which we find each term.
# For these two terms, we should probably expect DFs of 4.
for filename, values in tokenized_texts.items():
    if "odysseus" in values['counts']:
        df_odysseus += 1
    
    if "achilles" in values["counts"]:
        df_achilles += 1

# Now we'll import the log function to calculate the IDF for each term.
from math import log10

n_docs = len(tokenized_texts.keys())

idf_achilles = log10(n_docs / df_achilles)
idf_odysseus = log10(n_docs / df_odysseus)

print(idf_achilles)
# Out:
# 0.0

# %%
# Now let's calculate the TF-IDF "score" for each term in each document.

# Once again, iterate through the dictionary.
for filename, values in tokenized_texts.items():
    # Get the total number of terms in each file — we'll
    # use this to calculate the relative frequency as our
    # TF.
    total_terms = len(values['tokens'])

    # Get the TF for each term in this file.
    tf_achilles = values['counts']['achilles'] / total_terms
    tf_odysseus = values['counts']['odysseus'] / total_terms

    # Remember, the simplest version of TF-IDF is just
    # TF * 1/DF
    tf_idf_achilles = tf_achilles * idf_achilles
    tf_idf_odysseus = tf_odysseus * idf_odysseus

    # Now we can report on the statistics for this file
    print(f"""In {filename}:
TF of achilles: {tf_achilles}
TF of odysseus: {tf_odysseus}
TF-IDF of achilles: {tf_idf_achilles}
TF-IDF of odysseus: {tf_idf_odysseus}
""")
# Out:
# In tlg0012.tlg001.perseus-eng3.txt:
# TF of achilles: 0.002043613707165109
# TF of odysseus: 0.000638006230529595
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng4.txt:
# TF of achilles: 0.0001254955227626732
# TF of odysseus: 0.0042816119530794386
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg001.perseus-eng4.txt:
# TF of achilles: 0.002403038534032606
# TF of odysseus: 0.0007061061095261686
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0
#
# In tlg0012.tlg002.perseus-eng3.txt:
# TF of achilles: 0.0001048279838302835
# TF of odysseus: 0.0041603606082643765
# TF-IDF of achilles: 0.0
# TF-IDF of odysseus: 0.0

# %% [markdown]
# Well, the TF-IDF isn't super interesting, but at least we have the TF to fall back on.
#
# :::{note}
# Can you describe what happened? How might we solve this problem?
# :::

# %% [markdown]
# ### Overcoming frequent words
#
# In such a small corpus, it can be difficult to guess words that don't appear in all documents — certainly names of heroes like Achilles and Odysseus will appear in all of the documents, meaning $\log(n/DF)$ will always be 0.
#
# But we can use the `set()` constructor to find words that do not appear in all of the documents, and calculate TF-IDF on them.
#
# In programming, a **set** is very similar to a list, except it guarantees that it only contains at most 1 of every element.
#
# Let's start small:

# %%
my_list = [1, 1, 2, 3, 3]

set(my_list)
# Out:
# {1, 2, 3}

# %% [markdown]
# Notice how calling `set()` on `my_list` gets rid of the duplicate 1s and 3s. We can do likewise with strings.

# %%
non_universal_terms = {}

for filename, values in tokenized_texts.items():
    my_set = set(values['counts'].keys())

    for other_file, other_values in tokenized_texts.items():
        # make sure we don't compare the file
        # to itself, otherwise the difference
        # will be the empty set
        if other_file != filename:
            my_set -= set(other_values['counts'].keys())
    
    # now push the remaining set of terms to the dictionary
    non_universal_terms[filename] = my_set

# log `non_universal_terms` as a sanity check
non_universal_terms
# Out:
# {'tlg0012.tlg001.perseus-eng3.txt': {'onsets',
#   'embassage',
#   'maeonian',
#   'me—that',
#   'out-stretched',
#   'thea',
#   'buprasium',
#   'swiftships',
#   'river-bed',
#   'yoke-pad',
#   'soles',
#   'standest',
#   'isus',
#   'wide-scattered',
#   'blessings',
#   'marveling',
#   '—that',
#   'amny',
#   'froma',
#   'saveth',
#   'polyidus',
#   'protesilaus',
#   'drinking-bouts',
#   "ne'er",
#   'belloweth',
#   '409.1',
#   'aepytus',
#   'strifes',
#   'bronze-harnessed',
#   'cymothoë',
#   'eared',
#   'spattered',
#   'own—yet',
#   'washing-tanks',
#   'ploughing—for',
#   'bane—to',
#   'smitest',
#   'mischief—one',
#   'storm-footed',
#   'marking',
#   'sinketh',
#   'lycophron',
#   'choven',
#   'over-haughty',
#   'springeth',
#   'acessamenus',
#   'peace—yet',
#   'awaiteth',
#   'deemest',
#   'friendliness',
#   'dius',
#   'sullying',
#   'labouring',
#   'him—for',
#   'refreshing',
#   'calesius',
#   '565.1',
#   'consolation',
#   'joineth',
#   'rivalry',
#   'falleth',
#   'ships—would',
#   '159.1',
#   'avow',
#   'laodocus',
#   'serves',
#   'promptings',
#   'fie',
#   'horse-men',
#   'daetor',
#   'slaving',
#   'seemeth',
#   'podaleirius',
#   'casteth',
#   'cleaveth',
#   'gaped',
#   'fury-breathing',
#   'lyctus—for',
#   'shield-bearing',
#   'chicks',
#   'heside',
#   'closest',
#   'astyalus',
#   'vanquisheth',
#   'battlegear',
#   'displeasing',
#   'aepeia',
#   'rotteth',
#   'lustfulness',
#   'agastrophus',
#   'scandeia',
#   'unfed',
#   'tangle-strewn',
#   'valour',
#   'hips',
#   'ensigns',
#   'riseth',
#   'aenus',
#   'despiteful',
#   'digest',
#   'circleth',
#   'plaything',
#   'troes',
#   'forearm',
#   'sword—for',
#   'schedius',
#   'ten-fold',
#   'chanceth',
#   '—hampered',
#   'affright',
#   'fore-most',
#   '485.2',
#   'spurted',
#   'orphan',
#   'hippolochus',
#   'oversea',
#   'tartarus',
#   'swoopeth',
#   'sore-wearied',
#   'midmost',
#   'pillage',
#   'quelled',
#   'unprofitable',
#   'aegaeon',
#   'heed—',
#   'farm-stead',
#   'everywhither',
#   'thick-hidden',
#   'petted',
#   'muie',
#   'quaffest',
#   'entereth',
#   'evilly',
#   'screen',
#   'pedasus',
#   'laboureth',
#   'harvesttime',
#   'trickling',
#   'salt-sea',
#   'trace-horse',
#   'phylomedusa',
#   'fondled',
#   'oft',
#   'cypris',
#   'ganymedes',
#   'polymelus',
#   '203.1',
#   'all-ensnaring',
#   'cyparisseïs',
#   'simois',
#   'stock.',
#   'gone—aye',
#   'cymindis',
#   'entering-in',
#   'vouch-safed',
#   'wile',
#   'achdeans',
#   'grovelled',
#   'arrogance',
#   'bearable',
#   'habitation',
#   'ranging',
#   'attiring',
#   'new-built',
#   'dint',
#   'tear-fraught',
#   'watchers',
#   'atreus—for',
#   'horses—the',
#   'pards',
#   'echecles',
#   'eateth',
#   'waxeth',
#   'decayeth',
#   'amphiclus',
#   'ca11ed',
#   'entreatment',
#   'aenius',
#   'swiftlier',
#   'seaboard',
#   'pursueth',
#   'men-at-arms',
#   'white-toothed',
#   'anvil-block',
#   'crutch',
#   'sthenelus',
#   'reproachfully',
#   'son—his',
#   'mountain-tops',
#   'deïcoön',
#   'sea-beach',
#   'agrius',
#   'woollen',
#   'whirleth',
#   'adread',
#   'lyrnessus',
#   'athrob',
#   'liveth',
#   'agamemon',
#   'sullen',
#   'bill',
#   'kinfolk',
#   'heaped-up',
#   'eumelas',
#   'hap',
#   'rosettes',
#   'cos.',
#   'thersilochus',
#   'floateth',
#   'bronze-greaved',
#   'feasteth',
#   'housefolk',
#   '—whereas',
#   'ships—',
#   'glens',
#   'outstripped',
#   'water-snake',
#   'enfolding',
#   'bell-wether',
#   'putteth',
#   'ill-favoured',
#   'sea-waves',
#   "where'er",
#   'rangeth',
#   'asian',
#   'sintian',
#   'urgest',
#   'palaces',
#   'shoutings',
#   'sinneth',
#   'recking',
#   'arraying',
#   'assuaging',
#   'sitteth',
#   'this—a',
#   '515.1',
#   'betake',
#   'therethrough',
#   'hecamede',
#   'settest',
#   'eilithyiae',
#   'insults',
#   'keenest',
#   'peleus—in',
#   'trailed',
#   'turningpost',
#   'quenching',
#   'honses',
#   'fallest',
#   'clonius',
#   'bestirreth',
#   'ber',
#   'vaunteth',
#   'demesne-land',
#   'suffereth',
#   'polypoetes',
#   'vexing',
#   'fearsome',
#   'left—',
#   'me—and',
#   'polyaemon',
#   'dressing',
#   'fathec',
#   'spangled',
#   'sayeth',
#   'eleans',
#   'shieldmen',
#   'unspeakable—wolves',
#   'knight',
#   'glideth',
#   'coucheth',
#   '11.1',
#   'swearing',
#   'telleth',
#   'dreams—for',
#   'dare—and',
#   'afresh',
#   'conceiveth',
#   'mustered',
#   'hah',
#   'mightier—',
#   'dismiss',
#   'dishonoured',
#   'trustest',
#   'haft',
#   'tarring',
#   'knees—apisaon',
#   'foolhardy',
#   '55.1',
#   '239.1',
#   '47.1',
#   'wheeleth',
#   'bronze-hooved',
#   'seizeth',
#   'hector—for',
#   'hieth',
#   '331.1',
#   'more—and',
#   'feil',
#   'mixingbowl',
#   'bronze-wrought',
#   'advance',
#   'leeches',
#   'antilochos',
#   'pathway',
#   'spewing',
#   '327.1',
#   'long-edged',
#   'taiaemenes',
#   'thoë',
#   'joyeth',
#   'bubbleth',
#   '271.1',
#   'overturn',
#   'foe-men',
#   'evenus',
#   'gat',
#   'assuaged',
#   'concord',
#   'condemn',
#   'puffing',
#   'staineth',
#   'nastes—nastes',
#   'eüssorus',
#   'presumptuous',
#   'thereunder',
#   'dismount',
#   'cringed',
#   'rods',
#   'singers',
#   'fir-tree',
#   'scamandrius',
#   'all-nurturing',
#   'starteth',
#   'sentinel',
#   'thoön',
#   'honourof',
#   'bringeth',
#   "'twere",
#   'crashed',
#   'anemoreia',
#   'soothed',
#   'lulleth',
#   'cilicia',
#   'aforetimethou',
#   'turmuoil',
#   'rendeth',
#   'lieth',
#   'balius',
#   'scyrus',
#   'bank—a',
#   'delighting',
#   'gnaw',
#   'rum',
#   'battling',
#   'heaven—a',
#   'battle—unwitting',
#   'taketh',
#   'unstable',
#   'hyllus',
#   'axius—',
#   'appeasement',
#   'floweth',
#   'charis',
#   'deïpyrus',
#   'joinings',
#   'encircled',
#   'doryclus',
#   'lightning-bolt',
#   'astyocheia',
#   'differs',
#   'discerned',
#   'swift-streaming',
#   'swelleth',
#   'feathered',
#   'larisa',
#   'excessive',
#   'properly',
#   'oncoming',
#   'muse—best',
#   '249.1',
#   'blood.',
#   'withdrawing',
#   'driving-back',
#   'infallible',
#   'indignity',
#   'tormented',
#   'paeëon',
#   'streams—the',
#   'pyraechmes',
#   'knelt',
#   'glauce',
#   'evil-doers',
#   'irketh',
#   'aided',
#   'increaseth',
#   'ordaineth',
#   'wolf-born',
#   'careth',
#   'overweeningly',
#   'upbringing',
#   'surpasseth',
#   'amphoterus',
#   'polydorus',
#   'thelr',
#   'chiefly',
#   'messes',
#   'over-weening',
#   'gathereth',
#   'epeians',
#   'simoïs',
#   'wrathful',
#   'tempest-blast',
#   'contrariwise',
#   'inviolable',
#   'bowmanship',
#   'guarding',
#   'transgresseth',
#   'th',
#   'matchest',
#   'mycalessus',
#   'gable-rafters',
#   'shuddereth',
#   'loud-voiced',
#   'shrill-sounding',
#   'teareth',
#   'leaguer',
#   'fleshing-block',
#   'others—pitiless',
#   'soft-hearted',
#   'muen',
#   'new-wrought',
#   'bested',
#   'loud-lowing',
#   'combed',
#   'mingleth',
#   'hither-ward',
#   'zeus—hard',
#   'baseness',
#   'go—it',
#   'blunt',
#   'forgettest',
#   'groaneth',
#   'pried',
#   'hoary',
#   'unwashen',
#   'actaeä',
#   'cadmeians—',
#   'amphidamus',
#   'numbed',
#   'disobedient',
#   'hinu',
#   'thereof—',
#   'holden',
#   'stared',
#   'marreth',
#   'unwon',
#   'fleetly',
#   'clutcheth',
#   'lance',
#   'adornment',
#   'nethermost',
#   'withal—',
#   'rake',
#   'levelling',
#   'close-fastening',
#   'driveth',
#   'beseemeth',
#   'atymnius',
#   'eïonae',
#   'purposed',
#   'coursed',
#   'constraint',
#   'child-bearing',
#   'more.',
#   'undaunted—cast',
#   'augur—these',
#   'footed',
#   'swine-herd',
#   'borus',
#   'scamander',
#   'areïlycus',
#   '419.2',
#   '209.1',
#   'harbours',
#   'podargus',
#   'penning',
#   'furthur',
#   '419.1',
#   'gazeth',
#   'fleeting',
#   'kerchief',
#   'collar',
#   'glaucus',
#   'briefer',
#   'fair-woven',
#   'violet-hued',
#   'lysander',
#   'gleaming-bright',
#   'rhipe',
#   '565.2',
#   '—thou',
#   'chargeth',
#   'alcmaon',
#   'maiden—youth',
#   'wantonly',
#   'formeth',
#   'stymphalus',
#   'spear-cast',
#   'euphorbus',
#   'us—shadowy',
#   'amain',
#   'tarne',
#   "whatsoe'er",
#   "'twixt",
#   'stratia',
#   'necks—fools',
#   'sweepeth',
#   'lapith',
#   'powers',
#   'melting-vats',
#   'defacement',
#   '—on',
#   'ploughmen',
#   'sorrowless',
#   "bull's-hide",
#   'star—the',
#   'threatenings',
#   'tne',
#   'outstay',
#   'half-divine—of',
#   'harangue',
#   'hyrtacus',
#   'harry',
#   'halië',
#   'nourisheth',
#   'abideth',
#   'man—fool',
#   'fallow-land',
#   'encountered',
#   'spear-shaft',
#   'not—',
#   'glancing',
#   'heptaporus',
#   'life-giving',
#   'lighteth',
#   'gods—that',
#   'meed',
#   'wasteth',
#   'araisodarus',
#   'bright-gleaming',
#   'turning-points',
#   'alalcomenean',
#   'achilles—his',
#   'lamentest',
#   'unfought',
#   'bristleth',
#   'hungereth',
#   'side-traces',
#   'bronze—and',
#   'achaeans—for',
#   'refuseth',
#   'maim',
#   '329.1',
#   'enters',
#   'stout-builded',
#   'evippus',
#   'tract',
#   'bryseiae',
#   'hike',
#   'profitless',
#   '—if',
#   'fair-fashioned',
#   'fulfilleth',
#   'father-slayer',
#   'looketh',
#   'elm',
#   'hipponous',
#   'causeth',
#   '121.1',
#   'tugs',
#   'meeteth',
#   'zeus—who',
#   'corslet',
#   'asaeus',
#   'way-farer',
#   '521.1',
#   'arousing',
#   'polyneices',
#   'switft-footed',
#   'consorteth',
#   'fodder',
#   'inquirest',
#   'lurid',
#   'capaneus',
#   'straight-flying',
#   'agacles',
#   'phausius',
#   'autophonus',
#   'deed—one',
#   'harnesseth',
#   'sufficeth',
#   'blacker',
#   'walketh',
#   'swifted-footed',
#   'cadmeians',
#   'confront',
#   'equa1',
#   '181.1',
#   'biding',
#   'overmastered',
#   'hippodamus',
#   'intervene',
#   'sharp-toothed',
#   'spakest',
#   'doest',
#   'strophius',
#   'ialmenus',
#   'overmaster',
#   '—of',
#   'pandocus',
#   '—then',
#   'skilless',
#   'eteonus',
#   'phlegyes',
#   'stud',
#   'counselled',
#   'coeranus',
#   'spercheüs',
#   'ialysus',
#   'haze',
#   'boys—a',
#   'thie',
#   'briseïs',
#   'devoureth',
#   'exuiting',
#   'clashing',
#   'astypylus',
#   'arcadian',
#   'antimachus',
#   'comers',
#   'pylaemenes',
#   'smooth-barked',
#   'mid-space',
#   'whelm',
#   'selli',
#   'overmastereth',
#   'weigheth',
#   'forasmuch',
#   'setteth',
#   'opus',
#   'glistering',
#   'due—',
#   'olympus—',
#   '199.1',
#   'term',
#   'men—asius',
#   'scolus',
#   'vapour',
#   'moat',
#   'heard—',
#   'clamour',
#   'eneti',
#   'gleameth',
#   'crasheth',
#   'keenliest',
#   'granicus',
#   'grieveth',
#   'bathycles',
#   'forsakest',
#   'giveth',
#   'bird-diviners',
#   'swift-glancing',
#   'byre',
#   'louder',
#   'waelthy',
#   'epicles',
#   'conveyers',
#   'welleth',
#   'phradraon',
#   'scorned',
#   'home-going',
#   'zeus-sprung',
#   'turning-point',
#   'spool',
#   'eteocles',
#   'autonous',
#   '551.1',
#   'persisteth',
#   'guideth',
#   'anigh',
#   'melanippus',
#   'labourers',
#   '319.2',
#   'steading—but',
#   'nigher',
#   'stripes',
#   'flutter',
#   'halter',
#   'lasheth',
#   'chalcodon',
#   'all-unscathed',
#   'lycastus',
#   'delights',
#   'shear',
#   'stirreth',
#   'deft',
#   'horse-taming',
#   'mantineia',
#   'blackened',
#   'ohd',
#   "e'er",
#   '527.1',
#   'war-god',
#   'flighty',
#   'leapeth',
#   'out-runneth',
#   'damans',
#   '275.1',
#   'glorified',
#   'biddeth',
#   'ruinous',
#   'well-balanced',
#   '423.1',
#   'honoured',
#   'war-loving',
#   'streaming',
#   'aiders',
#   'discerneth',
#   'spaclous',
#   'afflict',
#   'echinae',
#   'honoureth',
#   'leïtus',
#   'alcathous—son',
#   'deïphobus—',
#   'shay',
#   'loose—the',
#   'heraldship',
#   'rouseth',
#   '557.1',
#   'lease',
#   'doer',
#   'admetus',
#   'war-gear',
#   'pleiades',
#   'witlessness',
#   "soe'er",
#   'sipylus',
#   'zone',
#   'slumbering',
#   'braided',
#   'hardily',
#   'iaera',
#   '29.1',
#   'skirts',
#   'callicolone',
#   'war—',
#   'landmark-stones',
#   'ceaseth',
#   '395.1',
#   'diligent',
#   'rose-sweet',
#   'saith',
#   'shield-men',
#   '37.1',
#   'grovelling',
#   'commandment',
#   'stoodest',
#   'therewithal',
#   'upbare',
#   'swift-falling',
#   'mideia',
#   'watcheth',
#   'way—in',
#   'whenas',
#   'accepteth',
#   'contempt',
#   'draggeth',
#   'aether',
#   'sthenelaus',
#   'combat.',
#   'coffer',
#   'nurseth',
#   'beholdeth',
#   'heart—it',
#   'reareth',
#   'alpheius',
#   'ot',
#   'afright',
#   'trampling',
#   'bethougnt',
#   'irresistible',
#   'splendour',
#   'aesyetes',
#   'waggon',
#   'much—but',
#   'titaressus',
#   'besieged',
#   'loathsome',
#   '—not',
#   '81.1',
#   'greatsouled',
#   'apart—yet',
#   'hypeiron',
#   'bethinking',
#   'apollos',
#   'lycophontes',
#   'agreement',
#   'watering-place',
#   'home-return',
#   'forswear',
#   'soul-devouring',
#   '—one',
#   'well-twisted',
#   'troy-land',
#   'vouchsafeth',
#   'men-folk',
#   'blazeth',
#   'thiat',
#   'sheep-fold',
#   'summoneth',
#   'deemeth',
#   'division',
#   'arsinous',
#   'helicaon',
#   'alcimedon',
#   'ships—they',
#   'hindereth',
#   'ox-eyed',
#   'horses.but',
#   'melteth',
#   "o'erleap",
#   'trechus',
#   'iron—ten',
#   'opheltius',
#   'steeling',
#   'reprisal',
#   'deïphobus',
#   'shimmering',
#   'shifteth',
#   'war-din',
#   'puppet',
#   'darteth',
#   'jewels',
#   'rending',
#   'orchards',
#   '—asius',
#   'simples',
#   'faintly',
#   'goaders',
#   'sorrow-laden',
#   'lodged',
#   'hand—upon',
#   'abii',
#   'limnoreia',
#   'endlessly',
#   'sore-pressed',
#   'begat—',
#   'showest',
#   'separates',
#   'far-shadowing',
#   'obdurate',
#   'entreating',
#   'raze',
#   'contriver',
#   'fleest',
#   'swift-flowing',
#   'zeus—even',
#   'manliness',
#   'ones—even',
#   'rageth',
#   'channel—',
#   'over-powering',
#   'war—dark',
#   'applauding',
#   'warcry',
#   'pylos-born',
#   'wordrous',
#   'strong-hooved',
#   'high-gated',
#   'fouling',
#   'epistrophus',
#   'rampart',
#   'quick-glancing',
#   'enjoined',
#   'railings',
#   'willeth',
#   'broiderings',
#   'thiem',
#   'aegis—the',
#   'bespake',
#   'carystus',
#   'peneius',
#   'now—it',
#   'minishing',
#   'destined',
#   'childishness',
#   'minyeïus',
#   'fair-growing',
#   'tamers',
#   'iamenus',
#   'unfledged',
#   'unmeet',
#   'loerians',
#   'eileithyia',
#   'flieth',
#   'bottle',
#   'straineth',
#   'haughtinesses',
#   'ceas',
#   'man-child',
#   'aïdoneus',
#   'percote',
#   'flax',
#   'araphius',
#   'shineth',
#   'podarces',
#   'striplings',
#   'heareth',
#   'wind-swept',
#   'yore',
#   'knoweth',
#   'axius',
#   'prone',
#   'sputtering',
#   'afore',
#   'talaus',
#   'althaea',
#   'rough-cast',
#   'shrinketh',
#   'declaredst',
#   'folk—ye',
#   'elm-trees',
#   'argives—some',
#   'caystrius',
#   'alectryon',
#   '397.1',
#   'upbraids',
#   '51.1',
#   'laogonus',
#   'lyres',
#   'unpaid',
#   'murmuring',
#   'bivouac',
#   'abydus',
#   'threateneth',
#   'dight',
#   'learnt',
#   'telamonian',
#   'plain—even',
#   'undermost',
#   'stinting',
#   'ln',
#   'imbrius',
#   'vineland',
#   'on-coming',
#   'strong-hoofed',
#   'icarian',
#   'tmolas',
#   'caletor',
#   'ithaemenes',
#   'troians',
#   'zeleia',
#   'payest',
#   'eudorus',
#   'thalysius',
#   'evil-minded',
#   'observed',
#   'stooping',
#   'pteleos',
#   'exacting',
#   'rod',
#   'amarynceus',
#   'stealing',
#   'nurtures',
#   'fulness',
#   'stabbed',
#   'gods—he',
#   'great-souled',
#   'amphinone',
#   'aud',
#   'wherefor',
#   '551.2',
#   'menesthius',
#   'marsh-land',
#   'howl',
#   'calleth',
#   'rolleth',
#   'bodeth',
#   'honourable',
#   'well-wheeled',
#   'sounded',
#   'earth—',
#   'cicalas',
#   'bespeak',
#   'buildeth',
#   'man-hood',
#   'caeneus',
#   'antheia',
#   ...},
#  'tlg0012.tlg002.perseus-eng4.txt': {'brush-wood',
#   'teaches',
#   'okyalos',
#   'independent',
#   'turned.',
#   'fifty-two',
#   'market',
#   'feather',
#   'waking',
#   'conferred',
#   'valuable',
#   'impulse',
#   'unpick',
#   'lively',
#   'disfigure',
#   'misconduct',
#   'ducts',
#   'scenes',
#   'yours.',
#   'vested',
#   'groove',
#   'drenching',
#   'refitting',
#   'reasonably',
#   'scolding',
#   'pyriphlegethon',
#   'blessedness',
#   'remarks',
#   'sidonia',
#   'shifted',
#   'verbal',
#   'leda',
#   'iros',
#   'seal',
#   'vassal',
#   'regained',
#   'apartment',
#   'perfidy',
#   'well-disposed',
#   'polite',
#   'volunteers',
#   'nausithoos',
#   'heinous',
#   'wink',
#   'distress.',
#   'scarred',
#   'behavior',
#   'insulting',
#   'interrupted',
#   'admittance',
#   'valuables',
#   'poorer',
#   'tidy',
#   'thawed',
#   'well-found',
#   'infinity',
#   'pits',
#   'credit',
#   'fretting',
#   'raven',
#   'freights',
#   'instinct',
#   'cooking',
#   'unpropitious',
#   'doubling',
#   'zethos',
#   'frightful',
#   'ghost',
#   'trees.',
#   'broken-hearted',
#   'kreon',
#   'assure',
#   'square',
#   'enchantments',
#   'supersede',
#   'cechalian-',
#   'casks',
#   'hoeing',
#   'loading',
#   'coast',
#   'acceptance',
#   'fort',
#   'polyneos',
#   'peopled',
#   'resuming',
#   'examined',
#   'maidservant',
#   'originally',
#   'importunity',
#   'uncivilized',
#   'misconducted',
#   'schemer',
#   'crossbeams',
#   'encouragingly',
#   'sufficient',
#   'import',
#   'provisioned',
#   'gold-enthroned',
#   'congratulate',
#   'lavishly',
#   'washing-cisterns',
#   'reflected',
#   'agreeable',
#   'gibes',
#   'dangerously',
#   'muttering',
#   'pestering',
#   'halosydne',
#   'festivities',
#   'courting',
#   'sailor',
#   'forceful',
#   'score',
#   'jumpers',
#   'aurora',
#   'bedside',
#   'torch-light',
#   'lend',
#   'fuller-handed',
#   'sea-',
#   'tour',
#   'meat-basket',
#   'becalmed',
#   'flatter',
#   'mistrust',
#   'ogygian.',
#   'schemes',
#   'dispute',
#   'curly',
#   'jumped',
#   'patron',
#   'boil',
#   'exhausted',
#   'antagonist',
#   'freemen',
#   'chopping',
#   'still.',
#   'compel',
#   'unblended',
#   'dresser',
#   'propitiation',
#   'soot',
#   'swindler',
#   'horizon',
#   'staid',
#   'humbly',
#   'damask',
#   'nêpenthes',
#   'scolded',
#   'festooned',
#   'thunder-bolts',
#   'prison',
#   'shoals',
#   'interesting',
#   'behave',
#   'arranged',
#   'severe',
#   'ekhthron',
#   'lodging',
#   'undergoing',
#   'moodily',
#   'girds',
#   'luxury',
#   'islet',
#   'inhuman',
#   'series',
#   'outhouses',
#   'claws',
#   'leveled',
#   'excellently',
#   'overflow',
#   'crime',
#   'howling',
#   'recalling',
#   'fraud',
#   'fancies',
#   'wrinkles',
#   'painlessly',
#   'appalling',
#   'loveliness',
#   'hemming',
#   'illustrious',
#   'crunch',
#   'bards',
#   'hatchet',
#   'invent',
#   'ensconced',
#   'adventures',
#   'picking',
#   '-for',
#   'gull',
#   'aigyptios',
#   'result',
#   'object',
#   'banqueting',
#   'supposing',
#   'cleanses',
#   'recoup',
#   'crop',
#   'evidently',
#   'ripens',
#   'dry-rotted',
#   'inextinguishable',
#   'surf-beaten',
#   'tricky',
#   'ripping',
#   'demoptolemos',
#   'gilding',
#   'detain',
#   'well-ripened',
#   '-but',
#   'unfortunate',
#   'lamos',
#   'actually',
#   'nudged',
#   'glide',
#   'kisses',
#   'ismaros',
#   'mesaulios',
#   'fishy',
#   'consciences',
#   'ordeals',
#   'ill-natured',
#   'crew.',
#   'nations',
#   'sweetmeats',
#   'sportsmen',
#   'succession',
#   'persons',
#   'soften',
#   'adored',
#   'sunrise',
#   'hereabouts',
#   'magician',
#   'miscreants',
#   'amount',
#   'tallied',
#   'charming',
#   'visitors',
#   'seagulls',
#   'calamities',
#   'thrives',
#   'religious',
#   'sweethearts',
#   'injury',
#   'house-keeper',
#   'no-good',
#   'coxswain',
#   'assures',
#   'artisans',
#   'diverted',
#   'poets',
#   'close-in',
#   'amnisos',
#   'apprehend',
#   'humming',
#   'aimlessly.',
#   'rigorously',
#   'swooning',
#   'magnificently',
#   'conversing',
#   'alkippe',
#   'bread-basket',
#   'eurymos',
#   'frustrate',
#   'intention',
#   'disturbed',
#   'horrible',
#   'boatmen',
#   'rekindle',
#   'alektor',
#   'unwaked',
#   'travels',
#   'itylos',
#   'rude',
#   'nobly',
#   'petition',
#   'intends',
#   'clapping',
#   'reclined',
#   'decently',
#   'bedroom',
#   'gourmet',
#   'henchmen',
#   'persist',
#   'fireside',
#   'victuals',
#   'savory',
#   'shamefaced',
#   'people-',
#   'extra',
#   'rascal',
#   'stratios',
#   'hearers',
#   'unharnessed',
#   'forge',
#   'modest',
#   'hurdles',
#   'neat',
#   'goddess.',
#   'whirlwinds',
#   'seethed',
#   'figures',
#   'caring',
#   'infamy',
#   'inconvenience',
#   'gloomy',
#   'horseback',
#   'usual',
#   'wooer',
#   'fret',
#   'cattle-lifting',
#   'shambles',
#   'frugal',
#   'cloisters',
#   'grassed',
#   'aware',
#   'enforce',
#   'once.',
#   'deliberately',
#   'contended',
#   'exterminate',
#   'dresses',
#   'lifts',
#   'travelers',
#   'select',
#   'accordingly',
#   'noised',
#   'amphialos',
#   'obstacles',
#   'simple',
#   'limp',
#   'cleaned',
#   'clamorous',
#   'dozen',
#   'cobwebs',
#   'cargoes',
#   'replenishing',
#   'repeat',
#   'netted',
#   'reminding',
#   'strictly',
#   'entranced',
#   'amuse',
#   'sea-gull',
#   'invariably',
#   'imagine',
#   'fleas',
#   'exit',
#   'nericum',
#   'free-booters',
#   'screams',
#   'peisistratos',
#   'matrimony',
#   'eternity',
#   'charlatan',
#   'ikmalios',
#   'foreigner',
#   'rangers',
#   'powder',
#   'chamois',
#   'amphilokhos',
#   'deathlike',
#   'shift',
#   'atrociously',
#   'blank',
#   'comfortingly',
#   'blue',
#   'pretense',
#   'threes',
#   'well-tilled',
#   'cases',
#   'gunwale',
#   'debts',
#   'amphinomos',
#   'afflictions',
#   'enamel',
#   'spell-proof',
#   'bitterest',
#   'housemaids',
#   'grandfather',
#   'prodigies',
#   'dances',
#   'gracefulness',
#   'squally',
#   'periklymenos',
#   'sea-gulls',
#   'ogres',
#   'astounded',
#   'temesa',
#   'eurynomos',
#   'dairy',
#   'exiles',
#   'curiosity',
#   'bondsman',
#   'cairn',
#   'embellishments',
#   'reckon',
#   'athlete',
#   'stranded',
#   'aigyptos',
#   'outlive',
#   'disgust',
#   'well-mated',
#   'inhabitants',
#   'encircle',
#   'familiarity',
#   'extraordinarily',
#   'adorn',
#   'occurred',
#   'damaged',
#   'memories',
#   'affair',
#   'leukothea',
#   'perjurer',
#   'broken-down',
#   'euphrosunê',
#   'marauders',
#   'jumping',
#   'tricks',
#   'straightening',
#   'plucks',
#   'eurymakhos',
#   'fits',
#   'misadventure',
#   'resemble',
#   'convene',
#   'ill-conditioned',
#   'overlap',
#   'gossips',
#   'hundreds',
#   'notices',
#   'respectable',
#   'krataiis',
#   'unwasted',
#   'eurymedousa',
#   'shocked',
#   'manure',
#   'scoundrels',
#   'center-post',
#   'pat',
#   'needlework',
#   'handsome',
#   'growl',
#   'consciousness',
#   'anabesineos',
#   'competed',
#   "'you",
#   'grievance',
#   'recline',
#   'expedition',
#   'rejoined',
#   'sighing',
#   'juicy',
#   'blighting',
#   'remove',
#   'pork',
#   'pretty',
#   'individuals',
#   'competing',
#   'coherent',
#   'bowshot',
#   'aver',
#   'wither',
#   'crews',
#   'oak-shoots',
#   'subtler',
#   'ill-treating',
#   'deficient',
#   'accompaniment',
#   'rode',
#   'frowned',
#   'work-box',
#   'swamp',
#   'beckoned',
#   'wonders',
#   'swaying',
#   'boethoos',
#   'cruelest',
#   'dears',
#   'undergone',
#   'hereditary',
#   'drunkard',
#   'constancy',
#   'parts.',
#   'insignificant',
#   'somebody',
#   'conclude',
#   'unfold',
#   'interest',
#   'deities',
#   'beechmast',
#   'lowering',
#   'quality',
#   'intelligent',
#   'heaven-taught',
#   'parties',
#   'bleached',
#   'bargaining',
#   'ethiopia',
#   'ash-wood',
#   'drubbing',
#   'bloodlessly',
#   'site',
#   'amply',
#   'outshine',
#   'frequent',
#   'dipping',
#   'unwarily',
#   'detested',
#   'seduced',
#   'age-mate',
#   'propriety',
#   'embolden',
#   'peaceful',
#   'disputes',
#   'pounced',
#   'spending',
#   'permanently',
#   'phaethousa',
#   'day-break',
#   'gambol',
#   'recollect',
#   'endeavors',
#   'terror-struck',
#   'attacks',
#   'alighting',
#   'blear',
#   'unexpectedly',
#   'raiding',
#   'water-sprinkling',
#   'sided',
#   'good-bye',
#   'steaming',
#   'injure',
#   'impunity',
#   'shifty',
#   'apples',
#   'gobbets',
#   'lances',
#   'daughters-in-law',
#   'selected',
#   'outcry',
#   'noses',
#   'lamentably',
#   'shiver',
#   'baring',
#   'sacrificial',
#   'blacksmith',
#   'discreditable',
#   'entirely',
#   'neaira',
#   'maron',
#   'embracing',
#   'mutual',
#   'tempts',
#   'liberal',
#   'grilled',
#   'peering',
#   'overhung',
#   'protector',
#   'reconnoiter',
#   'strategy',
#   'atmosphere',
#   'partner',
#   'overheard',
#   'providence',
#   '-lay',
#   'singular',
#   'handy',
#   'solitary',
#   'dirty',
#   'pester',
#   'noticing',
#   'naughtiness',
#   'massacre',
#   'trap',
#   'overrun',
#   'overboard',
#   'saluting',
#   'grandmother',
#   'purely',
#   'alternatives',
#   'straighter',
#   'center-piece',
#   'fish-fag',
#   'innocent',
#   'purchased',
#   'topes',
#   'drown',
#   'attempt',
#   'gate-house',
#   'rotting',
#   'prowls',
#   'deaths',
#   'contemptuously',
#   'crimson',
#   'insist',
#   'athlêtês',
#   'tournament',
#   'auger',
#   'virgin',
#   'abetting',
#   'handle-holes',
#   'unsewn',
#   'mid-ocean',
#   'aigisthos',
#   'sundry',
#   'deserve',
#   'shoo',
#   'chickens',
#   'tortures',
#   'bed-prop',
#   'strainers',
#   'reeking',
#   'muzzled',
#   'peacefulness',
#   'apeira',
#   'depends',
#   'scoundrel',
#   'noiselessly',
#   'tyndarus',
#   'deign',
#   'punished',
#   'propitious',
#   'nervous',
#   'absence.',
#   'dogfish',
#   'witchcraft',
#   'starving',
#   'shy',
#   'cheerfulness',
#   'convinced',
#   'ill-judged',
#   'neighboring',
#   'detaining',
#   'salutes',
#   'withholds',
#   'louts',
#   'tracks',
#   'sicel',
#   'upholds',
#   'pious',
#   'dangerous',
#   'misfortunes',
#   'dish',
#   'recklessness',
#   'rills',
#   'removing',
#   'bribes',
#   'demodokos',
#   'anchor',
#   'vestibule',
#   'languages',
#   'acre',
#   'ache',
#   'kneading',
#   'fatten',
#   'limbo',
#   'tamed',
#   'continual',
#   'exploits',
#   'answering',
#   'conscience-stricken',
#   'ivy-wood',
#   'explained',
#   'gossiping',
#   'juryman',
#   'floats',
#   'questioning',
#   'fine-looking',
#   'misgave',
#   'listens',
#   'overran',
#   'tremendous',
#   'banish',
#   'perching',
#   'shockingly',
#   'ancestors',
#   'spit',
#   'jeer',
#   'board.',
#   'ramping',
#   'anti-',
#   'superintend',
#   'grease',
#   'vantage',
#   'stouter',
#   'epikaste',
#   'stronghold',
#   'quantities',
#   'sucking',
#   'anyhow',
#   'iphikles',
#   'sicels',
#   'hint',
#   'butchered',
#   'traveled',
#   'chooses',
#   'worrying',
#   'hospitably',
#   'stagger',
#   'absolutely',
#   'competitions',
#   'completely',
#   'merchant',
#   'chance.',
#   'schemed',
#   'liquor',
#   'gut',
#   'agonies',
#   'outraged',
#   'intending',
#   'heaving',
#   'cooked',
#   'country-farm',
#   'fish-like',
#   'pigsties',
#   'worries',
#   'position',
#   'professed',
#   'pontonoos',
#   'smelling',
#   'intended',
#   'doubled',
#   'sputtered',
#   'accurately',
#   'long-suffering',
#   'dare-devil',
#   'gossamer',
#   'difficulties',
#   'poison',
#   'events',
#   'pleasuring',
#   'relate',
#   'manned',
#   'asopos',
#   'gobbled',
#   'stories',
#   'affect',
#   'damp',
#   'withholding',
#   'honors',
#   'ointments',
#   'gadding',
#   'merchants',
#   'world.',
#   'subscriptions',
#   'glowing',
#   'genuine',
#   'scrolls',
#   'peloponnese',
#   'tidily',
#   'reduced',
#   'breadbaskets',
#   'dreamland',
#   'abounds',
#   'watered',
#   'discernment',
#   'impossible',
#   'nods',
#   'proceeded',
#   'trooping',
#   'pig',
#   'visits',
#   'mentioned',
#   'grossly',
#   'legacy',
#   'persuasive',
#   'plaintive',
#   'coasts',
#   'raisins',
#   'apatê',
#   'frame',
#   'uncertainty',
#   'freighting',
#   'wiliness',
#   'clever',
#   'ravaged',
#   'lives.',
#   'stools',
#   'foretold',
#   'oikleus',
#   'crowning',
#   'bedded',
#   'attention',
#   'ktesippos',
#   'spirited',
#   'mysterious',
#   'tatters',
#   'discuss',
#   'wakefully',
#   'anybody',
#   'luxuriantly',
#   'barbarous',
#   'accounts',
#   'echetos',
#   'invites',
#   'eurykleia',
#   'kissing',
#   'serious',
#   'inquiring',
#   'prevails',
#   'studied',
#   'shabby',
#   'apology',
#   'usurp',
#   'forenoon',
#   'clapped',
#   'wonderfully',
#   'magnificent',
#   'creditable',
#   'timely',
#   'perilous',
#   'fortune-telling',
#   'enthroned',
#   'mash',
#   'breeder',
#   'evenings',
#   'management',
#   'elysium',
#   'obtaining',
#   'case-hardened',
#   'goodness',
#   'offices',
#   'tiptoe',
#   'stiffness',
#   'miller-women',
#   'mission',
#   'eumaios',
#   'bleeds',
#   'anticipates',
#   'knock',
#   'squalls',
#   'awed',
#   'nothing.',
#   'clamored',
#   'lump',
#   'drowned',
#   'firstly',
#   'ox-thong',
#   'emptied',
#   'squeal',
#   'ungrafted',
#   'foresworn',
#   'bearing-posts',
#   'bye',
#   'donors',
#   'relation',
#   'many-sided',
#   'steersmen',
#   'hive',
#   'well-to-do',
#   'traveler',
#   'ktesios',
#   'disturbance',
#   'inches.',
#   'sea-side',
#   'afternoon',
#   'enormous',
#   'promontory',
#   'philoitios',
#   'principles',
#   'irrigate',
#   'indoors',
#   'sluts',
#   'tapestries',
#   'unbound',
#   'downstairs',
#   'bait',
#   'seldom',
#   'eteocretans',
#   'recommend',
#   'scrubbed',
#   'rapids',
#   'obliged',
#   'coated',
#   'side-wind',
#   'abominably',
#   'platform',
#   'outlines',
#   'inheritance',
#   'female',
#   'good-naturedly',
#   'complexion',
#   'difference',
#   'satisfactory',
#   'thrifty',
#   'suggestion',
#   'enabled',
#   'prematurely',
#   'finer',
#   'customs',
#   'illumined',
#   'unmarried',
#   'surrounding',
#   'admired',
#   'entrances',
#   'summertime',
#   'damage',
#   'noticed',
#   'magistrate',
#   'ridiculous',
#   'mob',
#   'ripped',
#   'arrangement',
#   'smart-looking',
#   'bliss',
#   'visitor',
#   'kerdea',
#   'cruse',
#   'bruises',
#   'drunkenness',
#   'starve',
#   'situation',
#   'eurylokhos',
#   'levy',
#   'plotted',
#   'charring',
#   'messmates.',
#   'jelly',
#   'fiber',
#   'aspen',
#   'villainy',
#   'alêtheia',
#   'stages',
#   'ill-behaved',
#   'sea-horses',
#   'behaved',
#   'passages',
#   'mountaintops',
#   'dispensation',
#   'fingered',
#   'admirable',
#   'cloisters.',
#   'onto',
#   'nightfall',
#   'considerable',
#   'pacified',
#   'relations',
#   'piloted',
#   'twenty-four',
#   'imposing',
#   'intolerably',
#   'foreboded',
#   'tambour-frame',
#   'crazed',
#   'drugged',
#   'expression',
#   'alkinoos',
#   'wretchedly',
#   'inches',
#   'uncivil',
#   'ill-treat',
#   'sighs',
#   'scampered',
#   'antikleia',
#   'elect',
#   'tauntingly',
#   'sheep-stealing',
#   'sob',
#   'cravings',
#   'pretext',
#   'warful',
#   'unsavory',
#   'warned',
#   'diplomacy',
#   'ornaments',
#   'briskly',
#   'pomp',
#   'adzed',
#   'shabby-looking',
#   'revelers',
#   'headed',
#   'consulted',
#   'merchandise',
#   'bully',
#   'group',
#   'sheepskin',
#   'laborer',
#   'distressing',
#   'beck',
#   'sardonically',
#   'grafted',
#   'discharge',
#   'continues',
#   'dawdle',
#   'bustled',
#   'starved',
#   'thunderbolts',
#   'depreciate',
#   'rejects',
#   'apartments',
#   'warmly',
#   'wanderers',
#   'beggarly',
#   'ultimately',
#   'pavement',
#   'snaring',
#   'excuse',
#   ...},
#  'tlg0012.tlg001.perseus-eng4.txt': {'hippomakhos',
#   'stave',
#   'gaping',
#   'mountain-track',
#   'penalties',
#   'boons',
#   'duck',
#   'urgent',
#   'pall',
#   'quickest',
#   'roses',
#   'doting',
#   'cushion',
#   'misgiving',
#   'crystal',
#   'wronging',
#   'surpassing',
#   'steeled',
#   'mown',
#   'quailing',
#   'phylomedousa',
#   'wounding',
#   'file',
#   'kteatos',
#   'eionae',
#   'astypylos',
#   'dispatched',
#   'truer',
#   'exults',
#   'councilor',
#   'thicker',
#   'tricked',
#   'ablaze-',
#   'well-nigh',
#   'rock-perched',
#   'householders',
#   'alêthea',
#   'echios',
#   'succor',
#   'groanful',
#   'daintiest',
#   'full-speed',
#   'sallies',
#   'lost-',
#   'yoking',
#   'decrees',
#   'branching',
#   'vaunts',
#   'bondswomen',
#   'contradicts',
#   'spercheios',
#   'collar-bones',
#   'stated',
#   'menaces',
#   'lowed',
#   'attire',
#   'asaios',
#   'carelessness',
#   'northwest',
#   'top-rail',
#   'weddings',
#   'depended',
#   'helter-skelter',
#   'calmed',
#   'axes-',
#   'bystanders',
#   'decoyed',
#   'skirted',
#   'implanted',
#   'smashing',
#   'foolishness',
#   'enjoyment',
#   'unkindness',
#   'echeklos',
#   'waterside',
#   'train',
#   'entrapping',
#   'right-hand',
#   'unnerved',
#   'amphoteros',
#   'linus-song',
#   'bronzed',
#   'continuous',
#   'amphigenea',
#   'thickens',
#   'offend',
#   'spearsmen',
#   'feeblest',
#   'stunned',
#   'universal',
#   'chattel',
#   'thatched',
#   'echekles',
#   'demands',
#   'whisks',
#   'unmolested',
#   'bestrewn',
#   'openmouthed',
#   'levying',
#   'wheel-marks',
#   'persisted',
#   'crushing',
#   'cue',
#   'examine',
#   'goat-herd',
#   'ephyroi',
#   'bud',
#   'routs',
#   'arm-rods',
#   'resolutely',
#   'nay-',
#   'likymnios',
#   'exhort',
#   'death-throes',
#   'awe-struck',
#   'anew',
#   'moaned',
#   'half-circle',
#   'slinks',
#   'fledglings',
#   'zelea',
#   'ebbed',
#   'player',
#   'drowsy',
#   'intervals',
#   'masonry',
#   'ekhepolos',
#   'agakles',
#   'plays',
#   'smooth-tongued',
#   'dales',
#   'askanios',
#   'quoit',
#   'ferret-skin',
#   'gale-',
#   'gainsaid',
#   'untied',
#   'spear-wound',
#   'boxwood',
#   'preceding',
#   'eyed',
#   'reaped',
#   'washing-troughs',
#   'thrash',
#   'echinean',
#   'suffice',
#   'twisting',
#   'foundation',
#   'minyas',
#   'movement',
#   'wolf-skin',
#   'remorse',
#   'menesthios',
#   'women-servants',
#   'notify',
#   'flashes',
#   'judging',
#   'slanderer',
#   'panoply',
#   'induce',
#   'suggestions',
#   'steward',
#   'searches',
#   'argument',
#   'triple-barbed',
#   'unrighteous',
#   'pyraikhmes',
#   'punishing',
#   'meteor',
#   'sounder',
#   'fervently',
#   'eussoros',
#   'exchanged',
#   'cataract',
#   'cleaver',
#   'sheep-yard',
#   'kaletor',
#   'hip-joint',
#   'gamboling',
#   'ennomos',
#   'oreithuia',
#   'dardanos',
#   'thersilokhos',
#   'gorgeous',
#   'sceptered',
#   'texture',
#   'butts',
#   'rhigmos',
#   'kinship',
#   'ankaios',
#   'calamity',
#   'clip',
#   'furnace',
#   'limpid',
#   'unplundered',
#   'severs',
#   'nestlings',
#   'buffeting',
#   'recruit',
#   'never-ending',
#   'buds',
#   'deliberation',
#   'eteokles',
#   'effaced',
#   'laerkes',
#   'parch',
#   'hyrtios',
#   'stickle',
#   'stymphelus',
#   'curbed',
#   'fickle',
#   'lure',
#   'sadness',
#   'polyxenos',
#   'hippokoön',
#   'opportunely',
#   'compassionately',
#   'wine-cup',
#   'perea',
#   'grimy',
#   'serviceable',
#   'overjoyed',
#   'wields',
#   'sedition',
#   'unforgiving',
#   'parleying',
#   'fee',
#   'koön',
#   'hobbled',
#   'dagger',
#   'dikes',
#   'shaped',
#   'unsoiled',
#   'timê',
#   'limped',
#   'silver-eddying',
#   'iaira',
#   'retreat',
#   'hesitate',
#   'indulge',
#   'veering',
#   'partaking',
#   'tow',
#   'ajaxes',
#   'swerves',
#   'wriggled',
#   'overleap',
#   'delicacy',
#   'inviolate',
#   'fittest',
#   'tasseled',
#   'sea-fight',
#   'marshy',
#   'fangs',
#   'groveled',
#   'sword-wounds',
#   'minyeios',
#   'amisodoros',
#   'disdaining',
#   'sighed',
#   'bawling',
#   'dissuaded',
#   'aesopos',
#   'tlepolemos',
#   'archilokhos',
#   'limnorea',
#   'violate',
#   'golden-haired',
#   'mnesos',
#   'ikarian',
#   'tusked',
#   'hektor',
#   'particular',
#   'head-strong',
#   'nestled',
#   'robbing',
#   'boagrios',
#   'afford',
#   'porridge',
#   'atymnios',
#   'unloosed',
#   'tumbling',
#   'areilykos',
#   'kicks',
#   'arriving',
#   'bright-',
#   'mete',
#   'gatemen',
#   'another-',
#   'totally',
#   'elm-tree',
#   'biggest',
#   'indifferent',
#   'plenitude',
#   'meddle',
#   'lykastos',
#   'disquietness',
#   'glories',
#   'dejected',
#   'gravest',
#   'infirmities',
#   'lyktos',
#   'askalaphos',
#   'ambush-',
#   'uppermost',
#   'hammering',
#   'filly',
#   'precise',
#   'jeopardy',
#   'tuft',
#   'halcyon',
#   'erylaos',
#   'task-master',
#   'yawned',
#   'ialmenos',
#   'grain-growing',
#   'sift',
#   'divinity',
#   'aisyetes',
#   'leitos',
#   'aithe',
#   'cyparisseis',
#   'bronze-headed',
#   'concert',
#   'spearsman',
#   'impart',
#   'nerve',
#   'establishing',
#   'peeping',
#   'trice',
#   'thalia',
#   'portentous',
#   'extent',
#   'spade',
#   'cracked',
#   'baned',
#   'melting',
#   'thebaios',
#   'zeus-descended',
#   'spear-head',
#   'shielded',
#   'dells',
#   'pheneus',
#   'cross-bar',
#   'ill-favored',
#   'reconciles',
#   'wide-spreading',
#   'follow-',
#   'pheras',
#   'caressing',
#   'ill-pleased',
#   'harmlessly',
#   'blindly',
#   'unworthy',
#   'artifice',
#   'renew',
#   'hereby',
#   'severity',
#   'well-established',
#   'clears',
#   'fastens',
#   'invitation',
#   'incur',
#   'thymbraios',
#   'turning-posts',
#   'stable-men',
#   'opous',
#   'lagging',
#   'three-legged',
#   'brothers-in-law-for',
#   'fainted',
#   'curdles',
#   'dives',
#   'kreontes',
#   'victor',
#   'anxiety',
#   'haimon',
#   'aigialeia',
#   'woodsman',
#   'bunches',
#   'imprisoned',
#   'haughtiness',
#   'alalkomene',
#   'labor-',
#   'grit',
#   'majesty',
#   'fattened',
#   'flute',
#   'shivered',
#   'manfulness',
#   'overshadow',
#   'resplendent',
#   'rations',
#   'dale',
#   'pore',
#   'smarted',
#   'thoe',
#   'backbone',
#   'stopping',
#   'do-',
#   'robs',
#   'foster-father',
#   'babel',
#   'somehow',
#   'armfuls',
#   'picks',
#   'resolute',
#   'embroidering',
#   'suffuse',
#   'iphinoos',
#   'many-valleyed',
#   'heptaporos',
#   'applied',
#   'assarakos',
#   'hustles',
#   'harass',
#   'time-limit',
#   'defile',
#   'pedasos',
#   'swarmed',
#   'written',
#   'onchestos',
#   'interrupt',
#   'scouring',
#   'bronze-equipped',
#   'unwashed',
#   'well-bolted',
#   'titular',
#   'ox-hides',
#   'gorges',
#   'thenceforward',
#   'offal',
#   'defeated',
#   'river-geese',
#   'acquit',
#   'aipy',
#   'polypoites',
#   'koronos',
#   'worshipped',
#   'onslaught',
#   'beaming',
#   'crookedly',
#   'mid-air',
#   'brandishes',
#   'northward',
#   'assailants',
#   'phalanx',
#   'insure',
#   'amphiklos',
#   'isos',
#   'bared',
#   'slim-waisted',
#   'termagant',
#   'dion',
#   'mekisteus',
#   'lament-making',
#   'silvery',
#   'phlegyans',
#   'befriend',
#   'poises',
#   'branded',
#   'house-dogs',
#   'unattended',
#   'oiled',
#   'rabble',
#   'oxgoad',
#   'defy',
#   'philoi',
#   'ratify',
#   'recovered',
#   'ame',
#   'foot-races',
#   'rescue',
#   'straightly',
#   'savior',
#   'assist',
#   'overruling',
#   'runaway',
#   'shirked',
#   'brother-in-law',
#   'ripening',
#   'left-hand',
#   'heaven-born',
#   'alkimedon',
#   'steams',
#   'lavished',
#   'him-',
#   'recruits',
#   'sea-goddesses',
#   'hermos',
#   'ties',
#   'rhodios',
#   'sister-wife',
#   'graia',
#   'orthaios',
#   'accident',
#   'mantinea',
#   'rancor',
#   'fetching',
#   'wind-beaten',
#   'mated',
#   'overhead',
#   'suborning',
#   'bodes',
#   'champing',
#   'trifles',
#   'fullness',
#   'highways',
#   'lifeless',
#   'rashness',
#   'frightening',
#   'smothered',
#   'welfare',
#   'disquieted',
#   'spleen',
#   'bunched',
#   'blamed',
#   'inexorable',
#   'staunching',
#   'aristos',
#   'remounted',
#   'euphorbos',
#   'opinions',
#   'facing-bothways',
#   'ithaimenes',
#   'avert',
#   'imbrasos',
#   'hedged',
#   'preference',
#   'maion',
#   'oppress',
#   'divides',
#   'forbids',
#   'housed',
#   'single-edged',
#   'blithe',
#   'pledges',
#   'sôphrôn',
#   'winnowing-shovel',
#   'axios',
#   'slits',
#   'augeae',
#   'troubling',
#   'baulked',
#   'doubting',
#   'coast-land',
#   'iamenos',
#   'emblems',
#   'storm-tossed',
#   'close-fighting',
#   'euphemos',
#   'lungs',
#   'boldest',
#   'shamefacedness',
#   'hippodamos',
#   'envoy',
#   'furrowed',
#   'balearic',
#   'courageous',
#   'aesepos',
#   'cozen',
#   'cleaves',
#   'sminthe',
#   'encircling',
#   'time-',
#   'indiscretion',
#   'bedrabbled',
#   'tempers',
#   'charges',
#   'bronze-bedizened',
#   'opposed',
#   'drags',
#   'slobbered',
#   'narrowly',
#   'ship-building',
#   'weak-kneed',
#   'workwomen',
#   'disdain',
#   'noontide',
#   'disinclined',
#   'gore-bedrabbled',
#   'reconsider',
#   'bruise',
#   'bellow',
#   'cayster',
#   'helikaon',
#   'devours',
#   'bedchambers',
#   'hits',
#   'sulking',
#   'horse-breeders',
#   'saying-',
#   'prophesyings',
#   'deep-meadowed',
#   'bronze-smiths',
#   'agaue',
#   'orb',
#   'expects',
#   'overthrown',
#   'spear-stand',
#   'eileithuiai',
#   'swerving',
#   'plaiting',
#   'phocaeans',
#   'sown',
#   'augeas',
#   'humans',
#   'resumed',
#   'lyrnessos',
#   'tons',
#   'hecuba',
#   'carnage',
#   'wildfire',
#   'fluent',
#   'medesikaste',
#   'unpracticed',
#   'butt-end',
#   'polyidos',
#   'bowstrings',
#   'well-trained',
#   'axylos',
#   'cheek-pierced',
#   'specially',
#   'eschew',
#   'guneus',
#   'apothecaries',
#   'surveyed',
#   'noisome',
#   'hangs',
#   'stable-yard',
#   'maniac',
#   'forbidden',
#   'slackening',
#   'careless',
#   'eye-ball',
#   'strayed',
#   'parent',
#   'spreads',
#   'gurgling',
#   'snows',
#   'sounds',
#   'amarynkeus',
#   'accusing',
#   'metal',
#   'galley',
#   'protectress',
#   'pitting',
#   'sharply',
#   'loser',
#   'breathing-time',
#   'labored',
#   'keladon',
#   'banes',
#   'astyochea',
#   'marvels',
#   'heedfully',
#   'brutally',
#   'interlaced',
#   'bouprasion',
#   'unfavorable',
#   'clamoring',
#   'trechos',
#   'committing',
#   'instructed',
#   'impetuously',
#   'menaced',
#   'telos',
#   'lykaon',
#   'far-darting',
#   'lykon',
#   'iphiklos',
#   'clubfooted',
#   'uplift',
#   'koiranos',
#   'stinted',
#   'footprints',
#   'harping',
#   'fore-arm',
#   'flours',
#   'antrum',
#   'schoinos',
#   'selloi',
#   'hacked',
#   'scabbarded',
#   'needy',
#   'unwilting',
#   'career',
#   'peneus',
#   'ranked',
#   'nerved',
#   'minister',
#   'whizzing',
#   'sokos',
#   'chryseis',
#   'alkmaon',
#   'deipylos',
#   'laodokos',
#   'protesilaos',
#   'underwood',
#   'encourage',
#   'shuts',
#   'cajoling',
#   'crossing',
#   'liar',
#   'boils',
#   'crocylea',
#   'greaved',
#   'disobeys',
#   'bathykles',
#   'diaphragm',
#   'headgear',
#   'pining',
#   'richly-equipped',
#   'valorously',
#   'armlets',
#   'salvation',
#   'trozen',
#   'villain',
#   'opposing',
#   'prestigious',
#   'horrors',
#   'handsomely',
#   'favored',
#   'halizonoi',
#   'disgusted',
#   'frames',
#   'concourse',
#   'memnêmai',
#   'aitia',
#   'monument',
#   'uprears',
#   'hunts',
#   'dyed',
#   'kalkhas',
#   'pteleum',
#   'brothers-in-law',
#   'she-mule',
#   'familiar',
#   'untrue',
#   'winning-post',
#   'mule-plowed',
#   'unbelted',
#   'backbones',
#   'flocking',
#   'otos',
#   'mixes',
#   'beings',
#   'extremity',
#   'mid-battle',
#   'welkin',
#   'riverbed',
#   'damming',
#   'thyrsi',
#   'kapaneus',
#   'outposts',
#   'klea',
#   'gallop',
#   'chariot-racing',
#   'imploringly',
#   'tree-oak',
#   'shifting',
#   'hard-working',
#   'observance',
#   'exhorting',
#   'amarynkes',
#   'butcheries',
#   'suing',
#   'selleis',
#   'desperate',
#   'engulf',
#   'therefore-and',
#   'gloat',
#   'fountainhead',
#   'epistrophos',
#   'twixt',
#   'jump',
#   'hustled',
#   'ides',
#   'faded',
#   'brimming',
#   'ear-handled',
#   'containing',
#   'lykomedes',
#   'insatiably',
#   'sparrows',
#   'washes',
#   'bate',
#   'richness',
#   'varne',
#   'almighty',
#   'hippemolgoi',
#   'klonios',
#   'local',
#   'midea',
#   'daimones',
#   'carried-',
#   'melanippos',
#   'victual',
#   'plumed',
#   'spouting',
#   'highlands',
#   'boudeion',
#   'sources',
#   'soughed',
#   'infatuated',
#   'ganymede',
#   'kallikolone',
#   'celery',
#   'pigeon',
#   'aching',
#   'squeaky',
#   'athenian',
#   'helike',
#   'forcing',
#   'said-',
#   'kopreus',
#   'incurring',
#   'laughingly',
#   'arsinoos',
#   'sinful',
#   'allowances',
#   'pillows',
#   'incited',
#   'fight-',
#   'death-cry',
#   'crouches',
#   'aigialos',
#   'speo',
#   'kardamyle',
#   'swarm',
#   'chanting',
#   'flecks',
#   'helos',
#   'violation',
#   'mold',
#   'talaos',
#   'deiopites',
#   'virtuous',
#   'reassured',
#   'makar',
#   'aisyme',
#   'melanthos',
#   'boros',
#   'demigods',
#   'foursquare',
#   'fresh-burnished',
#   'actual',
#   'finality',
#   'unsteady',
#   'deipyros',
#   'relying',
#   'towns',
#   'coppice',
#   'enrage',
#   'clan-gatherings',
#   'mercilessly',
#   'wines',
#   'ormenios',
#   'wended',
#   'wealthiest',
#   'disconcerted',
#   'responsibility',
#   'full-fed',
#   'throes',
#   'imbrios',
#   'instruction',
#   'far-darter',
#   'seven-foot',
#   'whistle',
#   'headstrong',
#   'sea-monster',
#   'wielding',
#   'demokoön',
#   'undismayed',
#   'prothoenor',
#   'evil-hearted',
#   'active',
#   'wheelwright',
#   'showered',
#   'self-confident',
#   'competition',
#   'stalked',
#   'mourns',
#   'quarrelsome',
#   'kaineus',
#   'foreshadows',
#   'starts',
#   'spring-',
#   'dignity',
#   'exchanges',
#   'clank',
#   'relentless',
#   'homesteads',
#   'boundaries',
#   'canopy',
#   'ken',
#   'brandish',
#   'razed',
#   'zephyros',
#   'convulsed',
#   'pine-tree',
#   'amphios',
#   'mid-stream',
#   'erewhile',
#   'retreated',
#   'slaughtering',
#   'rendering',
#   'lineage.',
#   'railer',
#   'inspires',
#   "n't",
#   'orcus',
#   'loses',
#   'death-agony',
#   'bode',
#   'hillsides',
#   'admetos',
#   'truce',
#   'wreaked',
#   'ineffable',
#   'opheltios',
#   'persistently',
#   'expert',
#   'unfailingly',
#   'uncertain',
#   'melting-pots',
#   'cedar-wood',
#   'presuming',
#   'pain-killing',
#   'weather-beaten',
#   'pluck',
#   'leaped',
#   'pervaded',
#   'coarse',
#   'shouldered',
#   'polyaimon',
#   'buffet',
#   'hymen',
#   'foot-soldiers',
#   'sweet-singing',
#   'designs',
#   'consulting',
#   'cowed',
#   'couples',
#   'fork',
#   'heavenward',
#   'unsay',
#   'unwelcome',
#   'soaks',
#   'sthenelaos',
#   'idaios',
#   'reflecting',
#   'perkote',
#   'artificers',
#   'storehouse',
#   'inflict',
#   'laps',
#   'trifled',
#   'lights',
#   'vesture',
#   'well-assured',
#   'myrrhine',
#   'attempted',
#   'weaken',
#   'toppling',
#   'strophios',
#   'challenger',
#   'karystos',
#   'sulkily',
#   'thymbra',
#   'tartaros',
#   'beleaguered',
#   'hussy',
#   'myrmidon',
#   'podarkes',
#   'sustained',
#   'ousted',
#   'leadership',
#   'storming',
#   'asteropaios',
#   'ill-will',
#   'concerned',
#   'isandros',
#   'rescued',
#   'sea-monsters',
#   'goodwill',
#   'grips',
#   'sued',
#   'four-crested',
#   'saffron',
#   'praktios',
#   'sea-nymph',
#   'themistes',
#   'overreach',
#   'titaresios',
#   'ochesios',
#   'offshoot',
#   'garlands',
#   'peaceably',
#   'restive',
#   ...},
#  'tlg0012.tlg002.perseus-eng3.txt': {'labours',
#   'road-steads',
#   'lacks',
#   'comeliness.',
#   'men—meanwhile',
#   'forwardness',
#   "would'st",
#   'strength.',
#   'fair-faced',
#   'rear—if',
#   'seeks',
#   'us—who',
#   'hazarding',
#   'strokes',
#   'teaching',
#   'sicilian',
#   'helper.',
#   'fore-stays',
#   'roaming',
#   'carpentry',
#   'sale',
#   'overseer',
#   'crataiis',
#   'trade',
#   'yelping',
#   'aegyptius',
#   'vagabond.',
#   'parents—would',
#   'criest',
#   'mirth',
#   'phaethusa',
#   'casts',
#   'passer-by',
#   'vaulted-over',
#   'onward—soon',
#   'beaches',
#   'sturdier',
#   'archaeans',
#   'twigs',
#   'paeeon',
#   'deeds.',
#   'longed-for',
#   'tender-heartedness',
#   'cureless',
#   'suffering.',
#   'consorting',
#   'unchanged',
#   'grief.',
#   'ismarus',
#   'regret',
#   'many—aye',
#   'greenwood',
#   'trenches',
#   '—thy',
#   'markest',
#   'vermin',
#   'last.',
#   'owes',
#   'wretchedness',
#   'dawn.',
#   'core',
#   'psyria',
#   'misty',
#   'boastful',
#   'prelude',
#   'war.',
#   'furling',
#   'leucas',
#   'zethus',
#   'deigned',
#   'marring',
#   'circe.',
#   'harm.',
#   'spiders',
#   'giants.',
#   'wakens',
#   'demoptolemus',
#   'oughtest',
#   'thrice-blessed',
#   'deep-moaning',
#   'threateningly',
#   'forsake',
#   'fitteth',
#   'graciously',
#   'another.',
#   'undertook',
#   'tellest',
#   'abstain',
#   'supreme.',
#   'athena.',
#   'dimmed',
#   'city.',
#   'neaera',
#   'pontonous',
#   'curled',
#   'sheep-pen',
#   'postern',
#   'ephialtes—men',
#   'far-off',
#   'strengthening',
#   'confirmed',
#   'males—the',
#   '—where',
#   'rivals',
#   'forests.',
#   'sowing',
#   'irus',
#   'thee—hail',
#   'cross-planks',
#   'feast.',
#   'look—as',
#   'mounts',
#   '—he',
#   'mid-sea',
#   'spear-rack',
#   'gold.',
#   'line—',
#   'much.',
#   'curly-haired',
#   'sulphurous',
#   'pools',
#   'murders',
#   'thole-straps',
#   'loosened—then',
#   'eumaeus',
#   'gifts.',
#   'kindred',
#   'judged',
#   'elder.',
#   'pelasgians',
#   'unmanned.',
#   'myself.',
#   'statelier',
#   'torment.',
#   'rest.',
#   'achilles.',
#   'tale.',
#   'expectantly',
#   'buying',
#   'galling',
#   'stalls',
#   'eurymus',
#   'tearless',
#   'out-stripped',
#   'someday',
#   'husband.',
#   'roamed',
#   'offerings—there',
#   'gulfs',
#   'abound.',
#   'mischief-maker',
#   'porous',
#   'portioning',
#   'ctesius',
#   'made.',
#   'endue',
#   'seemly.',
#   'warms',
#   'no-wise',
#   'impious',
#   'long-shanked',
#   'trotted',
#   'unclear',
#   'besides.',
#   'oar-blade.',
#   'anoints',
#   'conquers',
#   'limb.',
#   'hollows',
#   'shrinkest',
#   'farthermost',
#   'aught.',
#   'brutal',
#   'decree',
#   'blossomed',
#   'gainful',
#   'tie',
#   'four-fold',
#   'portionless',
#   'mesaulius',
#   'arise.',
#   'oared',
#   'blame.',
#   'man-eater',
#   'plight.',
#   'himself.',
#   'afar.',
#   'hand-washing',
#   'wrenched',
#   'bountifully',
#   'blot',
#   'oar-loving',
#   'phaeacians.',
#   'tityos',
#   'resolve',
#   'frisk',
#   'kindness.',
#   'fawningly',
#   'pinched',
#   'launching',
#   'helius',
#   'adulterer.',
#   'prospers',
#   'evade',
#   'was—to',
#   'chair—a',
#   'land—his',
#   'me—for',
#   'crusted',
#   'whit—',
#   'cytherea',
#   'stranger-folk',
#   'wane',
#   'grey-headed',
#   'wife.',
#   'morticings',
#   'persisting',
#   'many-voiced',
#   'god.',
#   'maro',
#   'nudging',
#   'fast.',
#   'shoved',
#   'dangers',
#   'bootes',
#   'modesty',
#   'geraestus',
#   'cities.',
#   'house—proud',
#   'was—even',
#   'stone.',
#   'antinous',
#   'phaedimus',
#   'thoughts.',
#   'livelihood',
#   'it—a',
#   'acastus',
#   'gad-fly',
#   'winnowing-fan',
#   'plenteous',
#   'pasturing',
#   'mused',
#   'pelted',
#   'two-eared',
#   'brine-bred',
#   'me—be',
#   'confusedly.',
#   'neatherd',
#   'unfailing',
#   'strength—and',
#   'feud',
#   'alcmaeon',
#   'thrive',
#   'balm',
#   'cleanest',
#   'awry',
#   'barter',
#   'wrest',
#   'vessels—',
#   'shadows.',
#   '—how',
#   'sorrow—',
#   'weighted',
#   'anticleia',
#   'weddest',
#   'growling',
#   'banqueters',
#   'greed',
#   'robe—',
#   'draught',
#   'pranced',
#   'named.',
#   'guiding',
#   'roundabout',
#   'donning',
#   'wed.',
#   'repute',
#   'well.',
#   'remembers',
#   'two-fold',
#   'strew',
#   'passers-by',
#   'kitchen-wife',
#   'plunging',
#   'deck-beams',
#   'men—as',
#   'passion.',
#   'slave-women',
#   'table-dogs',
#   'seemlier',
#   'these.',
#   'stairway',
#   'naught—ate',
#   'rend.',
#   'tone',
#   'question.',
#   'begrudge',
#   'luckless',
#   'above.',
#   'scrip',
#   'woman—amazement',
#   'well-watered',
#   'cravens',
#   'heardest',
#   'sea—and',
#   'lamus',
#   'amphilochus',
#   'bones.',
#   'befoul',
#   'leucothea',
#   'possessions.',
#   'nobles',
#   'spars',
#   'true-hearted',
#   'enquiring',
#   'joy.',
#   'guiltless.',
#   'somewhat.',
#   'shews',
#   'planks',
#   'fair-stablished',
#   'polycaste',
#   'reviling.',
#   'contest.',
#   'hairy',
#   'vagabonds',
#   'this—what',
#   'in.',
#   'bedims',
#   'true-born',
#   'whencesoever',
#   'basest',
#   'hoof',
#   'reef',
#   'assurance',
#   'feels',
#   '—fool',
#   'intertwining',
#   'arms.',
#   'apollo—for',
#   'ignorance',
#   'mocked',
#   'woos',
#   'sins',
#   'home-coming',
#   'exists',
#   'destruction.',
#   'grief—unless',
#   'charybids',
#   'fiery-pointed',
#   'trial—for',
#   'assume',
#   'plentiful',
#   'keeper',
#   'nameless',
#   'life.',
#   'mournfully',
#   'cuttlefish',
#   'graceless',
#   'stab',
#   'unversed',
#   'syria',
#   'sheep—so',
#   'rags.',
#   'unrestrained',
#   'periphlegethon',
#   'handicraft',
#   'sea-ward',
#   'telemachus—for',
#   'planctae',
#   'cake',
#   'upon.',
#   'mind.',
#   'fugitive',
#   'trojans.',
#   'dismantled',
#   'purging',
#   'sorrows.',
#   'looses',
#   'eye—',
#   'endured.',
#   'soiled—there',
#   'drill',
#   'alcandre',
#   'bedabbled',
#   'door-stone',
#   'aegyptus',
#   'all—one',
#   'widespread',
#   'down.',
#   'bachelors—and',
#   'appears.',
#   'islands—dulichium',
#   'knowledge.',
#   'bridles',
#   'twinklings',
#   'compulsion',
#   'wreckers',
#   'eurymachus',
#   'man—why',
#   'itylus',
#   'swirl',
#   'stunted',
#   'fan',
#   'spellbound',
#   'over-full',
#   'knavish',
#   'dancing-lawns',
#   'stout-hoofed',
#   'notest',
#   'paced',
#   'revolve',
#   'pheae',
#   'descry',
#   'overseen',
#   'byblus',
#   'fairer',
#   'seethe',
#   'bathing',
#   'say.',
#   'melantheus',
#   'bilge',
#   'rehearsed',
#   'purpose.',
#   'worth.',
#   'rust—',
#   'achieves',
#   'fulfilled.',
#   'knaves',
#   'mastered',
#   'aid.',
#   'forebode',
#   'frown',
#   'reared.',
#   'mate',
#   'windward',
#   'townsmen',
#   'desires.',
#   'piloting',
#   'thievery',
#   'deceiving.',
#   'obtained',
#   'throw.',
#   'settlement',
#   'wine.',
#   'fisher',
#   'temese',
#   'robe—i',
#   'sea-eagle',
#   'purged',
#   'designed',
#   'response',
#   'wine-grape',
#   'near.',
#   'ripen',
#   'nuisance',
#   'land—a',
#   'blows.',
#   'substance.',
#   'bed—bedstead',
#   'comest',
#   'webs',
#   'high-of-heart',
#   'compels',
#   'gift.',
#   'milking',
#   'wizard',
#   'tanks',
#   'steering-oar',
#   'feebleness',
#   'lower—they',
#   'surround',
#   'weaned',
#   'amphiaraus',
#   'wailings',
#   'submittest',
#   'bed-fellow',
#   'unmoored',
#   'tasting',
#   'jewel',
#   'awaking',
#   'home—that',
#   'alive.',
#   'boethous',
#   'skilful',
#   'another—',
#   'gazes',
#   'thrall',
#   'weds',
#   'groped',
#   'vanquishes',
#   'roof-beam',
#   'land-ward',
#   'desist.',
#   'wheedling',
#   'women—',
#   'withal.',
#   'hand.',
#   'gains',
#   'smoky',
#   'go.',
#   'rich.',
#   'yard-arm',
#   'suspect.',
#   'valiance',
#   'elsewhere.',
#   'periclymenus',
#   'new-sawn',
#   'amazed',
#   'sun—and',
#   'thee.',
#   'wavers',
#   'achaea.',
#   'power—now',
#   'oicles',
#   'moving',
#   'unhonored',
#   'un-irused',
#   'dissembler',
#   'meal.',
#   'broods',
#   'assembly—for',
#   'coverlets—that',
#   'unmilked',
#   'too—farewell',
#   'ailed',
#   'thee—gathering',
#   'depend.',
#   'loneliness',
#   'pear-trees',
#   'of.',
#   'alector',
#   'escape.',
#   'lord.',
#   'ox-chine',
#   '—in',
#   'waiting-woman',
#   'crackled',
#   'raiment.',
#   'unawakening',
#   'reefs—for',
#   'goats—he',
#   'bewailed',
#   'gunwales',
#   'dastardly',
#   'corax',
#   'abound',
#   'spoil.',
#   'frets',
#   'fallen.',
#   'forth.',
#   'bays',
#   'marriage.',
#   'forboded',
#   'fulfil',
#   'heritage.',
#   'pursuit.',
#   'quarrels',
#   'unfalteringly',
#   'fruit—there',
#   'pegs',
#   'revolved',
#   'wooers—fools',
#   'moanings',
#   'earth.',
#   'spirals',
#   'consortest',
#   'guidance',
#   'potent',
#   'pictures',
#   'decent',
#   'unrighteousness',
#   'weaving—',
#   'requital.',
#   'downcast',
#   'upholding',
#   'man-destroying',
#   'bright-throned',
#   'oar-blades',
#   'head-gear',
#   'oarblades',
#   'cliffs—then',
#   'taphians.',
#   'heaven.',
#   'days.',
#   'recess',
#   'loosened.',
#   'clymenus',
#   'prize—',
#   'weaves',
#   'toil-worn',
#   'guardest',
#   'groanings—gifts',
#   'welcome.',
#   'sea-dogs',
#   'feastest',
#   'wrought—many',
#   'outdo',
#   'oedipodes',
#   'sword-hilt',
#   'failed—for',
#   'sunium',
#   'good-for-naught',
#   'wind.',
#   'thistle-tufts',
#   'winter-time',
#   'ocyalus',
#   'finely',
#   'bores',
#   'earned',
#   'alms',
#   'restraint',
#   'monsters',
#   'death-struggle',
#   'poseidon—a',
#   'others.',
#   'scyros',
#   'icmalius',
#   'random',
#   'takest',
#   'shunned',
#   'exact',
#   'maimer',
#   'leiocritus',
#   'laertes.',
#   'booming',
#   'sway—young',
#   'outworn.',
#   'knewest',
#   'crosses',
#   'telemachus.',
#   'sight.',
#   'faultless',
#   'endure.',
#   'chins',
#   'side—even',
#   'challenges',
#   'doorpost',
#   'hall.',
#   'streamlet',
#   'pinning',
#   'dishes',
#   'choose.',
#   'tarriest',
#   'disquiet',
#   'feast-day',
#   'compassion.',
#   'begirt',
#   'drive—the',
#   'steered',
#   'close-fitting',
#   'fellow.',
#   'aphrodite.',
#   '”',
#   'one—for',
#   'boon—honor',
#   'simple-minded',
#   'pines',
#   'truth.',
#   'for.',
#   'business.',
#   'neion',
#   'gifted',
#   'beneath—a',
#   'levelled',
#   'chafing',
#   'hummed',
#   'crates',
#   'piling',
#   'hunger.',
#   'scathe',
#   'boors',
#   'beaters',
#   'odysseus.',
#   'waned',
#   'strowing',
#   'echoes',
#   'deed.',
#   'sand-spits',
#   'achaeans.',
#   'bronze—not',
#   'wouldest.',
#   'prayer.',
#   'home—even',
#   'torment',
#   'smear',
#   'trunk',
#   'finely-wrought',
#   'females',
#   'armour.',
#   'thought.',
#   'eurymedusa',
#   'stoutly-bound',
#   'stablish',
#   'anchored',
#   'racking',
#   'enjoyest',
#   'thee—the',
#   'prayed-for',
#   'vanish',
#   'harrows',
#   'people.',
#   'tame',
#   'touches',
#   'hurt.',
#   'encompass',
#   'spider-webs.',
#   'friends.',
#   'halls—two',
#   'gulp',
#   'wood.',
#   'merchantman',
#   'wets',
#   'aeaea',
#   'seamanship',
#   'child.',
#   'oversee',
#   'reproach.',
#   'devise.',
#   'cavernous',
#   'see.',
#   'strong.',
#   'autolycus.',
#   'desirest.',
#   'playthings',
#   'fore-deck',
#   'craftsmen',
#   'full.',
#   'show.',
#   'barely',
#   'telepylus',
#   'curve',
#   'ladder',
#   'bubble',
#   'doorway.',
#   'flaxen',
#   'archer-god',
#   'theoclymenus',
#   'southwest',
#   'honours',
#   'electrum',
#   'strangers—zeus',
#   'rolls',
#   'lapithae',
#   'nausithous',
#   'spinners',
#   'distributed',
#   'god—',
#   'distressed.',
#   'contriving',
#   'yearns',
#   'mates',
#   'deigns',
#   'coming.',
#   'mid-',
#   'unwinged',
#   'swamp-land',
#   'sorceress',
#   'few.',
#   'lading-plank',
#   'splitting',
#   '4',
#   'baffling',
#   'boards',
#   'signed',
#   'bed-post',
#   'hades.',
#   'cephallenians.',
#   'tempestuously',
#   'jet',
#   'uprightly.',
#   'unripe',
#   'erectheus',
#   'debating',
#   'quaffs',
#   'marriage—',
#   'scatters',
#   'girth',
#   'will—no',
#   'ilius',
#   'longs',
#   'throughly',
#   'dwelling—who',
#   'was—',
#   'unbroken—not',
#   'reply',
#   'talkest',
#   'newest',
#   'sweet-smelling',
#   'recounting',
#   'sleep.',
#   'perished—fools',
#   'seawater',
#   'rejoicing.',
#   'too.',
#   'drips',
#   'assails',
#   'time.',
#   'loosens',
#   'lost.',
#   'cyllenian',
#   'store-rooms',
#   'variance',
#   'doorposts',
#   'fair—so',
#   'ethiopians—the',
#   'clings',
#   'watched.',
#   'withal—that',
#   'forever',
#   'trim',
#   'scornfully',
#   'water—this',
#   'perils.',
#   'marvellously',
#   'continuously',
#   'mockery',
#   'store.',
#   'notes',
#   'pleasure.',
#   'unprofitably',
#   'strong-blowing',
#   'oftenest',
#   'belched',
#   'vigorous',
#   'together—even',
#   'harmest',
#   'overlays',
#   'traveller',
#   'unharassed',
#   'rebukes',
#   'melampus',
#   'shrivelling',
#   'ample',
#   'men—though',
#   'epeus',
#   'thereafter.',
#   'distance.',
#   'night.',
#   'dancing-floors',
#   'amnisus',
#   'supplies',
#   'troublous',
#   'quailest',
#   'comprehend',
#   'forgetting',
#   'hirelings',
#   'perforce.',
#   'be.',
#   'word.',
#   'long-leafed',
#   'dome',
#   'them—he',
#   'flask',
#   'closely-woven',
#   'aghast',
#   'farm—thy',
#   'honourest',
#   'carven',
#   'hiding-places',
#   'ferrymen',
#   'long-winged',
#   'heart—a',
#   'plain-told',
#   'invoke',
#   'freshly-washed',
#   'best.',
#   'hoes',
#   'crouni',
#   'invoice',
#   'whistling',
#   'far.',
#   '“',
#   'escapes',
#   'unfenced',
#   'mending',
#   'spins',
#   'outlying',
#   'calledst',
#   'popular',
#   'wares',
#   'flock.',
#   'ship-wrights',
#   'boom',
#   'wallet.',
#   'halls.',
#   'nectar.',
#   'persephone—',
#   'decisive',
#   'ivy',
#   'stratius',
#   'slight',
#   'pass.',
#   'obey.',
#   'scrapings',
#   'fuller',
#   'is—has',
#   'coping',
#   'overcast',
#   'acts',
#   'land.',
#   'day.',
#   'unmanned',
#   'unprovoked',
#   'drink.',
#   'besets',
#   'forestalled',
#   'naught—a',
#   'drowse',
#   'season.',
#   'gave.',
#   'upstretched',
#   'darken',
#   'seagirt',
#   'thought—i',
#   'irksome',
#   'unabashed',
#   'melanthius.',
#   'things.',
#   'jeered',
#   'whelp',
#   'close-fitted',
#   'unravelling',
#   'maidens.',
#   'dreams.',
#   'receives',
#   'far-wandering',
#   'deep.',
#   'water.',
#   'master.',
#   'surpasses',
#   'thwarting',
#   'oh',
#   'zeus.',
#   'brace',
#   'lessened',
#   'drifting',
#   'mills',
#   'feed.',
#   'times—and',
#   'desiring',
#   'erembi',
#   'spurned',
#   'eilithyia',
#   'livest',
#   'king.',
#   'ready.',
#   'joins',
#   'trot',
#   'couldest',
#   'entertainment.',
#   'grazing—all',
#   'equip',
#   'trimming',
#   'silenced',
#   'inextricable',
#   'stout-clawed',
#   'doors—straightway',
#   'phronius',
#   'gloves',
#   'babes',
#   'reeling',
#   'shrill-blowing',
#   'mouldering',
#   'sure.',
#   'meadow-land',
#   'pays',
#   'wroth.',
#   'bellies—then',
#   'secret.',
#   'thicket-lair',
#   'befit',
#   'turning-places',
#   'sea-mew',
#   'father—for',
#   'team',
#   'round-shouldered',
#   'purge',
#   'sore-tired',
#   'folly.',
#   'isle.',
#   'produces',
#   'minstrels.',
#   'goodly.',
#   'live.',
#   'afterward',
#   'swiftly-falling',
#   'borne—for',
#   'scurf',
#   'today',
#   'prompts',
#   'sicilians',
#   'roadstead',
#   'water-grass',
#   'apollo.',
#   'contrivings',
#   'footsteps.',
#   'thee—hounds',
#   'aegisthus',
#   'instilled',
#   ...}}

# %% [markdown]
# ## Your turn
#
# Now that you've seen the basics of TF-IDF, use the `set`s that we've built to explore the values for several terms in this corpus.
#
# As you explore, make note of any findings that seem odd — are they errors in how we have run the analysis, or is the text just weird?
#
# Consider, too, how you might improve the analysis in the future.
#
# Then in your own words, describe _what_ TF-IDF is really telling us about a given term in each text and within the corpus as a whole.
#
# Finally, think about other objects of study for which TF-IDF might be useful.

# %%
for first_file, first_set in non_universal_terms.items():
    for second_file, second_set in non_universal_terms.items():
        if first_file == second_file:
            continue
        intersection = first_set & second_set
        if intersection: 
            print(f"\n  Shared unique terms between {first_file} and {second_file}:")
            print(intersection)

# %%
for first_file, first_set in non_universal_terms.items():
    for second_file, second_set in non_universal_terms.items():
        if first_file == second_file:
            continue
        union = first_set or second_set
        if union: 
            print(f"\n  unique words in both {first_file} and {second_file}:")
            print(union)
# Out:
#   unique words in both tlg0012.tlg001.perseus-eng3.txt and tlg0012.tlg002.perseus-eng4.txt:
# {'onsets', 'embassage', 'maeonian', 'me—that', 'out-stretched', 'thea', 'buprasium', 'swiftships', 'river-bed', 'yoke-pad', 'soles', 'standest', 'isus', 'wide-scattered', 'blessings', 'marveling', '—that', 'amny', 'froma', 'saveth', 'polyidus', 'protesilaus', 'drinking-bouts', "ne'er", 'belloweth', '409.1', 'aepytus', 'strifes', 'bronze-harnessed', 'cymothoë', 'eared', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'bane—to', 'smitest', 'mischief—one', 'storm-footed', 'marking', 'sinketh', 'lycophron', 'choven', 'over-haughty', 'springeth', 'acessamenus', 'peace—yet', 'awaiteth', 'deemest', 'friendliness', 'dius', 'sullying', 'labouring', 'him—for', 'refreshing', 'calesius', '565.1', 'consolation', 'joineth', 'rivalry', 'falleth', 'ships—would', '159.1', 'avow', 'laodocus', 'serves', 'promptings', 'fie', 'horse-men', 'daetor', 'slaving', 'seemeth', 'podaleirius', 'casteth', 'cleaveth', 'gaped', 'fury-breathing', 'lyctus—for', 'shield-bearing', 'chicks', 'heside', 'closest', 'astyalus', 'vanquisheth', 'battlegear', 'displeasing', 'aepeia', 'rotteth', 'lustfulness', 'agastrophus', 'scandeia', 'unfed', 'tangle-strewn', 'valour', 'hips', 'ensigns', 'riseth', 'aenus', 'despiteful', 'digest', 'circleth', 'plaything', 'troes', 'forearm', 'sword—for', 'schedius', 'ten-fold', 'chanceth', '—hampered', 'affright', 'fore-most', '485.2', 'spurted', 'orphan', 'hippolochus', 'oversea', 'tartarus', 'swoopeth', 'sore-wearied', 'midmost', 'pillage', 'quelled', 'unprofitable', 'aegaeon', 'heed—', 'farm-stead', 'everywhither', 'thick-hidden', 'petted', 'muie', 'quaffest', 'entereth', 'evilly', 'screen', 'pedasus', 'laboureth', 'harvesttime', 'trickling', 'salt-sea', 'trace-horse', 'phylomedusa', 'fondled', 'oft', 'cypris', 'ganymedes', 'polymelus', '203.1', 'all-ensnaring', 'cyparisseïs', 'simois', 'stock.', 'gone—aye', 'cymindis', 'entering-in', 'vouch-safed', 'wile', 'achdeans', 'grovelled', 'arrogance', 'bearable', 'habitation', 'ranging', 'attiring', 'new-built', 'dint', 'tear-fraught', 'watchers', 'atreus—for', 'horses—the', 'pards', 'echecles', 'eateth', 'waxeth', 'decayeth', 'amphiclus', 'ca11ed', 'entreatment', 'aenius', 'swiftlier', 'seaboard', 'pursueth', 'men-at-arms', 'white-toothed', 'anvil-block', 'crutch', 'sthenelus', 'reproachfully', 'son—his', 'mountain-tops', 'deïcoön', 'sea-beach', 'agrius', 'woollen', 'whirleth', 'adread', 'lyrnessus', 'athrob', 'liveth', 'agamemon', 'sullen', 'bill', 'kinfolk', 'heaped-up', 'eumelas', 'hap', 'rosettes', 'cos.', 'thersilochus', 'floateth', 'bronze-greaved', 'feasteth', 'housefolk', '—whereas', 'ships—', 'glens', 'outstripped', 'water-snake', 'enfolding', 'bell-wether', 'putteth', 'ill-favoured', 'sea-waves', "where'er", 'rangeth', 'asian', 'sintian', 'urgest', 'palaces', 'shoutings', 'sinneth', 'recking', 'arraying', 'assuaging', 'sitteth', 'this—a', '515.1', 'betake', 'therethrough', 'hecamede', 'settest', 'eilithyiae', 'insults', 'keenest', 'peleus—in', 'trailed', 'turningpost', 'quenching', 'honses', 'fallest', 'clonius', 'bestirreth', 'ber', 'vaunteth', 'demesne-land', 'suffereth', 'polypoetes', 'vexing', 'fearsome', 'left—', 'me—and', 'polyaemon', 'dressing', 'fathec', 'spangled', 'sayeth', 'eleans', 'shieldmen', 'unspeakable—wolves', 'knight', 'glideth', 'coucheth', '11.1', 'swearing', 'telleth', 'dreams—for', 'dare—and', 'afresh', 'conceiveth', 'mustered', 'hah', 'mightier—', 'dismiss', 'dishonoured', 'trustest', 'haft', 'tarring', 'knees—apisaon', 'foolhardy', '55.1', '239.1', '47.1', 'wheeleth', 'bronze-hooved', 'seizeth', 'hector—for', 'hieth', '331.1', 'more—and', 'feil', 'mixingbowl', 'bronze-wrought', 'advance', 'leeches', 'antilochos', 'pathway', 'spewing', '327.1', 'long-edged', 'taiaemenes', 'thoë', 'joyeth', 'bubbleth', '271.1', 'overturn', 'foe-men', 'evenus', 'gat', 'assuaged', 'concord', 'condemn', 'puffing', 'staineth', 'nastes—nastes', 'eüssorus', 'presumptuous', 'thereunder', 'dismount', 'cringed', 'rods', 'singers', 'fir-tree', 'scamandrius', 'all-nurturing' ...
#
#   unique words in both tlg0012.tlg001.perseus-eng3.txt and tlg0012.tlg001.perseus-eng4.txt:
# {'onsets', 'embassage', 'maeonian', 'me—that', 'out-stretched', 'thea', 'buprasium', 'swiftships', 'river-bed', 'yoke-pad', 'soles', 'standest', 'isus', 'wide-scattered', 'blessings', 'marveling', '—that', 'amny', 'froma', 'saveth', 'polyidus', 'protesilaus', 'drinking-bouts', "ne'er", 'belloweth', '409.1', 'aepytus', 'strifes', 'bronze-harnessed', 'cymothoë', 'eared', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'bane—to', 'smitest', 'mischief—one', 'storm-footed', 'marking', 'sinketh', 'lycophron', 'choven', 'over-haughty', 'springeth', 'acessamenus', 'peace—yet', 'awaiteth', 'deemest', 'friendliness', 'dius', 'sullying', 'labouring', 'him—for', 'refreshing', 'calesius', '565.1', 'consolation', 'joineth', 'rivalry', 'falleth', 'ships—would', '159.1', 'avow', 'laodocus', 'serves', 'promptings', 'fie', 'horse-men', 'daetor', 'slaving', 'seemeth', 'podaleirius', 'casteth', 'cleaveth', 'gaped', 'fury-breathing', 'lyctus—for', 'shield-bearing', 'chicks', 'heside', 'closest', 'astyalus', 'vanquisheth', 'battlegear', 'displeasing', 'aepeia', 'rotteth', 'lustfulness', 'agastrophus', 'scandeia', 'unfed', 'tangle-strewn', 'valour', 'hips', 'ensigns', 'riseth', 'aenus', 'despiteful', 'digest', 'circleth', 'plaything', 'troes', 'forearm', 'sword—for', 'schedius', 'ten-fold', 'chanceth', '—hampered', 'affright', 'fore-most', '485.2', 'spurted', 'orphan', 'hippolochus', 'oversea', 'tartarus', 'swoopeth', 'sore-wearied', 'midmost', 'pillage', 'quelled', 'unprofitable', 'aegaeon', 'heed—', 'farm-stead', 'everywhither', 'thick-hidden', 'petted', 'muie', 'quaffest', 'entereth', 'evilly', 'screen', 'pedasus', 'laboureth', 'harvesttime', 'trickling', 'salt-sea', 'trace-horse', 'phylomedusa', 'fondled', 'oft', 'cypris', 'ganymedes', 'polymelus', '203.1', 'all-ensnaring', 'cyparisseïs', 'simois', 'stock.', 'gone—aye', 'cymindis', 'entering-in', 'vouch-safed', 'wile', 'achdeans', 'grovelled', 'arrogance', 'bearable', 'habitation', 'ranging', 'attiring', 'new-built', 'dint', 'tear-fraught', 'watchers', 'atreus—for', 'horses—the', 'pards', 'echecles', 'eateth', 'waxeth', 'decayeth', 'amphiclus', 'ca11ed', 'entreatment', 'aenius', 'swiftlier', 'seaboard', 'pursueth', 'men-at-arms', 'white-toothed', 'anvil-block', 'crutch', 'sthenelus', 'reproachfully', 'son—his', 'mountain-tops', 'deïcoön', 'sea-beach', 'agrius', 'woollen', 'whirleth', 'adread', 'lyrnessus', 'athrob', 'liveth', 'agamemon', 'sullen', 'bill', 'kinfolk', 'heaped-up', 'eumelas', 'hap', 'rosettes', 'cos.', 'thersilochus', 'floateth', 'bronze-greaved', 'feasteth', 'housefolk', '—whereas', 'ships—', 'glens', 'outstripped', 'water-snake', 'enfolding', 'bell-wether', 'putteth', 'ill-favoured', 'sea-waves', "where'er", 'rangeth', 'asian', 'sintian', 'urgest', 'palaces', 'shoutings', 'sinneth', 'recking', 'arraying', 'assuaging', 'sitteth', 'this—a', '515.1', 'betake', 'therethrough', 'hecamede', 'settest', 'eilithyiae', 'insults', 'keenest', 'peleus—in', 'trailed', 'turningpost', 'quenching', 'honses', 'fallest', 'clonius', 'bestirreth', 'ber', 'vaunteth', 'demesne-land', 'suffereth', 'polypoetes', 'vexing', 'fearsome', 'left—', 'me—and', 'polyaemon', 'dressing', 'fathec', 'spangled', 'sayeth', 'eleans', 'shieldmen', 'unspeakable—wolves', 'knight', 'glideth', 'coucheth', '11.1', 'swearing', 'telleth', 'dreams—for', 'dare—and', 'afresh', 'conceiveth', 'mustered', 'hah', 'mightier—', 'dismiss', 'dishonoured', 'trustest', 'haft', 'tarring', 'knees—apisaon', 'foolhardy', '55.1', '239.1', '47.1', 'wheeleth', 'bronze-hooved', 'seizeth', 'hector—for', 'hieth', '331.1', 'more—and', 'feil', 'mixingbowl', 'bronze-wrought', 'advance', 'leeches', 'antilochos', 'pathway', 'spewing', '327.1', 'long-edged', 'taiaemenes', 'thoë', 'joyeth', 'bubbleth', '271.1', 'overturn', 'foe-men', 'evenus', 'gat', 'assuaged', 'concord', 'condemn', 'puffing', 'staineth', 'nastes—nastes', 'eüssorus', 'presumptuous', 'thereunder', 'dismount', 'cringed', 'rods', 'singers', 'fir-tree', 'scamandrius', 'all-nurturing' ...
#
#   unique words in both tlg0012.tlg001.perseus-eng3.txt and tlg0012.tlg002.perseus-eng3.txt:
# {'onsets', 'embassage', 'maeonian', 'me—that', 'out-stretched', 'thea', 'buprasium', 'swiftships', 'river-bed', 'yoke-pad', 'soles', 'standest', 'isus', 'wide-scattered', 'blessings', 'marveling', '—that', 'amny', 'froma', 'saveth', 'polyidus', 'protesilaus', 'drinking-bouts', "ne'er", 'belloweth', '409.1', 'aepytus', 'strifes', 'bronze-harnessed', 'cymothoë', 'eared', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'bane—to', 'smitest', 'mischief—one', 'storm-footed', 'marking', 'sinketh', 'lycophron', 'choven', 'over-haughty', 'springeth', 'acessamenus', 'peace—yet', 'awaiteth', 'deemest', 'friendliness', 'dius', 'sullying', 'labouring', 'him—for', 'refreshing', 'calesius', '565.1', 'consolation', 'joineth', 'rivalry', 'falleth', 'ships—would', '159.1', 'avow', 'laodocus', 'serves', 'promptings', 'fie', 'horse-men', 'daetor', 'slaving', 'seemeth', 'podaleirius', 'casteth', 'cleaveth', 'gaped', 'fury-breathing', 'lyctus—for', 'shield-bearing', 'chicks', 'heside', 'closest', 'astyalus', 'vanquisheth', 'battlegear', 'displeasing', 'aepeia', 'rotteth', 'lustfulness', 'agastrophus', 'scandeia', 'unfed', 'tangle-strewn', 'valour', 'hips', 'ensigns', 'riseth', 'aenus', 'despiteful', 'digest', 'circleth', 'plaything', 'troes', 'forearm', 'sword—for', 'schedius', 'ten-fold', 'chanceth', '—hampered', 'affright', 'fore-most', '485.2', 'spurted', 'orphan', 'hippolochus', 'oversea', 'tartarus', 'swoopeth', 'sore-wearied', 'midmost', 'pillage', 'quelled', 'unprofitable', 'aegaeon', 'heed—', 'farm-stead', 'everywhither', 'thick-hidden', 'petted', 'muie', 'quaffest', 'entereth', 'evilly', 'screen', 'pedasus', 'laboureth', 'harvesttime', 'trickling', 'salt-sea', 'trace-horse', 'phylomedusa', 'fondled', 'oft', 'cypris', 'ganymedes', 'polymelus', '203.1', 'all-ensnaring', 'cyparisseïs', 'simois', 'stock.', 'gone—aye', 'cymindis', 'entering-in', 'vouch-safed', 'wile', 'achdeans', 'grovelled', 'arrogance', 'bearable', 'habitation', 'ranging', 'attiring', 'new-built', 'dint', 'tear-fraught', 'watchers', 'atreus—for', 'horses—the', 'pards', 'echecles', 'eateth', 'waxeth', 'decayeth', 'amphiclus', 'ca11ed', 'entreatment', 'aenius', 'swiftlier', 'seaboard', 'pursueth', 'men-at-arms', 'white-toothed', 'anvil-block', 'crutch', 'sthenelus', 'reproachfully', 'son—his', 'mountain-tops', 'deïcoön', 'sea-beach', 'agrius', 'woollen', 'whirleth', 'adread', 'lyrnessus', 'athrob', 'liveth', 'agamemon', 'sullen', 'bill', 'kinfolk', 'heaped-up', 'eumelas', 'hap', 'rosettes', 'cos.', 'thersilochus', 'floateth', 'bronze-greaved', 'feasteth', 'housefolk', '—whereas', 'ships—', 'glens', 'outstripped', 'water-snake', 'enfolding', 'bell-wether', 'putteth', 'ill-favoured', 'sea-waves', "where'er", 'rangeth', 'asian', 'sintian', 'urgest', 'palaces', 'shoutings', 'sinneth', 'recking', 'arraying', 'assuaging', 'sitteth', 'this—a', '515.1', 'betake', 'therethrough', 'hecamede', 'settest', 'eilithyiae', 'insults', 'keenest', 'peleus—in', 'trailed', 'turningpost', 'quenching', 'honses', 'fallest', 'clonius', 'bestirreth', 'ber', 'vaunteth', 'demesne-land', 'suffereth', 'polypoetes', 'vexing', 'fearsome', 'left—', 'me—and', 'polyaemon', 'dressing', 'fathec', 'spangled', 'sayeth', 'eleans', 'shieldmen', 'unspeakable—wolves', 'knight', 'glideth', 'coucheth', '11.1', 'swearing', 'telleth', 'dreams—for', 'dare—and', 'afresh', 'conceiveth', 'mustered', 'hah', 'mightier—', 'dismiss', 'dishonoured', 'trustest', 'haft', 'tarring', 'knees—apisaon', 'foolhardy', '55.1', '239.1', '47.1', 'wheeleth', 'bronze-hooved', 'seizeth', 'hector—for', 'hieth', '331.1', 'more—and', 'feil', 'mixingbowl', 'bronze-wrought', 'advance', 'leeches', 'antilochos', 'pathway', 'spewing', '327.1', 'long-edged', 'taiaemenes', 'thoë', 'joyeth', 'bubbleth', '271.1', 'overturn', 'foe-men', 'evenus', 'gat', 'assuaged', 'concord', 'condemn', 'puffing', 'staineth', 'nastes—nastes', 'eüssorus', 'presumptuous', 'thereunder', 'dismount', 'cringed', 'rods', 'singers', 'fir-tree', 'scamandrius', 'all-nurturing' ...
#
#   unique words in both tlg0012.tlg002.perseus-eng4.txt and tlg0012.tlg001.perseus-eng3.txt:
# {'brush-wood', 'teaches', 'okyalos', 'independent', 'turned.', 'fifty-two', 'market', 'feather', 'waking', 'conferred', 'valuable', 'impulse', 'unpick', 'lively', 'disfigure', 'misconduct', 'ducts', 'scenes', 'yours.', 'vested', 'groove', 'drenching', 'refitting', 'reasonably', 'scolding', 'pyriphlegethon', 'blessedness', 'remarks', 'sidonia', 'shifted', 'verbal', 'leda', 'iros', 'seal', 'vassal', 'regained', 'apartment', 'perfidy', 'well-disposed', 'polite', 'volunteers', 'nausithoos', 'heinous', 'wink', 'distress.', 'scarred', 'behavior', 'insulting', 'interrupted', 'admittance', 'valuables', 'poorer', 'tidy', 'thawed', 'well-found', 'infinity', 'pits', 'credit', 'fretting', 'raven', 'freights', 'instinct', 'cooking', 'unpropitious', 'doubling', 'zethos', 'frightful', 'ghost', 'trees.', 'broken-hearted', 'kreon', 'assure', 'square', 'enchantments', 'supersede', 'cechalian-', 'casks', 'hoeing', 'loading', 'coast', 'acceptance', 'fort', 'polyneos', 'peopled', 'resuming', 'examined', 'maidservant', 'originally', 'importunity', 'uncivilized', 'misconducted', 'schemer', 'crossbeams', 'encouragingly', 'sufficient', 'import', 'provisioned', 'gold-enthroned', 'congratulate', 'lavishly', 'washing-cisterns', 'reflected', 'agreeable', 'gibes', 'dangerously', 'muttering', 'pestering', 'halosydne', 'festivities', 'courting', 'sailor', 'forceful', 'score', 'jumpers', 'aurora', 'bedside', 'torch-light', 'lend', 'fuller-handed', 'sea-', 'tour', 'meat-basket', 'becalmed', 'flatter', 'mistrust', 'ogygian.', 'schemes', 'dispute', 'curly', 'jumped', 'patron', 'boil', 'exhausted', 'antagonist', 'freemen', 'chopping', 'still.', 'compel', 'unblended', 'dresser', 'propitiation', 'soot', 'swindler', 'horizon', 'staid', 'humbly', 'damask', 'nêpenthes', 'scolded', 'festooned', 'thunder-bolts', 'prison', 'shoals', 'interesting', 'behave', 'arranged', 'severe', 'ekhthron', 'lodging', 'undergoing', 'moodily', 'girds', 'luxury', 'islet', 'inhuman', 'series', 'outhouses', 'claws', 'leveled', 'excellently', 'overflow', 'crime', 'howling', 'recalling', 'fraud', 'fancies', 'wrinkles', 'painlessly', 'appalling', 'loveliness', 'hemming', 'illustrious', 'crunch', 'bards', 'hatchet', 'invent', 'ensconced', 'adventures', 'picking', '-for', 'gull', 'aigyptios', 'result', 'object', 'banqueting', 'supposing', 'cleanses', 'recoup', 'crop', 'evidently', 'ripens', 'dry-rotted', 'inextinguishable', 'surf-beaten', 'tricky', 'ripping', 'demoptolemos', 'gilding', 'detain', 'well-ripened', '-but', 'unfortunate', 'lamos', 'actually', 'nudged', 'glide', 'kisses', 'ismaros', 'mesaulios', 'fishy', 'consciences', 'ordeals', 'ill-natured', 'crew.', 'nations', 'sweetmeats', 'sportsmen', 'succession', 'persons', 'soften', 'adored', 'sunrise', 'hereabouts', 'magician', 'miscreants', 'amount', 'tallied', 'charming', 'visitors', 'seagulls', 'calamities', 'thrives', 'religious', 'sweethearts', 'injury', 'house-keeper', 'no-good', 'coxswain', 'assures', 'artisans', 'diverted', 'poets', 'close-in', 'amnisos', 'apprehend', 'humming', 'aimlessly.', 'rigorously', 'swooning', 'magnificently', 'conversing', 'alkippe', 'bread-basket', 'eurymos', 'frustrate', 'intention', 'disturbed', 'horrible', 'boatmen', 'rekindle', 'alektor', 'unwaked', 'travels', 'itylos', 'rude', 'nobly', 'petition', 'intends', 'clapping', 'reclined', 'decently', 'bedroom', 'gourmet', 'henchmen', 'persist', 'fireside', 'victuals', 'savory', 'shamefaced', 'people-', 'extra', 'rascal', 'stratios', 'hearers', 'unharnessed', 'forge', 'modest', 'hurdles', 'neat', 'goddess.', 'whirlwinds', 'seethed', 'figures', 'caring', 'infamy', 'inconvenience', 'gloomy', 'horseback', 'usual', 'wooer', 'fret', 'cattle-lifting', 'shambles', 'frugal', 'cloisters', 'grassed', 'aware', 'enforce', 'once.', 'deliberately', 'contended', 'exterminate', 'dresses', 'lifts', 'travelers', 'select', 'accordingly', 'noised', 'amphialos', 'obstacles', 'simple', 'limp', 'cleaned', 'clamorous', 'dozen', 'cobwebs', 'cargoes', 'replenishing', 'repeat', 'netted', ...
#
#   unique words in both tlg0012.tlg002.perseus-eng4.txt and tlg0012.tlg001.perseus-eng4.txt:
# {'brush-wood', 'teaches', 'okyalos', 'independent', 'turned.', 'fifty-two', 'market', 'feather', 'waking', 'conferred', 'valuable', 'impulse', 'unpick', 'lively', 'disfigure', 'misconduct', 'ducts', 'scenes', 'yours.', 'vested', 'groove', 'drenching', 'refitting', 'reasonably', 'scolding', 'pyriphlegethon', 'blessedness', 'remarks', 'sidonia', 'shifted', 'verbal', 'leda', 'iros', 'seal', 'vassal', 'regained', 'apartment', 'perfidy', 'well-disposed', 'polite', 'volunteers', 'nausithoos', 'heinous', 'wink', 'distress.', 'scarred', 'behavior', 'insulting', 'interrupted', 'admittance', 'valuables', 'poorer', 'tidy', 'thawed', 'well-found', 'infinity', 'pits', 'credit', 'fretting', 'raven', 'freights', 'instinct', 'cooking', 'unpropitious', 'doubling', 'zethos', 'frightful', 'ghost', 'trees.', 'broken-hearted', 'kreon', 'assure', 'square', 'enchantments', 'supersede', 'cechalian-', 'casks', 'hoeing', 'loading', 'coast', 'acceptance', 'fort', 'polyneos', 'peopled', 'resuming', 'examined', 'maidservant', 'originally', 'importunity', 'uncivilized', 'misconducted', 'schemer', 'crossbeams', 'encouragingly', 'sufficient', 'import', 'provisioned', 'gold-enthroned', 'congratulate', 'lavishly', 'washing-cisterns', 'reflected', 'agreeable', 'gibes', 'dangerously', 'muttering', 'pestering', 'halosydne', 'festivities', 'courting', 'sailor', 'forceful', 'score', 'jumpers', 'aurora', 'bedside', 'torch-light', 'lend', 'fuller-handed', 'sea-', 'tour', 'meat-basket', 'becalmed', 'flatter', 'mistrust', 'ogygian.', 'schemes', 'dispute', 'curly', 'jumped', 'patron', 'boil', 'exhausted', 'antagonist', 'freemen', 'chopping', 'still.', 'compel', 'unblended', 'dresser', 'propitiation', 'soot', 'swindler', 'horizon', 'staid', 'humbly', 'damask', 'nêpenthes', 'scolded', 'festooned', 'thunder-bolts', 'prison', 'shoals', 'interesting', 'behave', 'arranged', 'severe', 'ekhthron', 'lodging', 'undergoing', 'moodily', 'girds', 'luxury', 'islet', 'inhuman', 'series', 'outhouses', 'claws', 'leveled', 'excellently', 'overflow', 'crime', 'howling', 'recalling', 'fraud', 'fancies', 'wrinkles', 'painlessly', 'appalling', 'loveliness', 'hemming', 'illustrious', 'crunch', 'bards', 'hatchet', 'invent', 'ensconced', 'adventures', 'picking', '-for', 'gull', 'aigyptios', 'result', 'object', 'banqueting', 'supposing', 'cleanses', 'recoup', 'crop', 'evidently', 'ripens', 'dry-rotted', 'inextinguishable', 'surf-beaten', 'tricky', 'ripping', 'demoptolemos', 'gilding', 'detain', 'well-ripened', '-but', 'unfortunate', 'lamos', 'actually', 'nudged', 'glide', 'kisses', 'ismaros', 'mesaulios', 'fishy', 'consciences', 'ordeals', 'ill-natured', 'crew.', 'nations', 'sweetmeats', 'sportsmen', 'succession', 'persons', 'soften', 'adored', 'sunrise', 'hereabouts', 'magician', 'miscreants', 'amount', 'tallied', 'charming', 'visitors', 'seagulls', 'calamities', 'thrives', 'religious', 'sweethearts', 'injury', 'house-keeper', 'no-good', 'coxswain', 'assures', 'artisans', 'diverted', 'poets', 'close-in', 'amnisos', 'apprehend', 'humming', 'aimlessly.', 'rigorously', 'swooning', 'magnificently', 'conversing', 'alkippe', 'bread-basket', 'eurymos', 'frustrate', 'intention', 'disturbed', 'horrible', 'boatmen', 'rekindle', 'alektor', 'unwaked', 'travels', 'itylos', 'rude', 'nobly', 'petition', 'intends', 'clapping', 'reclined', 'decently', 'bedroom', 'gourmet', 'henchmen', 'persist', 'fireside', 'victuals', 'savory', 'shamefaced', 'people-', 'extra', 'rascal', 'stratios', 'hearers', 'unharnessed', 'forge', 'modest', 'hurdles', 'neat', 'goddess.', 'whirlwinds', 'seethed', 'figures', 'caring', 'infamy', 'inconvenience', 'gloomy', 'horseback', 'usual', 'wooer', 'fret', 'cattle-lifting', 'shambles', 'frugal', 'cloisters', 'grassed', 'aware', 'enforce', 'once.', 'deliberately', 'contended', 'exterminate', 'dresses', 'lifts', 'travelers', 'select', 'accordingly', 'noised', 'amphialos', 'obstacles', 'simple', 'limp', 'cleaned', 'clamorous', 'dozen', 'cobwebs', 'cargoes', 'replenishing', 'repeat', 'netted', ...
#
#   unique words in both tlg0012.tlg002.perseus-eng4.txt and tlg0012.tlg002.perseus-eng3.txt:
# {'brush-wood', 'teaches', 'okyalos', 'independent', 'turned.', 'fifty-two', 'market', 'feather', 'waking', 'conferred', 'valuable', 'impulse', 'unpick', 'lively', 'disfigure', 'misconduct', 'ducts', 'scenes', 'yours.', 'vested', 'groove', 'drenching', 'refitting', 'reasonably', 'scolding', 'pyriphlegethon', 'blessedness', 'remarks', 'sidonia', 'shifted', 'verbal', 'leda', 'iros', 'seal', 'vassal', 'regained', 'apartment', 'perfidy', 'well-disposed', 'polite', 'volunteers', 'nausithoos', 'heinous', 'wink', 'distress.', 'scarred', 'behavior', 'insulting', 'interrupted', 'admittance', 'valuables', 'poorer', 'tidy', 'thawed', 'well-found', 'infinity', 'pits', 'credit', 'fretting', 'raven', 'freights', 'instinct', 'cooking', 'unpropitious', 'doubling', 'zethos', 'frightful', 'ghost', 'trees.', 'broken-hearted', 'kreon', 'assure', 'square', 'enchantments', 'supersede', 'cechalian-', 'casks', 'hoeing', 'loading', 'coast', 'acceptance', 'fort', 'polyneos', 'peopled', 'resuming', 'examined', 'maidservant', 'originally', 'importunity', 'uncivilized', 'misconducted', 'schemer', 'crossbeams', 'encouragingly', 'sufficient', 'import', 'provisioned', 'gold-enthroned', 'congratulate', 'lavishly', 'washing-cisterns', 'reflected', 'agreeable', 'gibes', 'dangerously', 'muttering', 'pestering', 'halosydne', 'festivities', 'courting', 'sailor', 'forceful', 'score', 'jumpers', 'aurora', 'bedside', 'torch-light', 'lend', 'fuller-handed', 'sea-', 'tour', 'meat-basket', 'becalmed', 'flatter', 'mistrust', 'ogygian.', 'schemes', 'dispute', 'curly', 'jumped', 'patron', 'boil', 'exhausted', 'antagonist', 'freemen', 'chopping', 'still.', 'compel', 'unblended', 'dresser', 'propitiation', 'soot', 'swindler', 'horizon', 'staid', 'humbly', 'damask', 'nêpenthes', 'scolded', 'festooned', 'thunder-bolts', 'prison', 'shoals', 'interesting', 'behave', 'arranged', 'severe', 'ekhthron', 'lodging', 'undergoing', 'moodily', 'girds', 'luxury', 'islet', 'inhuman', 'series', 'outhouses', 'claws', 'leveled', 'excellently', 'overflow', 'crime', 'howling', 'recalling', 'fraud', 'fancies', 'wrinkles', 'painlessly', 'appalling', 'loveliness', 'hemming', 'illustrious', 'crunch', 'bards', 'hatchet', 'invent', 'ensconced', 'adventures', 'picking', '-for', 'gull', 'aigyptios', 'result', 'object', 'banqueting', 'supposing', 'cleanses', 'recoup', 'crop', 'evidently', 'ripens', 'dry-rotted', 'inextinguishable', 'surf-beaten', 'tricky', 'ripping', 'demoptolemos', 'gilding', 'detain', 'well-ripened', '-but', 'unfortunate', 'lamos', 'actually', 'nudged', 'glide', 'kisses', 'ismaros', 'mesaulios', 'fishy', 'consciences', 'ordeals', 'ill-natured', 'crew.', 'nations', 'sweetmeats', 'sportsmen', 'succession', 'persons', 'soften', 'adored', 'sunrise', 'hereabouts', 'magician', 'miscreants', 'amount', 'tallied', 'charming', 'visitors', 'seagulls', 'calamities', 'thrives', 'religious', 'sweethearts', 'injury', 'house-keeper', 'no-good', 'coxswain', 'assures', 'artisans', 'diverted', 'poets', 'close-in', 'amnisos', 'apprehend', 'humming', 'aimlessly.', 'rigorously', 'swooning', 'magnificently', 'conversing', 'alkippe', 'bread-basket', 'eurymos', 'frustrate', 'intention', 'disturbed', 'horrible', 'boatmen', 'rekindle', 'alektor', 'unwaked', 'travels', 'itylos', 'rude', 'nobly', 'petition', 'intends', 'clapping', 'reclined', 'decently', 'bedroom', 'gourmet', 'henchmen', 'persist', 'fireside', 'victuals', 'savory', 'shamefaced', 'people-', 'extra', 'rascal', 'stratios', 'hearers', 'unharnessed', 'forge', 'modest', 'hurdles', 'neat', 'goddess.', 'whirlwinds', 'seethed', 'figures', 'caring', 'infamy', 'inconvenience', 'gloomy', 'horseback', 'usual', 'wooer', 'fret', 'cattle-lifting', 'shambles', 'frugal', 'cloisters', 'grassed', 'aware', 'enforce', 'once.', 'deliberately', 'contended', 'exterminate', 'dresses', 'lifts', 'travelers', 'select', 'accordingly', 'noised', 'amphialos', 'obstacles', 'simple', 'limp', 'cleaned', 'clamorous', 'dozen', 'cobwebs', 'cargoes', 'replenishing', 'repeat', 'netted', ...
#
#   unique words in both tlg0012.tlg001.perseus-eng4.txt and tlg0012.tlg001.perseus-eng3.txt:
# {'hippomakhos', 'stave', 'gaping', 'mountain-track', 'penalties', 'boons', 'duck', 'urgent', 'pall', 'quickest', 'roses', 'doting', 'cushion', 'misgiving', 'crystal', 'wronging', 'surpassing', 'steeled', 'mown', 'quailing', 'phylomedousa', 'wounding', 'file', 'kteatos', 'eionae', 'astypylos', 'dispatched', 'truer', 'exults', 'councilor', 'thicker', 'tricked', 'ablaze-', 'well-nigh', 'rock-perched', 'householders', 'alêthea', 'echios', 'succor', 'groanful', 'daintiest', 'full-speed', 'sallies', 'lost-', 'yoking', 'decrees', 'branching', 'vaunts', 'bondswomen', 'contradicts', 'spercheios', 'collar-bones', 'stated', 'menaces', 'lowed', 'attire', 'asaios', 'carelessness', 'northwest', 'top-rail', 'weddings', 'depended', 'helter-skelter', 'calmed', 'axes-', 'bystanders', 'decoyed', 'skirted', 'implanted', 'smashing', 'foolishness', 'enjoyment', 'unkindness', 'echeklos', 'waterside', 'train', 'entrapping', 'right-hand', 'unnerved', 'amphoteros', 'linus-song', 'bronzed', 'continuous', 'amphigenea', 'thickens', 'offend', 'spearsmen', 'feeblest', 'stunned', 'universal', 'chattel', 'thatched', 'echekles', 'demands', 'whisks', 'unmolested', 'bestrewn', 'openmouthed', 'levying', 'wheel-marks', 'persisted', 'crushing', 'cue', 'examine', 'goat-herd', 'ephyroi', 'bud', 'routs', 'arm-rods', 'resolutely', 'nay-', 'likymnios', 'exhort', 'death-throes', 'awe-struck', 'anew', 'moaned', 'half-circle', 'slinks', 'fledglings', 'zelea', 'ebbed', 'player', 'drowsy', 'intervals', 'masonry', 'ekhepolos', 'agakles', 'plays', 'smooth-tongued', 'dales', 'askanios', 'quoit', 'ferret-skin', 'gale-', 'gainsaid', 'untied', 'spear-wound', 'boxwood', 'preceding', 'eyed', 'reaped', 'washing-troughs', 'thrash', 'echinean', 'suffice', 'twisting', 'foundation', 'minyas', 'movement', 'wolf-skin', 'remorse', 'menesthios', 'women-servants', 'notify', 'flashes', 'judging', 'slanderer', 'panoply', 'induce', 'suggestions', 'steward', 'searches', 'argument', 'triple-barbed', 'unrighteous', 'pyraikhmes', 'punishing', 'meteor', 'sounder', 'fervently', 'eussoros', 'exchanged', 'cataract', 'cleaver', 'sheep-yard', 'kaletor', 'hip-joint', 'gamboling', 'ennomos', 'oreithuia', 'dardanos', 'thersilokhos', 'gorgeous', 'sceptered', 'texture', 'butts', 'rhigmos', 'kinship', 'ankaios', 'calamity', 'clip', 'furnace', 'limpid', 'unplundered', 'severs', 'nestlings', 'buffeting', 'recruit', 'never-ending', 'buds', 'deliberation', 'eteokles', 'effaced', 'laerkes', 'parch', 'hyrtios', 'stickle', 'stymphelus', 'curbed', 'fickle', 'lure', 'sadness', 'polyxenos', 'hippokoön', 'opportunely', 'compassionately', 'wine-cup', 'perea', 'grimy', 'serviceable', 'overjoyed', 'wields', 'sedition', 'unforgiving', 'parleying', 'fee', 'koön', 'hobbled', 'dagger', 'dikes', 'shaped', 'unsoiled', 'timê', 'limped', 'silver-eddying', 'iaira', 'retreat', 'hesitate', 'indulge', 'veering', 'partaking', 'tow', 'ajaxes', 'swerves', 'wriggled', 'overleap', 'delicacy', 'inviolate', 'fittest', 'tasseled', 'sea-fight', 'marshy', 'fangs', 'groveled', 'sword-wounds', 'minyeios', 'amisodoros', 'disdaining', 'sighed', 'bawling', 'dissuaded', 'aesopos', 'tlepolemos', 'archilokhos', 'limnorea', 'violate', 'golden-haired', 'mnesos', 'ikarian', 'tusked', 'hektor', 'particular', 'head-strong', 'nestled', 'robbing', 'boagrios', 'afford', 'porridge', 'atymnios', 'unloosed', 'tumbling', 'areilykos', 'kicks', 'arriving', 'bright-', 'mete', 'gatemen', 'another-', 'totally', 'elm-tree', 'biggest', 'indifferent', 'plenitude', 'meddle', 'lykastos', 'disquietness', 'glories', 'dejected', 'gravest', 'infirmities', 'lyktos', 'askalaphos', 'ambush-', 'uppermost', 'hammering', 'filly', 'precise', 'jeopardy', 'tuft', 'halcyon', 'erylaos', 'task-master', 'yawned', 'ialmenos', 'grain-growing', 'sift', 'divinity', 'aisyetes', 'leitos', 'aithe', 'cyparisseis', 'bronze-headed', 'concert', 'spearsman', 'impart', 'nerve', 'establishing', 'peeping', 'trice', 'thalia', 'portentous', 'extent', 'spade', 'cracked', 'baned', 'melting', 'thebaios', 'zeus-d ...
#
#   unique words in both tlg0012.tlg001.perseus-eng4.txt and tlg0012.tlg002.perseus-eng4.txt:
# {'hippomakhos', 'stave', 'gaping', 'mountain-track', 'penalties', 'boons', 'duck', 'urgent', 'pall', 'quickest', 'roses', 'doting', 'cushion', 'misgiving', 'crystal', 'wronging', 'surpassing', 'steeled', 'mown', 'quailing', 'phylomedousa', 'wounding', 'file', 'kteatos', 'eionae', 'astypylos', 'dispatched', 'truer', 'exults', 'councilor', 'thicker', 'tricked', 'ablaze-', 'well-nigh', 'rock-perched', 'householders', 'alêthea', 'echios', 'succor', 'groanful', 'daintiest', 'full-speed', 'sallies', 'lost-', 'yoking', 'decrees', 'branching', 'vaunts', 'bondswomen', 'contradicts', 'spercheios', 'collar-bones', 'stated', 'menaces', 'lowed', 'attire', 'asaios', 'carelessness', 'northwest', 'top-rail', 'weddings', 'depended', 'helter-skelter', 'calmed', 'axes-', 'bystanders', 'decoyed', 'skirted', 'implanted', 'smashing', 'foolishness', 'enjoyment', 'unkindness', 'echeklos', 'waterside', 'train', 'entrapping', 'right-hand', 'unnerved', 'amphoteros', 'linus-song', 'bronzed', 'continuous', 'amphigenea', 'thickens', 'offend', 'spearsmen', 'feeblest', 'stunned', 'universal', 'chattel', 'thatched', 'echekles', 'demands', 'whisks', 'unmolested', 'bestrewn', 'openmouthed', 'levying', 'wheel-marks', 'persisted', 'crushing', 'cue', 'examine', 'goat-herd', 'ephyroi', 'bud', 'routs', 'arm-rods', 'resolutely', 'nay-', 'likymnios', 'exhort', 'death-throes', 'awe-struck', 'anew', 'moaned', 'half-circle', 'slinks', 'fledglings', 'zelea', 'ebbed', 'player', 'drowsy', 'intervals', 'masonry', 'ekhepolos', 'agakles', 'plays', 'smooth-tongued', 'dales', 'askanios', 'quoit', 'ferret-skin', 'gale-', 'gainsaid', 'untied', 'spear-wound', 'boxwood', 'preceding', 'eyed', 'reaped', 'washing-troughs', 'thrash', 'echinean', 'suffice', 'twisting', 'foundation', 'minyas', 'movement', 'wolf-skin', 'remorse', 'menesthios', 'women-servants', 'notify', 'flashes', 'judging', 'slanderer', 'panoply', 'induce', 'suggestions', 'steward', 'searches', 'argument', 'triple-barbed', 'unrighteous', 'pyraikhmes', 'punishing', 'meteor', 'sounder', 'fervently', 'eussoros', 'exchanged', 'cataract', 'cleaver', 'sheep-yard', 'kaletor', 'hip-joint', 'gamboling', 'ennomos', 'oreithuia', 'dardanos', 'thersilokhos', 'gorgeous', 'sceptered', 'texture', 'butts', 'rhigmos', 'kinship', 'ankaios', 'calamity', 'clip', 'furnace', 'limpid', 'unplundered', 'severs', 'nestlings', 'buffeting', 'recruit', 'never-ending', 'buds', 'deliberation', 'eteokles', 'effaced', 'laerkes', 'parch', 'hyrtios', 'stickle', 'stymphelus', 'curbed', 'fickle', 'lure', 'sadness', 'polyxenos', 'hippokoön', 'opportunely', 'compassionately', 'wine-cup', 'perea', 'grimy', 'serviceable', 'overjoyed', 'wields', 'sedition', 'unforgiving', 'parleying', 'fee', 'koön', 'hobbled', 'dagger', 'dikes', 'shaped', 'unsoiled', 'timê', 'limped', 'silver-eddying', 'iaira', 'retreat', 'hesitate', 'indulge', 'veering', 'partaking', 'tow', 'ajaxes', 'swerves', 'wriggled', 'overleap', 'delicacy', 'inviolate', 'fittest', 'tasseled', 'sea-fight', 'marshy', 'fangs', 'groveled', 'sword-wounds', 'minyeios', 'amisodoros', 'disdaining', 'sighed', 'bawling', 'dissuaded', 'aesopos', 'tlepolemos', 'archilokhos', 'limnorea', 'violate', 'golden-haired', 'mnesos', 'ikarian', 'tusked', 'hektor', 'particular', 'head-strong', 'nestled', 'robbing', 'boagrios', 'afford', 'porridge', 'atymnios', 'unloosed', 'tumbling', 'areilykos', 'kicks', 'arriving', 'bright-', 'mete', 'gatemen', 'another-', 'totally', 'elm-tree', 'biggest', 'indifferent', 'plenitude', 'meddle', 'lykastos', 'disquietness', 'glories', 'dejected', 'gravest', 'infirmities', 'lyktos', 'askalaphos', 'ambush-', 'uppermost', 'hammering', 'filly', 'precise', 'jeopardy', 'tuft', 'halcyon', 'erylaos', 'task-master', 'yawned', 'ialmenos', 'grain-growing', 'sift', 'divinity', 'aisyetes', 'leitos', 'aithe', 'cyparisseis', 'bronze-headed', 'concert', 'spearsman', 'impart', 'nerve', 'establishing', 'peeping', 'trice', 'thalia', 'portentous', 'extent', 'spade', 'cracked', 'baned', 'melting', 'thebaios', 'zeus-d ...
#
#   unique words in both tlg0012.tlg001.perseus-eng4.txt and tlg0012.tlg002.perseus-eng3.txt:
# {'hippomakhos', 'stave', 'gaping', 'mountain-track', 'penalties', 'boons', 'duck', 'urgent', 'pall', 'quickest', 'roses', 'doting', 'cushion', 'misgiving', 'crystal', 'wronging', 'surpassing', 'steeled', 'mown', 'quailing', 'phylomedousa', 'wounding', 'file', 'kteatos', 'eionae', 'astypylos', 'dispatched', 'truer', 'exults', 'councilor', 'thicker', 'tricked', 'ablaze-', 'well-nigh', 'rock-perched', 'householders', 'alêthea', 'echios', 'succor', 'groanful', 'daintiest', 'full-speed', 'sallies', 'lost-', 'yoking', 'decrees', 'branching', 'vaunts', 'bondswomen', 'contradicts', 'spercheios', 'collar-bones', 'stated', 'menaces', 'lowed', 'attire', 'asaios', 'carelessness', 'northwest', 'top-rail', 'weddings', 'depended', 'helter-skelter', 'calmed', 'axes-', 'bystanders', 'decoyed', 'skirted', 'implanted', 'smashing', 'foolishness', 'enjoyment', 'unkindness', 'echeklos', 'waterside', 'train', 'entrapping', 'right-hand', 'unnerved', 'amphoteros', 'linus-song', 'bronzed', 'continuous', 'amphigenea', 'thickens', 'offend', 'spearsmen', 'feeblest', 'stunned', 'universal', 'chattel', 'thatched', 'echekles', 'demands', 'whisks', 'unmolested', 'bestrewn', 'openmouthed', 'levying', 'wheel-marks', 'persisted', 'crushing', 'cue', 'examine', 'goat-herd', 'ephyroi', 'bud', 'routs', 'arm-rods', 'resolutely', 'nay-', 'likymnios', 'exhort', 'death-throes', 'awe-struck', 'anew', 'moaned', 'half-circle', 'slinks', 'fledglings', 'zelea', 'ebbed', 'player', 'drowsy', 'intervals', 'masonry', 'ekhepolos', 'agakles', 'plays', 'smooth-tongued', 'dales', 'askanios', 'quoit', 'ferret-skin', 'gale-', 'gainsaid', 'untied', 'spear-wound', 'boxwood', 'preceding', 'eyed', 'reaped', 'washing-troughs', 'thrash', 'echinean', 'suffice', 'twisting', 'foundation', 'minyas', 'movement', 'wolf-skin', 'remorse', 'menesthios', 'women-servants', 'notify', 'flashes', 'judging', 'slanderer', 'panoply', 'induce', 'suggestions', 'steward', 'searches', 'argument', 'triple-barbed', 'unrighteous', 'pyraikhmes', 'punishing', 'meteor', 'sounder', 'fervently', 'eussoros', 'exchanged', 'cataract', 'cleaver', 'sheep-yard', 'kaletor', 'hip-joint', 'gamboling', 'ennomos', 'oreithuia', 'dardanos', 'thersilokhos', 'gorgeous', 'sceptered', 'texture', 'butts', 'rhigmos', 'kinship', 'ankaios', 'calamity', 'clip', 'furnace', 'limpid', 'unplundered', 'severs', 'nestlings', 'buffeting', 'recruit', 'never-ending', 'buds', 'deliberation', 'eteokles', 'effaced', 'laerkes', 'parch', 'hyrtios', 'stickle', 'stymphelus', 'curbed', 'fickle', 'lure', 'sadness', 'polyxenos', 'hippokoön', 'opportunely', 'compassionately', 'wine-cup', 'perea', 'grimy', 'serviceable', 'overjoyed', 'wields', 'sedition', 'unforgiving', 'parleying', 'fee', 'koön', 'hobbled', 'dagger', 'dikes', 'shaped', 'unsoiled', 'timê', 'limped', 'silver-eddying', 'iaira', 'retreat', 'hesitate', 'indulge', 'veering', 'partaking', 'tow', 'ajaxes', 'swerves', 'wriggled', 'overleap', 'delicacy', 'inviolate', 'fittest', 'tasseled', 'sea-fight', 'marshy', 'fangs', 'groveled', 'sword-wounds', 'minyeios', 'amisodoros', 'disdaining', 'sighed', 'bawling', 'dissuaded', 'aesopos', 'tlepolemos', 'archilokhos', 'limnorea', 'violate', 'golden-haired', 'mnesos', 'ikarian', 'tusked', 'hektor', 'particular', 'head-strong', 'nestled', 'robbing', 'boagrios', 'afford', 'porridge', 'atymnios', 'unloosed', 'tumbling', 'areilykos', 'kicks', 'arriving', 'bright-', 'mete', 'gatemen', 'another-', 'totally', 'elm-tree', 'biggest', 'indifferent', 'plenitude', 'meddle', 'lykastos', 'disquietness', 'glories', 'dejected', 'gravest', 'infirmities', 'lyktos', 'askalaphos', 'ambush-', 'uppermost', 'hammering', 'filly', 'precise', 'jeopardy', 'tuft', 'halcyon', 'erylaos', 'task-master', 'yawned', 'ialmenos', 'grain-growing', 'sift', 'divinity', 'aisyetes', 'leitos', 'aithe', 'cyparisseis', 'bronze-headed', 'concert', 'spearsman', 'impart', 'nerve', 'establishing', 'peeping', 'trice', 'thalia', 'portentous', 'extent', 'spade', 'cracked', 'baned', 'melting', 'thebaios', 'zeus-d ...
#
#   unique words in both tlg0012.tlg002.perseus-eng3.txt and tlg0012.tlg001.perseus-eng3.txt:
# {'labours', 'road-steads', 'lacks', 'comeliness.', 'men—meanwhile', 'forwardness', "would'st", 'strength.', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'hazarding', 'strokes', 'teaching', 'sicilian', 'helper.', 'fore-stays', 'roaming', 'carpentry', 'sale', 'overseer', 'crataiis', 'trade', 'yelping', 'aegyptius', 'vagabond.', 'parents—would', 'criest', 'mirth', 'phaethusa', 'casts', 'passer-by', 'vaulted-over', 'onward—soon', 'beaches', 'sturdier', 'archaeans', 'twigs', 'paeeon', 'deeds.', 'longed-for', 'tender-heartedness', 'cureless', 'suffering.', 'consorting', 'unchanged', 'grief.', 'ismarus', 'regret', 'many—aye', 'greenwood', 'trenches', '—thy', 'markest', 'vermin', 'last.', 'owes', 'wretchedness', 'dawn.', 'core', 'psyria', 'misty', 'boastful', 'prelude', 'war.', 'furling', 'leucas', 'zethus', 'deigned', 'marring', 'circe.', 'harm.', 'spiders', 'giants.', 'wakens', 'demoptolemus', 'oughtest', 'thrice-blessed', 'deep-moaning', 'threateningly', 'forsake', 'fitteth', 'graciously', 'another.', 'undertook', 'tellest', 'abstain', 'supreme.', 'athena.', 'dimmed', 'city.', 'neaera', 'pontonous', 'curled', 'sheep-pen', 'postern', 'ephialtes—men', 'far-off', 'strengthening', 'confirmed', 'males—the', '—where', 'rivals', 'forests.', 'sowing', 'irus', 'thee—hail', 'cross-planks', 'feast.', 'look—as', 'mounts', '—he', 'mid-sea', 'spear-rack', 'gold.', 'line—', 'much.', 'curly-haired', 'sulphurous', 'pools', 'murders', 'thole-straps', 'loosened—then', 'eumaeus', 'gifts.', 'kindred', 'judged', 'elder.', 'pelasgians', 'unmanned.', 'myself.', 'statelier', 'torment.', 'rest.', 'achilles.', 'tale.', 'expectantly', 'buying', 'galling', 'stalls', 'eurymus', 'tearless', 'out-stripped', 'someday', 'husband.', 'roamed', 'offerings—there', 'gulfs', 'abound.', 'mischief-maker', 'porous', 'portioning', 'ctesius', 'made.', 'endue', 'seemly.', 'warms', 'no-wise', 'impious', 'long-shanked', 'trotted', 'unclear', 'besides.', 'oar-blade.', 'anoints', 'conquers', 'limb.', 'hollows', 'shrinkest', 'farthermost', 'aught.', 'brutal', 'decree', 'blossomed', 'gainful', 'tie', 'four-fold', 'portionless', 'mesaulius', 'arise.', 'oared', 'blame.', 'man-eater', 'plight.', 'himself.', 'afar.', 'hand-washing', 'wrenched', 'bountifully', 'blot', 'oar-loving', 'phaeacians.', 'tityos', 'resolve', 'frisk', 'kindness.', 'fawningly', 'pinched', 'launching', 'helius', 'adulterer.', 'prospers', 'evade', 'was—to', 'chair—a', 'land—his', 'me—for', 'crusted', 'whit—', 'cytherea', 'stranger-folk', 'wane', 'grey-headed', 'wife.', 'morticings', 'persisting', 'many-voiced', 'god.', 'maro', 'nudging', 'fast.', 'shoved', 'dangers', 'bootes', 'modesty', 'geraestus', 'cities.', 'house—proud', 'was—even', 'stone.', 'antinous', 'phaedimus', 'thoughts.', 'livelihood', 'it—a', 'acastus', 'gad-fly', 'winnowing-fan', 'plenteous', 'pasturing', 'mused', 'pelted', 'two-eared', 'brine-bred', 'me—be', 'confusedly.', 'neatherd', 'unfailing', 'strength—and', 'feud', 'alcmaeon', 'thrive', 'balm', 'cleanest', 'awry', 'barter', 'wrest', 'vessels—', 'shadows.', '—how', 'sorrow—', 'weighted', 'anticleia', 'weddest', 'growling', 'banqueters', 'greed', 'robe—', 'draught', 'pranced', 'named.', 'guiding', 'roundabout', 'donning', 'wed.', 'repute', 'well.', 'remembers', 'two-fold', 'strew', 'passers-by', 'kitchen-wife', 'plunging', 'deck-beams', 'men—as', 'passion.', 'slave-women', 'table-dogs', 'seemlier', 'these.', 'stairway', 'naught—ate', 'rend.', 'tone', 'question.', 'begrudge', 'luckless', 'above.', 'scrip', 'woman—amazement', 'well-watered', 'cravens', 'heardest', 'sea—and', 'lamus', 'amphilochus', 'bones.', 'befoul', 'leucothea', 'possessions.', 'nobles', 'spars', 'true-hearted', 'enquiring', 'joy.', 'guiltless.', 'somewhat.', 'shews', 'planks', 'fair-stablished', 'polycaste', 'reviling.', 'contest.', 'hairy', 'vagabonds', 'this—what', 'in.', 'bedims', 'true-born', 'whencesoever', 'basest', 'hoof', 'reef', 'assurance', 'feels', '—fool', 'intertwining', 'arms.', 'apollo—for', 'ignorance', 'mocked',  ...
#
#   unique words in both tlg0012.tlg002.perseus-eng3.txt and tlg0012.tlg002.perseus-eng4.txt:
# {'labours', 'road-steads', 'lacks', 'comeliness.', 'men—meanwhile', 'forwardness', "would'st", 'strength.', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'hazarding', 'strokes', 'teaching', 'sicilian', 'helper.', 'fore-stays', 'roaming', 'carpentry', 'sale', 'overseer', 'crataiis', 'trade', 'yelping', 'aegyptius', 'vagabond.', 'parents—would', 'criest', 'mirth', 'phaethusa', 'casts', 'passer-by', 'vaulted-over', 'onward—soon', 'beaches', 'sturdier', 'archaeans', 'twigs', 'paeeon', 'deeds.', 'longed-for', 'tender-heartedness', 'cureless', 'suffering.', 'consorting', 'unchanged', 'grief.', 'ismarus', 'regret', 'many—aye', 'greenwood', 'trenches', '—thy', 'markest', 'vermin', 'last.', 'owes', 'wretchedness', 'dawn.', 'core', 'psyria', 'misty', 'boastful', 'prelude', 'war.', 'furling', 'leucas', 'zethus', 'deigned', 'marring', 'circe.', 'harm.', 'spiders', 'giants.', 'wakens', 'demoptolemus', 'oughtest', 'thrice-blessed', 'deep-moaning', 'threateningly', 'forsake', 'fitteth', 'graciously', 'another.', 'undertook', 'tellest', 'abstain', 'supreme.', 'athena.', 'dimmed', 'city.', 'neaera', 'pontonous', 'curled', 'sheep-pen', 'postern', 'ephialtes—men', 'far-off', 'strengthening', 'confirmed', 'males—the', '—where', 'rivals', 'forests.', 'sowing', 'irus', 'thee—hail', 'cross-planks', 'feast.', 'look—as', 'mounts', '—he', 'mid-sea', 'spear-rack', 'gold.', 'line—', 'much.', 'curly-haired', 'sulphurous', 'pools', 'murders', 'thole-straps', 'loosened—then', 'eumaeus', 'gifts.', 'kindred', 'judged', 'elder.', 'pelasgians', 'unmanned.', 'myself.', 'statelier', 'torment.', 'rest.', 'achilles.', 'tale.', 'expectantly', 'buying', 'galling', 'stalls', 'eurymus', 'tearless', 'out-stripped', 'someday', 'husband.', 'roamed', 'offerings—there', 'gulfs', 'abound.', 'mischief-maker', 'porous', 'portioning', 'ctesius', 'made.', 'endue', 'seemly.', 'warms', 'no-wise', 'impious', 'long-shanked', 'trotted', 'unclear', 'besides.', 'oar-blade.', 'anoints', 'conquers', 'limb.', 'hollows', 'shrinkest', 'farthermost', 'aught.', 'brutal', 'decree', 'blossomed', 'gainful', 'tie', 'four-fold', 'portionless', 'mesaulius', 'arise.', 'oared', 'blame.', 'man-eater', 'plight.', 'himself.', 'afar.', 'hand-washing', 'wrenched', 'bountifully', 'blot', 'oar-loving', 'phaeacians.', 'tityos', 'resolve', 'frisk', 'kindness.', 'fawningly', 'pinched', 'launching', 'helius', 'adulterer.', 'prospers', 'evade', 'was—to', 'chair—a', 'land—his', 'me—for', 'crusted', 'whit—', 'cytherea', 'stranger-folk', 'wane', 'grey-headed', 'wife.', 'morticings', 'persisting', 'many-voiced', 'god.', 'maro', 'nudging', 'fast.', 'shoved', 'dangers', 'bootes', 'modesty', 'geraestus', 'cities.', 'house—proud', 'was—even', 'stone.', 'antinous', 'phaedimus', 'thoughts.', 'livelihood', 'it—a', 'acastus', 'gad-fly', 'winnowing-fan', 'plenteous', 'pasturing', 'mused', 'pelted', 'two-eared', 'brine-bred', 'me—be', 'confusedly.', 'neatherd', 'unfailing', 'strength—and', 'feud', 'alcmaeon', 'thrive', 'balm', 'cleanest', 'awry', 'barter', 'wrest', 'vessels—', 'shadows.', '—how', 'sorrow—', 'weighted', 'anticleia', 'weddest', 'growling', 'banqueters', 'greed', 'robe—', 'draught', 'pranced', 'named.', 'guiding', 'roundabout', 'donning', 'wed.', 'repute', 'well.', 'remembers', 'two-fold', 'strew', 'passers-by', 'kitchen-wife', 'plunging', 'deck-beams', 'men—as', 'passion.', 'slave-women', 'table-dogs', 'seemlier', 'these.', 'stairway', 'naught—ate', 'rend.', 'tone', 'question.', 'begrudge', 'luckless', 'above.', 'scrip', 'woman—amazement', 'well-watered', 'cravens', 'heardest', 'sea—and', 'lamus', 'amphilochus', 'bones.', 'befoul', 'leucothea', 'possessions.', 'nobles', 'spars', 'true-hearted', 'enquiring', 'joy.', 'guiltless.', 'somewhat.', 'shews', 'planks', 'fair-stablished', 'polycaste', 'reviling.', 'contest.', 'hairy', 'vagabonds', 'this—what', 'in.', 'bedims', 'true-born', 'whencesoever', 'basest', 'hoof', 'reef', 'assurance', 'feels', '—fool', 'intertwining', 'arms.', 'apollo—for', 'ignorance', 'mocked',  ...
#
#   unique words in both tlg0012.tlg002.perseus-eng3.txt and tlg0012.tlg001.perseus-eng4.txt:
# {'labours', 'road-steads', 'lacks', 'comeliness.', 'men—meanwhile', 'forwardness', "would'st", 'strength.', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'hazarding', 'strokes', 'teaching', 'sicilian', 'helper.', 'fore-stays', 'roaming', 'carpentry', 'sale', 'overseer', 'crataiis', 'trade', 'yelping', 'aegyptius', 'vagabond.', 'parents—would', 'criest', 'mirth', 'phaethusa', 'casts', 'passer-by', 'vaulted-over', 'onward—soon', 'beaches', 'sturdier', 'archaeans', 'twigs', 'paeeon', 'deeds.', 'longed-for', 'tender-heartedness', 'cureless', 'suffering.', 'consorting', 'unchanged', 'grief.', 'ismarus', 'regret', 'many—aye', 'greenwood', 'trenches', '—thy', 'markest', 'vermin', 'last.', 'owes', 'wretchedness', 'dawn.', 'core', 'psyria', 'misty', 'boastful', 'prelude', 'war.', 'furling', 'leucas', 'zethus', 'deigned', 'marring', 'circe.', 'harm.', 'spiders', 'giants.', 'wakens', 'demoptolemus', 'oughtest', 'thrice-blessed', 'deep-moaning', 'threateningly', 'forsake', 'fitteth', 'graciously', 'another.', 'undertook', 'tellest', 'abstain', 'supreme.', 'athena.', 'dimmed', 'city.', 'neaera', 'pontonous', 'curled', 'sheep-pen', 'postern', 'ephialtes—men', 'far-off', 'strengthening', 'confirmed', 'males—the', '—where', 'rivals', 'forests.', 'sowing', 'irus', 'thee—hail', 'cross-planks', 'feast.', 'look—as', 'mounts', '—he', 'mid-sea', 'spear-rack', 'gold.', 'line—', 'much.', 'curly-haired', 'sulphurous', 'pools', 'murders', 'thole-straps', 'loosened—then', 'eumaeus', 'gifts.', 'kindred', 'judged', 'elder.', 'pelasgians', 'unmanned.', 'myself.', 'statelier', 'torment.', 'rest.', 'achilles.', 'tale.', 'expectantly', 'buying', 'galling', 'stalls', 'eurymus', 'tearless', 'out-stripped', 'someday', 'husband.', 'roamed', 'offerings—there', 'gulfs', 'abound.', 'mischief-maker', 'porous', 'portioning', 'ctesius', 'made.', 'endue', 'seemly.', 'warms', 'no-wise', 'impious', 'long-shanked', 'trotted', 'unclear', 'besides.', 'oar-blade.', 'anoints', 'conquers', 'limb.', 'hollows', 'shrinkest', 'farthermost', 'aught.', 'brutal', 'decree', 'blossomed', 'gainful', 'tie', 'four-fold', 'portionless', 'mesaulius', 'arise.', 'oared', 'blame.', 'man-eater', 'plight.', 'himself.', 'afar.', 'hand-washing', 'wrenched', 'bountifully', 'blot', 'oar-loving', 'phaeacians.', 'tityos', 'resolve', 'frisk', 'kindness.', 'fawningly', 'pinched', 'launching', 'helius', 'adulterer.', 'prospers', 'evade', 'was—to', 'chair—a', 'land—his', 'me—for', 'crusted', 'whit—', 'cytherea', 'stranger-folk', 'wane', 'grey-headed', 'wife.', 'morticings', 'persisting', 'many-voiced', 'god.', 'maro', 'nudging', 'fast.', 'shoved', 'dangers', 'bootes', 'modesty', 'geraestus', 'cities.', 'house—proud', 'was—even', 'stone.', 'antinous', 'phaedimus', 'thoughts.', 'livelihood', 'it—a', 'acastus', 'gad-fly', 'winnowing-fan', 'plenteous', 'pasturing', 'mused', 'pelted', 'two-eared', 'brine-bred', 'me—be', 'confusedly.', 'neatherd', 'unfailing', 'strength—and', 'feud', 'alcmaeon', 'thrive', 'balm', 'cleanest', 'awry', 'barter', 'wrest', 'vessels—', 'shadows.', '—how', 'sorrow—', 'weighted', 'anticleia', 'weddest', 'growling', 'banqueters', 'greed', 'robe—', 'draught', 'pranced', 'named.', 'guiding', 'roundabout', 'donning', 'wed.', 'repute', 'well.', 'remembers', 'two-fold', 'strew', 'passers-by', 'kitchen-wife', 'plunging', 'deck-beams', 'men—as', 'passion.', 'slave-women', 'table-dogs', 'seemlier', 'these.', 'stairway', 'naught—ate', 'rend.', 'tone', 'question.', 'begrudge', 'luckless', 'above.', 'scrip', 'woman—amazement', 'well-watered', 'cravens', 'heardest', 'sea—and', 'lamus', 'amphilochus', 'bones.', 'befoul', 'leucothea', 'possessions.', 'nobles', 'spars', 'true-hearted', 'enquiring', 'joy.', 'guiltless.', 'somewhat.', 'shews', 'planks', 'fair-stablished', 'polycaste', 'reviling.', 'contest.', 'hairy', 'vagabonds', 'this—what', 'in.', 'bedims', 'true-born', 'whencesoever', 'basest', 'hoof', 'reef', 'assurance', 'feels', '—fool', 'intertwining', 'arms.', 'apollo—for', 'ignorance', 'mocked',  ...

# %%
for first_file, first_set in non_universal_terms.items():
    for second_file, second_set in non_universal_terms.items():
        if first_file == second_file:
            continue
        difference = first_set - second_set
        if difference: 
            print(f"\n  unique words in {first_file} not in {second_file}:")
            print(difference)
# Out:
#   unique words in tlg0012.tlg001.perseus-eng3.txt not in tlg0012.tlg002.perseus-eng4.txt:
# {'onsets', 'embassage', 'loiter', 'fulfilleth', 'townsfolk—far', 'maeonian', 'unshepherded', 'gods—', 'purposing', 'ascania', 'accompany', 'father-slayer', 'acamas', 'spear-famed', 'me—that', 'poising', 'pitiest', 'out-stretched', 'astynous', 'looketh', 'gazest', 'roareth', 'thea', 'elm', 'buprasium', 'unransomed', 'plaintively', 'swiftships', 'river-bed', 'thalpius', 'immovably', 'yoke-pad', 'achelous', 'soles', 'standest', 'sovreignty', 'hipponous', 'vehement', 'runneth', 'isus', 'lop', 'wide-scattered', 'crusheth', 'causeth', 'judgement', 'blessings', 'marveling', '121.1', 'strong-built', 'assaileth', 'ownself', 'tugs', 'meeteth', 'enyalius', '—that', 'amny', '—some', 'froma', 'ear-rings', 'zeus—who', 'warped', 'asius', '—nay', 'toiling', 'broodeth', 'wardeth', 'corslet', 'zeus-nurtured', 'saveth', 'asaeus', 'shin', 'courseth', 'behoveth', 'things—my', 'raging—thitherward', 'polyidus', 'panteth', 'way-farer', 'suiting', 'licymnius', 'disorderly', '521.1', 'protesilaus', 'unbearable', 'arousing', 'neeks', 'drinking-bouts', 'speakers', "ne'er", 'axle-trees', 'belloweth', '423.3', 'cloven', 'frantic', 'son—he', 'erythini', 'send—even', '409.1', 'full-wrought', 'polyneices', 'aepytus', 'strifes', 'switft-footed', 'churlish', 'bronze-harnessed', 'cymothoë', 'taskmaster', 'onchestus', 'eared', 'marshallers', 'baleful', 'man-slaying', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'water-courses', 'bane—to', 'smitest', 'consorteth', 'mischief—one', 'obeys', 'broughtest', 'storm-footed', 'perisheth', 'chaseth', 'coön', 'marking', 'slender', 'sinketh', 'euneos', 'offerest', 'crier', 'echo', 'lycophron', 'choven', 'axius—axius', 'ormenius', 'fodder', 'inquirest', 'over-haughty', 'streweth', 'succoureth', 'springeth', 'wind-waved', 'acessamenus', 'lurid', 'gentle-mindedness', 'peace—yet', 'wind-nurtured', 'capaneus', 'themselves—even', 'awaiteth', 'straight-flying', 'deemest', 'you—if', 'fillies', 'agacles', 'friendliness', 'phausius', 'above—', 'alcandrus', 'wrought—nay', 'wide-flowing', 'autophonus', 'dius', 'sullying', 'deed—one', 'harnesseth', 'accomplisheth', 'mattock', 'suspended', 'labouring', 'him—for', "e'en", 'callianeira', 'refreshing', 'prayeth', 'calesius', 'sufficeth', 'blacker', 'walketh', 'first-born', '565.1', 'ower', 'augeias', 'consolation', 'tight-stretched', 'calchas', 'selleïs', '215.1', 'eïoneus', 'joineth', 'unbought', 'rivalry', 'swft', 'falleth', 'now—for', 'ships—would', 'swifted-footed', 'cadmeians', 'herds-men', 'dooms', '159.1', 'peered', 'departeth', 'bearers', 'aegialus', 'thwarter', 'confront', 'avow', 'apportion', 'rhodius', 'sendest', 'speio', 'laodocus', 'halcyon-bird', 'serves', 'souled', 'promptings', 'elder-born', 'equa1', 'hest', 'fie', '181.1', 'helenus', 'horse-men', '569.1', 'biding', 'daetor', 'ceasest', 'disarray', 'soundeth', 'overmastered', 'creaked', 'forbare', 'high-arched', 'saffron-robed', 'oaks—the', 'slaving', 'hippodamus', 'cherisheth', 'seemeth', 'iron—all', 'burgeoneth', 'through—', 'unmarked', 'podaleirius', 'casteth', 'stead-fast', 'safer', 'intervene', 'cleaveth', 'gaped', "whoe'er", 'sharp-toothed', 'deïpylus', 'zeus—born', 'fury-breathing', 'sharp-fanged', 'lyctus—for', 'spakest', 'doest', 'strophius', 'shield-bearing', 'chicks', 'heside', 'ialmenus', 'cruelty', 'moveless', 'overmaster', 'closest', 'astyalus', 'passeth', 'poureth', 'vanquisheth', 'mother—but', 'bhack', 'cardamyle', 'ankle-pieces', 'swiftness', '—of', 'aesymnus', 'pandocus', 'it—and', 'asclepius', 'battlegear', '—then', 'unblest', 'oïleus', 'mastereth', '483.2', 'displeasing', 'box-wood', 'kindliness', 'aepeia', 'rotteth', 'lustfulness', 'areithous', 'unsacked', 'skilless', 'this—that', 'saileth', 'dog-fly', 'dravest', 'agastrophus', 'eteonus', 'infatuate', 'phlegyes', 'wives—there', 'close-fenced', 'scandeia', 'quaileth', 'stud', 'it—yet', 'axylus', 'counselled', 'dancing-floor', 'ptolemaeus', 'unfed', 'coeranus', 'leucus', 'all—a', 'hector—', 'tangle-strewn', 'spercheüs', 'ialysus', 'relax', 'haz ...
#
#   unique words in tlg0012.tlg001.perseus-eng3.txt not in tlg0012.tlg001.perseus-eng4.txt:
# {'onsets', 'embassage', 'loiter', 'fulfilleth', 'townsfolk—far', 'maeonian', 'unshepherded', 'gods—', 'purposing', 'ascania', 'accompany', 'father-slayer', 'acamas', 'spear-famed', 'me—that', 'poising', 'pitiest', 'out-stretched', 'astynous', 'looketh', 'gazest', 'roareth', 'thea', 'elm', 'buprasium', 'unransomed', 'plaintively', 'swiftships', 'river-bed', 'thalpius', 'immovably', 'yoke-pad', 'achelous', 'soles', 'standest', 'sovreignty', 'hipponous', 'vehement', 'runneth', 'isus', 'lop', 'wide-scattered', 'crusheth', 'causeth', 'judgement', 'blessings', 'marveling', '121.1', 'strong-built', 'assaileth', 'ownself', 'tugs', 'meeteth', 'enyalius', '—that', 'amny', '—some', 'froma', 'ear-rings', 'zeus—who', 'warped', 'asius', '—nay', 'toiling', 'broodeth', 'wardeth', 'corslet', 'zeus-nurtured', 'saveth', 'asaeus', 'shin', 'courseth', 'behoveth', 'things—my', 'raging—thitherward', 'polyidus', 'panteth', 'way-farer', 'suiting', 'licymnius', 'disorderly', '521.1', 'protesilaus', 'unbearable', 'arousing', 'neeks', 'drinking-bouts', 'speakers', "ne'er", 'axle-trees', 'belloweth', '423.3', 'cloven', 'frantic', 'son—he', 'erythini', 'send—even', '409.1', 'full-wrought', 'polyneices', 'aepytus', 'strifes', 'switft-footed', 'churlish', 'bronze-harnessed', 'cymothoë', 'taskmaster', 'onchestus', 'eared', 'marshallers', 'baleful', 'man-slaying', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'water-courses', 'bane—to', 'smitest', 'consorteth', 'mischief—one', 'obeys', 'broughtest', 'storm-footed', 'perisheth', 'chaseth', 'coön', 'marking', 'slender', 'sinketh', 'euneos', 'offerest', 'crier', 'echo', 'lycophron', 'choven', 'axius—axius', 'ormenius', 'fodder', 'inquirest', 'over-haughty', 'streweth', 'succoureth', 'springeth', 'wind-waved', 'acessamenus', 'lurid', 'gentle-mindedness', 'peace—yet', 'wind-nurtured', 'capaneus', 'themselves—even', 'awaiteth', 'straight-flying', 'deemest', 'you—if', 'fillies', 'agacles', 'friendliness', 'phausius', 'above—', 'alcandrus', 'wrought—nay', 'wide-flowing', 'autophonus', 'dius', 'sullying', 'deed—one', 'harnesseth', 'accomplisheth', 'mattock', 'suspended', 'labouring', 'him—for', "e'en", 'callianeira', 'refreshing', 'prayeth', 'calesius', 'sufficeth', 'blacker', 'walketh', 'first-born', '565.1', 'ower', 'augeias', 'consolation', 'tight-stretched', 'calchas', 'selleïs', '215.1', 'eïoneus', 'joineth', 'unbought', 'rivalry', 'swft', 'falleth', 'now—for', 'ships—would', 'swifted-footed', 'cadmeians', 'herds-men', 'dooms', '159.1', 'peered', 'departeth', 'bearers', 'aegialus', 'thwarter', 'confront', 'avow', 'apportion', 'rhodius', 'sendest', 'speio', 'laodocus', 'halcyon-bird', 'serves', 'souled', 'promptings', 'elder-born', 'equa1', 'hest', 'fie', '181.1', 'helenus', 'horse-men', '569.1', 'biding', 'daetor', 'ceasest', 'disarray', 'soundeth', 'overmastered', 'creaked', 'forbare', 'high-arched', 'saffron-robed', 'oaks—the', 'slaving', 'hippodamus', 'cherisheth', 'seemeth', 'iron—all', 'burgeoneth', 'through—', 'unmarked', 'podaleirius', 'casteth', 'stead-fast', 'safer', 'intervene', 'cleaveth', 'gaped', "whoe'er", 'sharp-toothed', 'deïpylus', 'zeus—born', 'fury-breathing', 'sharp-fanged', 'lyctus—for', 'spakest', 'doest', 'strophius', 'shield-bearing', 'chicks', 'heside', 'ialmenus', 'cruelty', 'moveless', 'overmaster', 'closest', 'astyalus', 'passeth', 'poureth', 'vanquisheth', 'mother—but', 'bhack', 'cardamyle', 'ankle-pieces', 'swiftness', '—of', 'aesymnus', 'pandocus', 'it—and', 'asclepius', 'battlegear', '—then', 'unblest', 'oïleus', 'mastereth', '483.2', 'displeasing', 'box-wood', 'kindliness', 'aepeia', 'rotteth', 'lustfulness', 'areithous', 'unsacked', 'skilless', 'this—that', 'saileth', 'dog-fly', 'dravest', 'agastrophus', 'eteonus', 'infatuate', 'phlegyes', 'wives—there', 'close-fenced', 'scandeia', 'quaileth', 'stud', 'it—yet', 'axylus', 'counselled', 'dancing-floor', 'ptolemaeus', 'unfed', 'coeranus', 'leucus', 'all—a', 'hector—', 'tangle-strewn', 'spercheüs', 'ialysus', 'relax', 'haz ...
#
#   unique words in tlg0012.tlg001.perseus-eng3.txt not in tlg0012.tlg002.perseus-eng3.txt:
# {'onsets', 'embassage', 'loiter', 'fulfilleth', 'townsfolk—far', 'maeonian', 'unshepherded', 'gods—', 'purposing', 'ascania', 'accompany', 'father-slayer', 'acamas', 'spear-famed', 'me—that', 'poising', 'pitiest', 'out-stretched', 'astynous', 'looketh', 'gazest', 'roareth', 'thea', 'elm', 'buprasium', 'unransomed', 'plaintively', 'swiftships', 'river-bed', 'thalpius', 'immovably', 'yoke-pad', 'achelous', 'soles', 'standest', 'sovreignty', 'hipponous', 'vehement', 'runneth', 'isus', 'lop', 'wide-scattered', 'crusheth', 'causeth', 'judgement', 'blessings', 'marveling', '121.1', 'strong-built', 'assaileth', 'ownself', 'tugs', 'meeteth', 'enyalius', '—that', 'amny', '—some', 'froma', 'ear-rings', 'zeus—who', 'warped', 'asius', '—nay', 'toiling', 'broodeth', 'wardeth', 'corslet', 'zeus-nurtured', 'saveth', 'asaeus', 'shin', 'courseth', 'behoveth', 'things—my', 'raging—thitherward', 'polyidus', 'panteth', 'way-farer', 'suiting', 'licymnius', 'disorderly', '521.1', 'protesilaus', 'unbearable', 'arousing', 'neeks', 'drinking-bouts', 'speakers', "ne'er", 'axle-trees', 'belloweth', '423.3', 'cloven', 'frantic', 'son—he', 'erythini', 'send—even', '409.1', 'full-wrought', 'polyneices', 'aepytus', 'strifes', 'switft-footed', 'churlish', 'bronze-harnessed', 'cymothoë', 'taskmaster', 'onchestus', 'eared', 'marshallers', 'baleful', 'man-slaying', 'spattered', 'own—yet', 'washing-tanks', 'ploughing—for', 'water-courses', 'bane—to', 'smitest', 'consorteth', 'mischief—one', 'obeys', 'broughtest', 'storm-footed', 'perisheth', 'chaseth', 'coön', 'marking', 'slender', 'sinketh', 'euneos', 'offerest', 'crier', 'echo', 'lycophron', 'choven', 'axius—axius', 'ormenius', 'fodder', 'inquirest', 'over-haughty', 'streweth', 'succoureth', 'springeth', 'wind-waved', 'acessamenus', 'lurid', 'gentle-mindedness', 'peace—yet', 'wind-nurtured', 'capaneus', 'themselves—even', 'awaiteth', 'straight-flying', 'deemest', 'you—if', 'fillies', 'agacles', 'friendliness', 'phausius', 'above—', 'alcandrus', 'wrought—nay', 'wide-flowing', 'autophonus', 'dius', 'sullying', 'deed—one', 'harnesseth', 'accomplisheth', 'mattock', 'suspended', 'labouring', 'him—for', "e'en", 'callianeira', 'refreshing', 'prayeth', 'calesius', 'sufficeth', 'blacker', 'walketh', 'first-born', '565.1', 'ower', 'augeias', 'consolation', 'tight-stretched', 'calchas', 'selleïs', '215.1', 'eïoneus', 'joineth', 'unbought', 'rivalry', 'swft', 'falleth', 'now—for', 'ships—would', 'swifted-footed', 'cadmeians', 'herds-men', 'dooms', '159.1', 'peered', 'departeth', 'bearers', 'aegialus', 'thwarter', 'confront', 'avow', 'apportion', 'rhodius', 'sendest', 'speio', 'laodocus', 'halcyon-bird', 'serves', 'souled', 'promptings', 'elder-born', 'equa1', 'hest', 'fie', '181.1', 'helenus', 'horse-men', '569.1', 'biding', 'daetor', 'ceasest', 'disarray', 'soundeth', 'overmastered', 'creaked', 'forbare', 'high-arched', 'saffron-robed', 'oaks—the', 'slaving', 'hippodamus', 'cherisheth', 'seemeth', 'iron—all', 'burgeoneth', 'through—', 'unmarked', 'podaleirius', 'casteth', 'stead-fast', 'safer', 'intervene', 'cleaveth', 'gaped', "whoe'er", 'sharp-toothed', 'deïpylus', 'zeus—born', 'fury-breathing', 'sharp-fanged', 'lyctus—for', 'spakest', 'doest', 'strophius', 'shield-bearing', 'chicks', 'heside', 'ialmenus', 'cruelty', 'moveless', 'overmaster', 'closest', 'astyalus', 'passeth', 'poureth', 'vanquisheth', 'mother—but', 'bhack', 'cardamyle', 'ankle-pieces', 'swiftness', '—of', 'aesymnus', 'pandocus', 'it—and', 'asclepius', 'battlegear', '—then', 'unblest', 'oïleus', 'mastereth', '483.2', 'displeasing', 'box-wood', 'kindliness', 'aepeia', 'rotteth', 'lustfulness', 'areithous', 'unsacked', 'skilless', 'this—that', 'saileth', 'dog-fly', 'dravest', 'agastrophus', 'eteonus', 'infatuate', 'phlegyes', 'wives—there', 'close-fenced', 'scandeia', 'quaileth', 'stud', 'it—yet', 'axylus', 'counselled', 'dancing-floor', 'ptolemaeus', 'unfed', 'coeranus', 'leucus', 'all—a', 'hector—', 'tangle-strewn', 'spercheüs', 'ialysus', 'relax', 'haz ...
#
#   unique words in tlg0012.tlg002.perseus-eng4.txt not in tlg0012.tlg001.perseus-eng3.txt:
# {'usurp', 'forenoon', 'aigyptos', 'outlive', 'brush-wood', 'ones.', 'dissipated', 'disgust', 'well-mated', 'teaches', 'clapped', 'inhabitants', 'encircle', 'okyalos', 'independent', 'turned.', 'kindnesses', 'wonderfully', 'minyan', 'familiarity', 'foul-mouthed', 'fifty-two', 'dining', 'market', 'banishes', 'extraordinarily', 'adorn', 'widely', 'feather', 'magnificent', 'it-', 'waking', 'conferred', 'ogygian', 'creditable', 'occurred', 'timely', 'perilous', 'bondwoman', 'valuable', 'impulse', 'fortune-telling', 'unpick', 'lively', 'heralded', 'damaged', 'enthroned', 'memories', 'transgress', 'affair', 'disfigure', 'misconduct', 'ducts', 'mash', 'scenes', 'yours.', 'leukothea', 'breeder', 'vested', 'evenings', 'groove', 'perjurer', 'broken-down', 'drenching', 'management', 'euphrosunê', 'marauders', 'toasted', 'refitting', 'reasonably', 'jumping', 'tricks', 'elysium', 'straightening', 'plucks', 'scolding', 'eurymakhos', 'fits', 'obtaining', 'pyriphlegethon', 'misadventure', 'resemble', 'land-locked', 'enmity', 'convene', 'ill-conditioned', 'case-hardened', 'lioness', 'toys', 'resume', 'blessedness', 'rudder', 'swaggering', 'squalid', 'salutations', 'cypress-wood', 'remarks', 'overlap', 'sidonia', 'shifted', 'goodness', 'chuckle', 'outbuildings', 'verbal', 'leda', 'gossips', 'offices', 'iros', 'seal', 'vassal', 'blandishment', 'hundreds', 'recognizing', 'notices', 'tiptoe', 'regained', 'ktimene', 'stiffness', 'woe-begone', 'miller-women', 'mission', 'apartment', 'respectable', 'perfidy', 'flagging', 'well-disposed', 'hurts', 'polite', 'krataiis', 'volunteers', 'drip', 'unwasted', 'eumaios', 'nausithoos', 'eurymedousa', 'heinous', 'wink', 'distress.', 'warble', 'bleeds', 'anticipates', 'dowry', 'shocked', 'knock', 'squalls', 'thrinacian', 'moons', 'awed', 'oblige', 'picture', 'scarred', 'manure', 'nothing.', 'defying', 'clamored', 'scoundrels', 'behavior', 'irrepressible', 'lump', 'center-post', 'pat', 'drowned', 'rafter', 'insulting', 'firstly', 'likelihood', 'ox-thong', 'interrupted', 'admittance', 'emptied', 'aft', 'valuables', 'squeal', 'shave', 'ungrafted', 'polykaste', 'needlework', 'poorer', 'foresworn', 'tidy', 'merge', 'handsome', 'alkmaion', 'growl', 'bearing-posts', 'reprimand', 'bye', 'thawed', 'consciousness', 'donors', 'well-found', 'spends', 'visibly', 'relation', 'thoroughly', 'issued', 'infinity', 'pits', 'many-sided', 'goatskins', 'steersmen', '=', 'credit', 'anabesineos', 'competed', "'you", 'fretting', 'hive', 'well-to-do', 'grievance', 'raven', 'overflowing', 'recline', 'expedition', 'freights', 'instinct', 'backstay', 'gardener', 'rejoined', 'sighing', 'traveler', 'boarhounds', 'juicy', 'cooking', 'ktesios', 'disturbance', 'good-for-nothing', 'unpropitious', 'inches.', 'doubling', 'blighting', 'sea-side', 'remove', 'style', 'zethos', 'frightful', 'pork', 'afternoon', 'enormous', 'promontory', 'pretty', 'philoitios', 'ghost', 'principles', 'cheese-racks', 'individuals', 'trees.', 'true-begotten', 'broken-hearted', 'competing', 'irrigate', 'coherent', 'kreon', 'assure', 'bowshot', 'offense', 'square', 'enchantments', 'indoors', 'telemos', 'aver', 'wither', 'supersede', 'sluts', 'tapestries', 'unbound', 'cechalian-', 'crews', 'usually', 'oak-shoots', 'subtler', 'downstairs', 'casks', 'dragon', 'gaia', 'bait', 'hoeing', 'fresh-risen', 'ill-treating', 'deficient', 'loading', 'earshot', 'funeral.', 'accompaniment', 'rode', 'frowned', 'giantess', 'coast', 'work-box', 'acceptance', 'seldom', 'wooden', 'fort', 'polyneos', 'swamp', 'eteocretans', 'recommend', 'peopled', 'beckoned', 'overarching', 'resuming', 'scrubbed', 'rapids', 'examined', 'maidservant', 'allow', 'wonders', 'obliged', 'swaying', 'coated', 'originally', 'boethoos', 'importunity', 'squealing', 'uncivilized', 'cruelest', 'side-wind', 'abominably', 'brambles', 'musically', 'dears', 'platform', 'cross-piece', 'outlines', 'swill', 'inheritance', 'continent', 'undergone', 'female', 'hereditary', 'drunkard', 'constancy', 'sights', 'parts.', 'tambour', 'insig ...
#
#   unique words in tlg0012.tlg002.perseus-eng4.txt not in tlg0012.tlg001.perseus-eng4.txt:
# {'usurp', 'forenoon', 'aigyptos', 'outlive', 'brush-wood', 'ones.', 'dissipated', 'disgust', 'well-mated', 'teaches', 'clapped', 'inhabitants', 'encircle', 'okyalos', 'independent', 'turned.', 'kindnesses', 'wonderfully', 'minyan', 'familiarity', 'foul-mouthed', 'fifty-two', 'dining', 'market', 'banishes', 'extraordinarily', 'adorn', 'widely', 'feather', 'magnificent', 'it-', 'waking', 'conferred', 'ogygian', 'creditable', 'occurred', 'timely', 'perilous', 'bondwoman', 'valuable', 'impulse', 'fortune-telling', 'unpick', 'lively', 'heralded', 'damaged', 'enthroned', 'memories', 'transgress', 'affair', 'disfigure', 'misconduct', 'ducts', 'mash', 'scenes', 'yours.', 'leukothea', 'breeder', 'vested', 'evenings', 'groove', 'perjurer', 'broken-down', 'drenching', 'management', 'euphrosunê', 'marauders', 'toasted', 'refitting', 'reasonably', 'jumping', 'tricks', 'elysium', 'straightening', 'plucks', 'scolding', 'eurymakhos', 'fits', 'obtaining', 'pyriphlegethon', 'misadventure', 'resemble', 'land-locked', 'enmity', 'convene', 'ill-conditioned', 'case-hardened', 'lioness', 'toys', 'resume', 'blessedness', 'rudder', 'swaggering', 'squalid', 'salutations', 'cypress-wood', 'remarks', 'overlap', 'sidonia', 'shifted', 'goodness', 'chuckle', 'outbuildings', 'verbal', 'leda', 'gossips', 'offices', 'iros', 'seal', 'vassal', 'blandishment', 'hundreds', 'recognizing', 'notices', 'tiptoe', 'regained', 'ktimene', 'stiffness', 'woe-begone', 'miller-women', 'mission', 'apartment', 'respectable', 'perfidy', 'flagging', 'well-disposed', 'hurts', 'polite', 'krataiis', 'volunteers', 'drip', 'unwasted', 'eumaios', 'nausithoos', 'eurymedousa', 'heinous', 'wink', 'distress.', 'warble', 'bleeds', 'anticipates', 'dowry', 'shocked', 'knock', 'squalls', 'thrinacian', 'moons', 'awed', 'oblige', 'picture', 'scarred', 'manure', 'nothing.', 'defying', 'clamored', 'scoundrels', 'behavior', 'irrepressible', 'lump', 'center-post', 'pat', 'drowned', 'rafter', 'insulting', 'firstly', 'likelihood', 'ox-thong', 'interrupted', 'admittance', 'emptied', 'aft', 'valuables', 'squeal', 'shave', 'ungrafted', 'polykaste', 'needlework', 'poorer', 'foresworn', 'tidy', 'merge', 'handsome', 'alkmaion', 'growl', 'bearing-posts', 'reprimand', 'bye', 'thawed', 'consciousness', 'donors', 'well-found', 'spends', 'visibly', 'relation', 'thoroughly', 'issued', 'infinity', 'pits', 'many-sided', 'goatskins', 'steersmen', '=', 'credit', 'anabesineos', 'competed', "'you", 'fretting', 'hive', 'well-to-do', 'grievance', 'raven', 'overflowing', 'recline', 'expedition', 'freights', 'instinct', 'backstay', 'gardener', 'rejoined', 'sighing', 'traveler', 'boarhounds', 'juicy', 'cooking', 'ktesios', 'disturbance', 'good-for-nothing', 'unpropitious', 'inches.', 'doubling', 'blighting', 'sea-side', 'remove', 'style', 'zethos', 'frightful', 'pork', 'afternoon', 'enormous', 'promontory', 'pretty', 'philoitios', 'ghost', 'principles', 'cheese-racks', 'individuals', 'trees.', 'true-begotten', 'broken-hearted', 'competing', 'irrigate', 'coherent', 'kreon', 'assure', 'bowshot', 'offense', 'square', 'enchantments', 'indoors', 'telemos', 'aver', 'wither', 'supersede', 'sluts', 'tapestries', 'unbound', 'cechalian-', 'crews', 'usually', 'oak-shoots', 'subtler', 'downstairs', 'casks', 'dragon', 'gaia', 'bait', 'hoeing', 'fresh-risen', 'ill-treating', 'deficient', 'loading', 'earshot', 'funeral.', 'accompaniment', 'rode', 'frowned', 'giantess', 'coast', 'work-box', 'acceptance', 'seldom', 'wooden', 'fort', 'polyneos', 'swamp', 'eteocretans', 'recommend', 'peopled', 'beckoned', 'overarching', 'resuming', 'scrubbed', 'rapids', 'examined', 'maidservant', 'allow', 'wonders', 'obliged', 'swaying', 'coated', 'originally', 'boethoos', 'importunity', 'squealing', 'uncivilized', 'cruelest', 'side-wind', 'abominably', 'brambles', 'musically', 'dears', 'platform', 'cross-piece', 'outlines', 'swill', 'inheritance', 'continent', 'undergone', 'female', 'hereditary', 'drunkard', 'constancy', 'sights', 'parts.', 'tambour', 'insig ...
#
#   unique words in tlg0012.tlg002.perseus-eng4.txt not in tlg0012.tlg002.perseus-eng3.txt:
# {'usurp', 'forenoon', 'aigyptos', 'outlive', 'brush-wood', 'ones.', 'dissipated', 'disgust', 'well-mated', 'teaches', 'clapped', 'inhabitants', 'encircle', 'okyalos', 'independent', 'turned.', 'kindnesses', 'wonderfully', 'minyan', 'familiarity', 'foul-mouthed', 'fifty-two', 'dining', 'market', 'banishes', 'extraordinarily', 'adorn', 'widely', 'feather', 'magnificent', 'it-', 'waking', 'conferred', 'ogygian', 'creditable', 'occurred', 'timely', 'perilous', 'bondwoman', 'valuable', 'impulse', 'fortune-telling', 'unpick', 'lively', 'heralded', 'damaged', 'enthroned', 'memories', 'transgress', 'affair', 'disfigure', 'misconduct', 'ducts', 'mash', 'scenes', 'yours.', 'leukothea', 'breeder', 'vested', 'evenings', 'groove', 'perjurer', 'broken-down', 'drenching', 'management', 'euphrosunê', 'marauders', 'toasted', 'refitting', 'reasonably', 'jumping', 'tricks', 'elysium', 'straightening', 'plucks', 'scolding', 'eurymakhos', 'fits', 'obtaining', 'pyriphlegethon', 'misadventure', 'resemble', 'land-locked', 'enmity', 'convene', 'ill-conditioned', 'case-hardened', 'lioness', 'toys', 'resume', 'blessedness', 'rudder', 'swaggering', 'squalid', 'salutations', 'cypress-wood', 'remarks', 'overlap', 'sidonia', 'shifted', 'goodness', 'chuckle', 'outbuildings', 'verbal', 'leda', 'gossips', 'offices', 'iros', 'seal', 'vassal', 'blandishment', 'hundreds', 'recognizing', 'notices', 'tiptoe', 'regained', 'ktimene', 'stiffness', 'woe-begone', 'miller-women', 'mission', 'apartment', 'respectable', 'perfidy', 'flagging', 'well-disposed', 'hurts', 'polite', 'krataiis', 'volunteers', 'drip', 'unwasted', 'eumaios', 'nausithoos', 'eurymedousa', 'heinous', 'wink', 'distress.', 'warble', 'bleeds', 'anticipates', 'dowry', 'shocked', 'knock', 'squalls', 'thrinacian', 'moons', 'awed', 'oblige', 'picture', 'scarred', 'manure', 'nothing.', 'defying', 'clamored', 'scoundrels', 'behavior', 'irrepressible', 'lump', 'center-post', 'pat', 'drowned', 'rafter', 'insulting', 'firstly', 'likelihood', 'ox-thong', 'interrupted', 'admittance', 'emptied', 'aft', 'valuables', 'squeal', 'shave', 'ungrafted', 'polykaste', 'needlework', 'poorer', 'foresworn', 'tidy', 'merge', 'handsome', 'alkmaion', 'growl', 'bearing-posts', 'reprimand', 'bye', 'thawed', 'consciousness', 'donors', 'well-found', 'spends', 'visibly', 'relation', 'thoroughly', 'issued', 'infinity', 'pits', 'many-sided', 'goatskins', 'steersmen', '=', 'credit', 'anabesineos', 'competed', "'you", 'fretting', 'hive', 'well-to-do', 'grievance', 'raven', 'overflowing', 'recline', 'expedition', 'freights', 'instinct', 'backstay', 'gardener', 'rejoined', 'sighing', 'traveler', 'boarhounds', 'juicy', 'cooking', 'ktesios', 'disturbance', 'good-for-nothing', 'unpropitious', 'inches.', 'doubling', 'blighting', 'sea-side', 'remove', 'style', 'zethos', 'frightful', 'pork', 'afternoon', 'enormous', 'promontory', 'pretty', 'philoitios', 'ghost', 'principles', 'cheese-racks', 'individuals', 'trees.', 'true-begotten', 'broken-hearted', 'competing', 'irrigate', 'coherent', 'kreon', 'assure', 'bowshot', 'offense', 'square', 'enchantments', 'indoors', 'telemos', 'aver', 'wither', 'supersede', 'sluts', 'tapestries', 'unbound', 'cechalian-', 'crews', 'usually', 'oak-shoots', 'subtler', 'downstairs', 'casks', 'dragon', 'gaia', 'bait', 'hoeing', 'fresh-risen', 'ill-treating', 'deficient', 'loading', 'earshot', 'funeral.', 'accompaniment', 'rode', 'frowned', 'giantess', 'coast', 'work-box', 'acceptance', 'seldom', 'wooden', 'fort', 'polyneos', 'swamp', 'eteocretans', 'recommend', 'peopled', 'beckoned', 'overarching', 'resuming', 'scrubbed', 'rapids', 'examined', 'maidservant', 'allow', 'wonders', 'obliged', 'swaying', 'coated', 'originally', 'boethoos', 'importunity', 'squealing', 'uncivilized', 'cruelest', 'side-wind', 'abominably', 'brambles', 'musically', 'dears', 'platform', 'cross-piece', 'outlines', 'swill', 'inheritance', 'continent', 'undergone', 'female', 'hereditary', 'drunkard', 'constancy', 'sights', 'parts.', 'tambour', 'insig ...
#
#   unique words in tlg0012.tlg001.perseus-eng4.txt not in tlg0012.tlg001.perseus-eng3.txt:
# {'house-dogs', 'polyaimon', 'kymindis', 'rudely', 'oratory', 'hippomakhos', 'stave', 'gaping', 'buffet', 'unattended', 'satnios', 'mountain-track', 'oiled', 'rabble', 'hymen', 'foot-soldiers', 'oxgoad', 'olenian', 'penalties', 'one-half', 'swarms', 'defy', 'bowstring', 'sweet-singing', 'boons', 'upheld', 'philoi', 'ratify', 'duck', 'urgent', 'recovered', 'ame', 'designs', 'fire-', 'foot-races', 'rescue', 'pall', 'consulting', 'flaring', 'quickest', 'straightly', 'spear-hounds', 'savior', 'hunter-eagle', 'assist', 'life-breath', 'heats', 'roses', 'cowed', 'fired', 'couples', 'doting', 'overruling', 'oinomaos', 'runaway', 'astyalos', 'fork', 'heavenward', 'occupied', 'cushion', 'unsay', 'unwelcome', 'unite', 'shirked', 'brother-in-law', 'ripening', 'rivulets', 'misgiving', 'soaks', 'congratulated', 'comforting', 'sthenelaos', 'crystal', 'left-hand', 'heaven-born', 'alkimedon', 'yokestraps', 'wronging', 'notions', 'steams', 'lavished', 'laborers', 'kapys', 'him-', 'diverting', 'surpassing', 'recruits', 'coils', 'idaios', 'sea-goddesses', '-and', 'rhaea', 'steeled', 'hermos', 'ties', 'reflecting', 'serving-woman', 'perkote', 'rhodios', 'sister-wife', 'daunted', 'mown', 'veer', 'quailing', 'artificers', 'storehouse', 'graia', 'orthaios', 'phylomedousa', 'wounding', 'reeked', 'accident', 'file', 'glaukos', 'inflict', 'mantinea', 'kteatos', 'eionae', 'laps', 'rancor', 'trifled', 'astypylos', 'simoeis', 'fetching', 'dispatched', 'wind-beaten', 'truer', 'lights', 'vesture', 'exults', 'councilor', 'thicker', 'mated', 'well-assured', 'overhead', 'myrrhine', 'tricked', 'preferred', 'ablaze-', 'discomfited', 'fastness', 'well-nigh', 'suborning', 'aktaia', 'ray', 'rock-perched', 'attempted', 'householders', 'bodes', 'alêthea', 'weaken', 'toppling', 'echios', 'blare', 'strophios', 'challenger', 'befriends', 'succor', 'groanful', 'champing', 'karystos', 'daintiest', 'trifles', 'fullness', 'battle-cries', 'highways', 'sulkily', 'lifeless', 'rashness', 'full-speed', 'thymbra', 'frightening', 'smothered', 'welfare', 'tartaros', 'beleaguered', 'hussy', 'myrmidon', 'frankincense', 'disquieted', 'meekly', 'podarkes', 'unheeded', 'chaff-', 'sallies', 'excelling', 'sixthly', 'cicadas', 'sustained', 'sesamus', 'ousted', 'meonian', 'lost-', 'spleen', 'leadership', 'yoking', 'bunched', 'storming', 'decrees', 'blamed', 'branching', 'vaunts', 'incite', 'asteropaios', 'behooves', 'bondswomen', 'ill-will', 'hobbling', 'concerned', 'abydos', 'inexorable', 'isandros', 'staunching', 'rescued', 'sea-monsters', 'aristos', 'goodwill', 'grips', 'sued', 'four-crested', 'remounted', 'euphorbos', 'unaided', 'saffron', 'bronze-pointed', 'contradicts', 'pandaros', 'praktios', 'sea-nymph', 'themistes', 'spercheios', 'opinions', 'overreach', 'collar-bones', 'stated', 'facing-bothways', 'ithaimenes', 'avert', 'imbrasos', 'hedged', 'fen', 'preference', 'maion', 'oppress', 'divides', 'echepolos', 'titaresios', 'forbids', 'eeriboia', 'housed', 'single-edged', 'ochesios', 'menaces', 'one-', 'bygones', 'blithe', 'offshoot', 'alektryon', 'lowed', 'imprison', 'mire', 'agastrophos', 'attire', 'garlands', 'asaios', 'unburdened', 'peaceably', 'carelessness', 'pledges', 'restive', 'pylaios', 'preferring', 'meonians', 'curtain', 'kharites', 'vigorously', 'seniority', 'override', 'commune', 'pitched', 'physicians', 'schedios', 'northwest', 'sôphrôn', 'performance', 'winnowing-shovel', 'tempests', 'liars', 'phaesus', 'engaging', 'disposal', 'kymodoke', 'moisten', 'axios', 'sea-wrack', 'spouse', 'top-rail', 'weddings', 'buoy', 'slits', 'uphold', 'depended', 'evildoer', 'helter-skelter', 'triumphant', 'bloodstained', 'phradmon', 'augeae', 'calmed', 'troubling', 'promakhos', '-gates', 'kymothoe', 'axes-', 'baulked', 'bystanders', 'decoyed', 'diviner', 'alight', 'doubting', 'outdid', 'thigh-bones', 'coast-land', 'iamenos', 'skirted', 'emblems', 'sea-pike', 'storm-tossed', 'close-fighting', 'euphemos', 'akheloos', 'lungs', 'rival', 'sleeping-ground', 'implanted', 'smashing', 'boldest', 'sha ...
#
#   unique words in tlg0012.tlg001.perseus-eng4.txt not in tlg0012.tlg002.perseus-eng4.txt:
# {'house-dogs', 'polyaimon', 'kymindis', 'rudely', 'oratory', 'hippomakhos', 'stave', 'gaping', 'buffet', 'unattended', 'satnios', 'mountain-track', 'oiled', 'rabble', 'hymen', 'foot-soldiers', 'oxgoad', 'olenian', 'penalties', 'one-half', 'swarms', 'defy', 'bowstring', 'sweet-singing', 'boons', 'upheld', 'philoi', 'ratify', 'duck', 'urgent', 'recovered', 'ame', 'designs', 'fire-', 'foot-races', 'rescue', 'pall', 'consulting', 'flaring', 'quickest', 'straightly', 'spear-hounds', 'savior', 'hunter-eagle', 'assist', 'life-breath', 'heats', 'roses', 'cowed', 'fired', 'couples', 'doting', 'overruling', 'oinomaos', 'runaway', 'astyalos', 'fork', 'heavenward', 'occupied', 'cushion', 'unsay', 'unwelcome', 'unite', 'shirked', 'brother-in-law', 'ripening', 'rivulets', 'misgiving', 'soaks', 'congratulated', 'comforting', 'sthenelaos', 'crystal', 'left-hand', 'heaven-born', 'alkimedon', 'yokestraps', 'wronging', 'notions', 'steams', 'lavished', 'laborers', 'kapys', 'him-', 'diverting', 'surpassing', 'recruits', 'coils', 'idaios', 'sea-goddesses', '-and', 'rhaea', 'steeled', 'hermos', 'ties', 'reflecting', 'serving-woman', 'perkote', 'rhodios', 'sister-wife', 'daunted', 'mown', 'veer', 'quailing', 'artificers', 'storehouse', 'graia', 'orthaios', 'phylomedousa', 'wounding', 'reeked', 'accident', 'file', 'glaukos', 'inflict', 'mantinea', 'kteatos', 'eionae', 'laps', 'rancor', 'trifled', 'astypylos', 'simoeis', 'fetching', 'dispatched', 'wind-beaten', 'truer', 'lights', 'vesture', 'exults', 'councilor', 'thicker', 'mated', 'well-assured', 'overhead', 'myrrhine', 'tricked', 'preferred', 'ablaze-', 'discomfited', 'fastness', 'well-nigh', 'suborning', 'aktaia', 'ray', 'rock-perched', 'attempted', 'householders', 'bodes', 'alêthea', 'weaken', 'toppling', 'echios', 'blare', 'strophios', 'challenger', 'befriends', 'succor', 'groanful', 'champing', 'karystos', 'daintiest', 'trifles', 'fullness', 'battle-cries', 'highways', 'sulkily', 'lifeless', 'rashness', 'full-speed', 'thymbra', 'frightening', 'smothered', 'welfare', 'tartaros', 'beleaguered', 'hussy', 'myrmidon', 'frankincense', 'disquieted', 'meekly', 'podarkes', 'unheeded', 'chaff-', 'sallies', 'excelling', 'sixthly', 'cicadas', 'sustained', 'sesamus', 'ousted', 'meonian', 'lost-', 'spleen', 'leadership', 'yoking', 'bunched', 'storming', 'decrees', 'blamed', 'branching', 'vaunts', 'incite', 'asteropaios', 'behooves', 'bondswomen', 'ill-will', 'hobbling', 'concerned', 'abydos', 'inexorable', 'isandros', 'staunching', 'rescued', 'sea-monsters', 'aristos', 'goodwill', 'grips', 'sued', 'four-crested', 'remounted', 'euphorbos', 'unaided', 'saffron', 'bronze-pointed', 'contradicts', 'pandaros', 'praktios', 'sea-nymph', 'themistes', 'spercheios', 'opinions', 'overreach', 'collar-bones', 'stated', 'facing-bothways', 'ithaimenes', 'avert', 'imbrasos', 'hedged', 'fen', 'preference', 'maion', 'oppress', 'divides', 'echepolos', 'titaresios', 'forbids', 'eeriboia', 'housed', 'single-edged', 'ochesios', 'menaces', 'one-', 'bygones', 'blithe', 'offshoot', 'alektryon', 'lowed', 'imprison', 'mire', 'agastrophos', 'attire', 'garlands', 'asaios', 'unburdened', 'peaceably', 'carelessness', 'pledges', 'restive', 'pylaios', 'preferring', 'meonians', 'curtain', 'kharites', 'vigorously', 'seniority', 'override', 'commune', 'pitched', 'physicians', 'schedios', 'northwest', 'sôphrôn', 'performance', 'winnowing-shovel', 'tempests', 'liars', 'phaesus', 'engaging', 'disposal', 'kymodoke', 'moisten', 'axios', 'sea-wrack', 'spouse', 'top-rail', 'weddings', 'buoy', 'slits', 'uphold', 'depended', 'evildoer', 'helter-skelter', 'triumphant', 'bloodstained', 'phradmon', 'augeae', 'calmed', 'troubling', 'promakhos', '-gates', 'kymothoe', 'axes-', 'baulked', 'bystanders', 'decoyed', 'diviner', 'alight', 'doubting', 'outdid', 'thigh-bones', 'coast-land', 'iamenos', 'skirted', 'emblems', 'sea-pike', 'storm-tossed', 'close-fighting', 'euphemos', 'akheloos', 'lungs', 'rival', 'sleeping-ground', 'implanted', 'smashing', 'boldest', 'sha ...
#
#   unique words in tlg0012.tlg001.perseus-eng4.txt not in tlg0012.tlg002.perseus-eng3.txt:
# {'house-dogs', 'polyaimon', 'kymindis', 'rudely', 'oratory', 'hippomakhos', 'stave', 'gaping', 'buffet', 'unattended', 'satnios', 'mountain-track', 'oiled', 'rabble', 'hymen', 'foot-soldiers', 'oxgoad', 'olenian', 'penalties', 'one-half', 'swarms', 'defy', 'bowstring', 'sweet-singing', 'boons', 'upheld', 'philoi', 'ratify', 'duck', 'urgent', 'recovered', 'ame', 'designs', 'fire-', 'foot-races', 'rescue', 'pall', 'consulting', 'flaring', 'quickest', 'straightly', 'spear-hounds', 'savior', 'hunter-eagle', 'assist', 'life-breath', 'heats', 'roses', 'cowed', 'fired', 'couples', 'doting', 'overruling', 'oinomaos', 'runaway', 'astyalos', 'fork', 'heavenward', 'occupied', 'cushion', 'unsay', 'unwelcome', 'unite', 'shirked', 'brother-in-law', 'ripening', 'rivulets', 'misgiving', 'soaks', 'congratulated', 'comforting', 'sthenelaos', 'crystal', 'left-hand', 'heaven-born', 'alkimedon', 'yokestraps', 'wronging', 'notions', 'steams', 'lavished', 'laborers', 'kapys', 'him-', 'diverting', 'surpassing', 'recruits', 'coils', 'idaios', 'sea-goddesses', '-and', 'rhaea', 'steeled', 'hermos', 'ties', 'reflecting', 'serving-woman', 'perkote', 'rhodios', 'sister-wife', 'daunted', 'mown', 'veer', 'quailing', 'artificers', 'storehouse', 'graia', 'orthaios', 'phylomedousa', 'wounding', 'reeked', 'accident', 'file', 'glaukos', 'inflict', 'mantinea', 'kteatos', 'eionae', 'laps', 'rancor', 'trifled', 'astypylos', 'simoeis', 'fetching', 'dispatched', 'wind-beaten', 'truer', 'lights', 'vesture', 'exults', 'councilor', 'thicker', 'mated', 'well-assured', 'overhead', 'myrrhine', 'tricked', 'preferred', 'ablaze-', 'discomfited', 'fastness', 'well-nigh', 'suborning', 'aktaia', 'ray', 'rock-perched', 'attempted', 'householders', 'bodes', 'alêthea', 'weaken', 'toppling', 'echios', 'blare', 'strophios', 'challenger', 'befriends', 'succor', 'groanful', 'champing', 'karystos', 'daintiest', 'trifles', 'fullness', 'battle-cries', 'highways', 'sulkily', 'lifeless', 'rashness', 'full-speed', 'thymbra', 'frightening', 'smothered', 'welfare', 'tartaros', 'beleaguered', 'hussy', 'myrmidon', 'frankincense', 'disquieted', 'meekly', 'podarkes', 'unheeded', 'chaff-', 'sallies', 'excelling', 'sixthly', 'cicadas', 'sustained', 'sesamus', 'ousted', 'meonian', 'lost-', 'spleen', 'leadership', 'yoking', 'bunched', 'storming', 'decrees', 'blamed', 'branching', 'vaunts', 'incite', 'asteropaios', 'behooves', 'bondswomen', 'ill-will', 'hobbling', 'concerned', 'abydos', 'inexorable', 'isandros', 'staunching', 'rescued', 'sea-monsters', 'aristos', 'goodwill', 'grips', 'sued', 'four-crested', 'remounted', 'euphorbos', 'unaided', 'saffron', 'bronze-pointed', 'contradicts', 'pandaros', 'praktios', 'sea-nymph', 'themistes', 'spercheios', 'opinions', 'overreach', 'collar-bones', 'stated', 'facing-bothways', 'ithaimenes', 'avert', 'imbrasos', 'hedged', 'fen', 'preference', 'maion', 'oppress', 'divides', 'echepolos', 'titaresios', 'forbids', 'eeriboia', 'housed', 'single-edged', 'ochesios', 'menaces', 'one-', 'bygones', 'blithe', 'offshoot', 'alektryon', 'lowed', 'imprison', 'mire', 'agastrophos', 'attire', 'garlands', 'asaios', 'unburdened', 'peaceably', 'carelessness', 'pledges', 'restive', 'pylaios', 'preferring', 'meonians', 'curtain', 'kharites', 'vigorously', 'seniority', 'override', 'commune', 'pitched', 'physicians', 'schedios', 'northwest', 'sôphrôn', 'performance', 'winnowing-shovel', 'tempests', 'liars', 'phaesus', 'engaging', 'disposal', 'kymodoke', 'moisten', 'axios', 'sea-wrack', 'spouse', 'top-rail', 'weddings', 'buoy', 'slits', 'uphold', 'depended', 'evildoer', 'helter-skelter', 'triumphant', 'bloodstained', 'phradmon', 'augeae', 'calmed', 'troubling', 'promakhos', '-gates', 'kymothoe', 'axes-', 'baulked', 'bystanders', 'decoyed', 'diviner', 'alight', 'doubting', 'outdid', 'thigh-bones', 'coast-land', 'iamenos', 'skirted', 'emblems', 'sea-pike', 'storm-tossed', 'close-fighting', 'euphemos', 'akheloos', 'lungs', 'rival', 'sleeping-ground', 'implanted', 'smashing', 'boldest', 'sha ...
#
#   unique words in tlg0012.tlg002.perseus-eng3.txt not in tlg0012.tlg001.perseus-eng3.txt:
# {'soiled—there', 'doorway.', 'high-horned', 'father—again', 'drill', 'labours', 'flaxen', 'establish', 'alcandre', 'road-steads', 'avoids', 'bedabbled', 'lacks', 'door-stone', 'oarsmen—that', 'comeliness.', 'aegyptus', 'men—meanwhile', 'all—one', 'widespread', 'archer-god', 'scratches', 'down.', 'forwardness', 'comelier', 'bachelors—and', 'appears.', "would'st", 'come.', 'strength.', 'theoclymenus', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'islands—dulichium', 'hazarding', 'southwest', 'thinkest', 'strokes', 'teaching', 'honours', 'any.', 'knowledge.', 'clear-seen', 'maidservants', 'bridles', 'electrum', 'twinklings', 'strangers—zeus', 'foot.', 'rolls', 'lapithae', 'sicilian', 'helper.', 'faint.', 'fore-stays', 'roaming', 'park', 'carpentry', 'compulsion', 'nausithous', 'alcippe', 'bossy', 'sale', 'unheeding', 'spinners', 'cross-beams', 'words.', 'distributed', 'bethinks', 'fortune.', 'things—who', 'myriad', 'binds', 'wreckers', 'separately.', 'overseer', 'god—', 'distressed.', 'contriving', 'eurymachus', 'crataiis', 'man—why', 'yearns', 'cheerless', 'itylus', 'envy', 'perished.', 'trade', 'yelping', 'aegyptius', 'mates', 'sun—a', 'swirl', 'vagabond.', 'deigns', 'parents—would', 'criest', 'mirth', 'phaethusa', 'coming.', 'casts', 'wickedness.', 'mid-', 'passer-by', 'roves', 'unwinged', 'vaulted-over', 'scraped', 'onward—soon', 'swamp-land', 'stunted', 'beaches', 'sturdier', 'sorceress', 'scour', 'fan', 'archaeans', 'over-full', 'spellbound', 'few.', 'knavish', 'twigs', 'lading-plank', 'me—there', 'paeeon', 'dancing-lawns', 'splitting', 'stout-hoofed', '4', 'notest', 'baffling', 'paced', 'boards', 'unseemly—but', 'deeds.', 'revolve', 'signed', 'two-and-twenty', 'longed-for', 'ungraciously', 'tender-heartedness', 'treacherous', 'cureless', 'suffering.', 'consorting', 'pheae', 'bed-post', 'overseen', 'descry', 'byblus', 'ogygia', 'fairer', 'unchanged', 'grief.', 'hades.', 'seethe', 'cephallenians.', 'ismarus', 'tempestuously', 'bathing', 'regret', 'mind—tell', 'say.', 'melantheus', 'bilge', 'rehearsed', 'purpose.', 'right-minded', 'worth.', 'wide-spread', 'wrongs.', 'thine.', 'jet', 'many—aye', 'uprightly.', 'nuisances', 'unripe', 'greenwood', 'have.', 'erectheus', 'across—and', 'glory.', 'door-post', 'trenches', 'rust—', 'debating', '—thy', 'quaffs', 'markest', 'achieves', 'icarius', 'marriage—', 'fulfilled.', 'vermin', 'scatters', 'scares', 'last.', 'owes', 'girth', 'halyards', 'wretchedness', 'knaves', 'suppliants.', 'feet.', 'close-barred', 'mastered', 'dawn.', 'polyneus', 'will—no', 'aid.', 'ilius', 'sheep-gut—so', 'longs', 'well-seasoned', 'stronger.', 'forebode', 'fittingly', 'core', 'frown', 'throughly', 'dwelling—who', 'psyria', 'was—', 'lawlessness—ctesippus', 'unbroken—not', 'home-borne', 'heracles—his', 'misty', 'garden-plot', 'boastful', 'reply', 'reared.', 'prelude', 'mate', 'war.', 'furling', 'last—even', 'talkest', 'newest', 'leucas', 'fringed', 'eurylochus', 'windward', 'zethus', 'deigned', 'sweet-smelling', 'marring', 'circe.', 'recounting', 'sleep.', 'constrain', 'perished—fools', 'practise', 'seawater', 'rejoicing.', 'too.', 'drips', 'townsmen', 'assails', 'abase', 'palisades', 'harm.', 'desires.', 'piloting', 'thievery', 'time.', 'spiders', 'loosens', 'fives', 'deceiving.', 'obtained', 'lost.', 'cyllenian', 'giants.', 'throw.', 'settlement', 'wakens', 'fig-trees', 'them—verily', 'store-rooms', 'variance', 'demoptolemus', 'oughtest', 'thrice-blessed', 'doorposts', 'households', 'am.', 'float', 'wine.', 'fair—so', 'ethiopians—the', 'deep-moaning', 'threateningly', 'fisher', 'temese', 'forsake', 'robe—i', 'sea-eagle', 'purged', 'clings', 'fitteth', 'watched.', 'withal—that', 'forever', 'trim', 'graciously', 'another.', 'designed', 'response', 'undertook', 'laughable', 'scornfully', 'water—this', 'wine-grape', 'tellest', 'near.', 'this—or', 'abstain', 'reputed', 'ripen', 'perils.', 'lament—yet', 'supreme.', 'athena.', 'broad-eared', 'long-oared', 'dimmed', 'enquired', 'marvellously', 'city.', 'continuously', ' ...
#
#   unique words in tlg0012.tlg002.perseus-eng3.txt not in tlg0012.tlg002.perseus-eng4.txt:
# {'soiled—there', 'doorway.', 'high-horned', 'father—again', 'drill', 'labours', 'flaxen', 'establish', 'alcandre', 'road-steads', 'avoids', 'bedabbled', 'lacks', 'door-stone', 'oarsmen—that', 'comeliness.', 'aegyptus', 'men—meanwhile', 'all—one', 'widespread', 'archer-god', 'scratches', 'down.', 'forwardness', 'comelier', 'bachelors—and', 'appears.', "would'st", 'come.', 'strength.', 'theoclymenus', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'islands—dulichium', 'hazarding', 'southwest', 'thinkest', 'strokes', 'teaching', 'honours', 'any.', 'knowledge.', 'clear-seen', 'maidservants', 'bridles', 'electrum', 'twinklings', 'strangers—zeus', 'foot.', 'rolls', 'lapithae', 'sicilian', 'helper.', 'faint.', 'fore-stays', 'roaming', 'park', 'carpentry', 'compulsion', 'nausithous', 'alcippe', 'bossy', 'sale', 'unheeding', 'spinners', 'cross-beams', 'words.', 'distributed', 'bethinks', 'fortune.', 'things—who', 'myriad', 'binds', 'wreckers', 'separately.', 'overseer', 'god—', 'distressed.', 'contriving', 'eurymachus', 'crataiis', 'man—why', 'yearns', 'cheerless', 'itylus', 'envy', 'perished.', 'trade', 'yelping', 'aegyptius', 'mates', 'sun—a', 'swirl', 'vagabond.', 'deigns', 'parents—would', 'criest', 'mirth', 'phaethusa', 'coming.', 'casts', 'wickedness.', 'mid-', 'passer-by', 'roves', 'unwinged', 'vaulted-over', 'scraped', 'onward—soon', 'swamp-land', 'stunted', 'beaches', 'sturdier', 'sorceress', 'scour', 'fan', 'archaeans', 'over-full', 'spellbound', 'few.', 'knavish', 'twigs', 'lading-plank', 'me—there', 'paeeon', 'dancing-lawns', 'splitting', 'stout-hoofed', '4', 'notest', 'baffling', 'paced', 'boards', 'unseemly—but', 'deeds.', 'revolve', 'signed', 'two-and-twenty', 'longed-for', 'ungraciously', 'tender-heartedness', 'treacherous', 'cureless', 'suffering.', 'consorting', 'pheae', 'bed-post', 'overseen', 'descry', 'byblus', 'ogygia', 'fairer', 'unchanged', 'grief.', 'hades.', 'seethe', 'cephallenians.', 'ismarus', 'tempestuously', 'bathing', 'regret', 'mind—tell', 'say.', 'melantheus', 'bilge', 'rehearsed', 'purpose.', 'right-minded', 'worth.', 'wide-spread', 'wrongs.', 'thine.', 'jet', 'many—aye', 'uprightly.', 'nuisances', 'unripe', 'greenwood', 'have.', 'erectheus', 'across—and', 'glory.', 'door-post', 'trenches', 'rust—', 'debating', '—thy', 'quaffs', 'markest', 'achieves', 'icarius', 'marriage—', 'fulfilled.', 'vermin', 'scatters', 'scares', 'last.', 'owes', 'girth', 'halyards', 'wretchedness', 'knaves', 'suppliants.', 'feet.', 'close-barred', 'mastered', 'dawn.', 'polyneus', 'will—no', 'aid.', 'ilius', 'sheep-gut—so', 'longs', 'well-seasoned', 'stronger.', 'forebode', 'fittingly', 'core', 'frown', 'throughly', 'dwelling—who', 'psyria', 'was—', 'lawlessness—ctesippus', 'unbroken—not', 'home-borne', 'heracles—his', 'misty', 'garden-plot', 'boastful', 'reply', 'reared.', 'prelude', 'mate', 'war.', 'furling', 'last—even', 'talkest', 'newest', 'leucas', 'fringed', 'eurylochus', 'windward', 'zethus', 'deigned', 'sweet-smelling', 'marring', 'circe.', 'recounting', 'sleep.', 'constrain', 'perished—fools', 'practise', 'seawater', 'rejoicing.', 'too.', 'drips', 'townsmen', 'assails', 'abase', 'palisades', 'harm.', 'desires.', 'piloting', 'thievery', 'time.', 'spiders', 'loosens', 'fives', 'deceiving.', 'obtained', 'lost.', 'cyllenian', 'giants.', 'throw.', 'settlement', 'wakens', 'fig-trees', 'them—verily', 'store-rooms', 'variance', 'demoptolemus', 'oughtest', 'thrice-blessed', 'doorposts', 'households', 'am.', 'float', 'wine.', 'fair—so', 'ethiopians—the', 'deep-moaning', 'threateningly', 'fisher', 'temese', 'forsake', 'robe—i', 'sea-eagle', 'purged', 'clings', 'fitteth', 'watched.', 'withal—that', 'forever', 'trim', 'graciously', 'another.', 'designed', 'response', 'undertook', 'laughable', 'scornfully', 'water—this', 'wine-grape', 'tellest', 'near.', 'this—or', 'abstain', 'reputed', 'ripen', 'perils.', 'lament—yet', 'supreme.', 'athena.', 'broad-eared', 'long-oared', 'dimmed', 'enquired', 'marvellously', 'city.', 'continuously', ' ...
#
#   unique words in tlg0012.tlg002.perseus-eng3.txt not in tlg0012.tlg001.perseus-eng4.txt:
# {'soiled—there', 'doorway.', 'high-horned', 'father—again', 'drill', 'labours', 'flaxen', 'establish', 'alcandre', 'road-steads', 'avoids', 'bedabbled', 'lacks', 'door-stone', 'oarsmen—that', 'comeliness.', 'aegyptus', 'men—meanwhile', 'all—one', 'widespread', 'archer-god', 'scratches', 'down.', 'forwardness', 'comelier', 'bachelors—and', 'appears.', "would'st", 'come.', 'strength.', 'theoclymenus', 'fair-faced', 'rear—if', 'seeks', 'us—who', 'islands—dulichium', 'hazarding', 'southwest', 'thinkest', 'strokes', 'teaching', 'honours', 'any.', 'knowledge.', 'clear-seen', 'maidservants', 'bridles', 'electrum', 'twinklings', 'strangers—zeus', 'foot.', 'rolls', 'lapithae', 'sicilian', 'helper.', 'faint.', 'fore-stays', 'roaming', 'park', 'carpentry', 'compulsion', 'nausithous', 'alcippe', 'bossy', 'sale', 'unheeding', 'spinners', 'cross-beams', 'words.', 'distributed', 'bethinks', 'fortune.', 'things—who', 'myriad', 'binds', 'wreckers', 'separately.', 'overseer', 'god—', 'distressed.', 'contriving', 'eurymachus', 'crataiis', 'man—why', 'yearns', 'cheerless', 'itylus', 'envy', 'perished.', 'trade', 'yelping', 'aegyptius', 'mates', 'sun—a', 'swirl', 'vagabond.', 'deigns', 'parents—would', 'criest', 'mirth', 'phaethusa', 'coming.', 'casts', 'wickedness.', 'mid-', 'passer-by', 'roves', 'unwinged', 'vaulted-over', 'scraped', 'onward—soon', 'swamp-land', 'stunted', 'beaches', 'sturdier', 'sorceress', 'scour', 'fan', 'archaeans', 'over-full', 'spellbound', 'few.', 'knavish', 'twigs', 'lading-plank', 'me—there', 'paeeon', 'dancing-lawns', 'splitting', 'stout-hoofed', '4', 'notest', 'baffling', 'paced', 'boards', 'unseemly—but', 'deeds.', 'revolve', 'signed', 'two-and-twenty', 'longed-for', 'ungraciously', 'tender-heartedness', 'treacherous', 'cureless', 'suffering.', 'consorting', 'pheae', 'bed-post', 'overseen', 'descry', 'byblus', 'ogygia', 'fairer', 'unchanged', 'grief.', 'hades.', 'seethe', 'cephallenians.', 'ismarus', 'tempestuously', 'bathing', 'regret', 'mind—tell', 'say.', 'melantheus', 'bilge', 'rehearsed', 'purpose.', 'right-minded', 'worth.', 'wide-spread', 'wrongs.', 'thine.', 'jet', 'many—aye', 'uprightly.', 'nuisances', 'unripe', 'greenwood', 'have.', 'erectheus', 'across—and', 'glory.', 'door-post', 'trenches', 'rust—', 'debating', '—thy', 'quaffs', 'markest', 'achieves', 'icarius', 'marriage—', 'fulfilled.', 'vermin', 'scatters', 'scares', 'last.', 'owes', 'girth', 'halyards', 'wretchedness', 'knaves', 'suppliants.', 'feet.', 'close-barred', 'mastered', 'dawn.', 'polyneus', 'will—no', 'aid.', 'ilius', 'sheep-gut—so', 'longs', 'well-seasoned', 'stronger.', 'forebode', 'fittingly', 'core', 'frown', 'throughly', 'dwelling—who', 'psyria', 'was—', 'lawlessness—ctesippus', 'unbroken—not', 'home-borne', 'heracles—his', 'misty', 'garden-plot', 'boastful', 'reply', 'reared.', 'prelude', 'mate', 'war.', 'furling', 'last—even', 'talkest', 'newest', 'leucas', 'fringed', 'eurylochus', 'windward', 'zethus', 'deigned', 'sweet-smelling', 'marring', 'circe.', 'recounting', 'sleep.', 'constrain', 'perished—fools', 'practise', 'seawater', 'rejoicing.', 'too.', 'drips', 'townsmen', 'assails', 'abase', 'palisades', 'harm.', 'desires.', 'piloting', 'thievery', 'time.', 'spiders', 'loosens', 'fives', 'deceiving.', 'obtained', 'lost.', 'cyllenian', 'giants.', 'throw.', 'settlement', 'wakens', 'fig-trees', 'them—verily', 'store-rooms', 'variance', 'demoptolemus', 'oughtest', 'thrice-blessed', 'doorposts', 'households', 'am.', 'float', 'wine.', 'fair—so', 'ethiopians—the', 'deep-moaning', 'threateningly', 'fisher', 'temese', 'forsake', 'robe—i', 'sea-eagle', 'purged', 'clings', 'fitteth', 'watched.', 'withal—that', 'forever', 'trim', 'graciously', 'another.', 'designed', 'response', 'undertook', 'laughable', 'scornfully', 'water—this', 'wine-grape', 'tellest', 'near.', 'this—or', 'abstain', 'reputed', 'ripen', 'perils.', 'lament—yet', 'supreme.', 'athena.', 'broad-eared', 'long-oared', 'dimmed', 'enquired', 'marvellously', 'city.', 'continuously', ' ...

# %%
print("Keys in tokenized_texts:", tokenized_texts.keys())

tokens_per_file = {}
for filename, data in tokenized_texts.items():
    tokens_per_file[filename] = set(data["counts"].keys())

file_a = "tlg0012.tlg001.perseus-eng3.txt"
file_b = "tlg0012.tlg001.perseus-eng4.txt"

shared_tokens = tokens_per_file[file_a] & tokens_per_file[file_b]
print(f"\ntokens in {file_a} and {file_b}:")
print(f"\n count of tokens:")
print(len(shared_tokens))
print(f"\n total tokens in {file_a}:")
print(len(tokens_per_file[file_a]))
print(f"\n total tokens in {file_b}:")
print(len(tokens_per_file[file_b]))
print(shared_tokens)
# Out:
# Keys in tokenized_texts: dict_keys(['tlg0012.tlg001.perseus-eng3.txt', 'tlg0012.tlg002.perseus-eng4.txt', 'tlg0012.tlg001.perseus-eng4.txt', 'tlg0012.tlg002.perseus-eng3.txt'])
#
# tokens in tlg0012.tlg001.perseus-eng3.txt and tlg0012.tlg001.perseus-eng4.txt:
#
#  count of tokens:
# 4511
#
#  total tokens in tlg0012.tlg001.perseus-eng3.txt:
# 7815
#
#  total tokens in tlg0012.tlg001.perseus-eng4.txt:
# 7750
# {'thaumacia', 'lay', 'pylos', 'saying', 'embark', 'camp', 'spent', 'offered', 'dressed', 'aphrodite', 'theseus', 'whistled', 'sprang', 'earnestly', 'guide', 'blood-red', 'sidon', 'smiled', 'wish', 'wicker', 'declares', 'consent', 'copae', 'compact', 'thundered', 'maris', 'gortys', 'overtaking', 'with', 'returning', 'indeed', 'certain', 'eve', 'thrones', 'throats', 'vulture', 'strap', 'ankles', 'pelasgi', 'bonds', 'abate', 'godlike', 'wonder', 'goods', 'slayer', 'peoples', 'diomede', 'bred', 'weakling', 'amphidamas', 'dead', 'devoured', 'would', 'generation', 'tied', 'liver', 'thetis', 'thrasymedes', 'add', 'thronged', 'antenor', 'sons-in-law', 'phrontis', 'sank', 'half', 'mind', 'falcon', 'already', 'dart', 'crouching', 'host', 'teuthras', 'mounted', 'little', 'gale', 'boasting', 'feed', 'deisenor', 'skill', 'thronium', 'calliarus', 'ringing', 'taller', 'grief', 'hilted', '!', 'mane', 'purify', 'swiftly', 'cabesus', 'pityeia', 'folk', 'clasped', 'gate', 'askance', 'woven', 'wiping', 'awoke', 'shine', 'flakes', 'bloodless', 'bows', 'beyond', 'mine', 'tarried', 'want', 'mood', 'unseemly', 'sons', 'band', 'echoing', 'periphas', 'beats', 'bowman', 'ruin', 'scatter', 'prince', 'iphis', 'girls', 'lean', 'fast', 'fates', 'unprotected', 'thirteen', 'enfolded', 'hue', 'satisfy', 'hellespont', 'pittheus', 'polished', 'fixed', 'dashed', 'lighted', 'forget', 'athenians', 'avoid', 'fertile', 'charged', 'lighting', 'dally', 'depths', 'entrails', 'nisa', 'amends', 'lindos', 'horseman', 'escaped', 'exceeding', 'ass', 'beguile', 'invincible', 'grandson', 'brain', 'court', 'darkness', 'sacred', 'mother', 'limit', 'east', 'bay', 'uproar', 'grieve', 'homes', 'fain', 'nod', 'utter', 'contests', 'exhorted', 'dirge', 'phoenix', 'fleetness', 'birth', 'burn', 'besought', 'cower', 'urging', 'tamarisks', 'ruthless', 'pleasure', 'archer', 'supplication', 'bind', 'eurybates', 'mound', 'woe', 'trusting', 'slept', 'storm', 'calydnian', 'daggers', 'therefore', 'twin', 'stripping', 'honey-sweet', 'shorter', 'hearkened', 'flocks', 'sorrowing', 'victory', 'tiryns', 'towering', 'go', 'starlings', 'conquer', 'infant', 'hero', 'morys', 'four-wheeled', 'bounded', 'weeping', 'supper', 'weak', 'hind', 'wedded', 'this', 'fists', 'refused', 'kindle', 'spied', 'mixed', 'dusky', 'near', 'paying', 'nymph', 'vied', 'ferret', 'othryoneus', 'crouched', 'scant', 'match', 'sing', 'chain', 'dione', 'arene', 'wooded', 'limbs', 'bends', 'part', 'woodcutters', 'adrasteia', 'sojourner', 'curious', 'euphetes', 'maidens', 'ilos', 'enyo', 'when', 'windy', 'harma', 'my', 'garment', 'barred', 'winds', 'tomb', 'naves', 'mynes', 'hem', 'running', 'shaker', 'plume', 'dark-prowed', 'tongue', 'she', 'bolt', 'nigh', 'tear', 'listen', 'fair-haired', 'pillar', 'heir', ',', 'bondage', 'timber', ']', 'horns', 'mentor', 'bridegroom', 'message', 'bid', 'hills', 'please', 'fallow', 'warrior', 'ready', 'wherewith', 'promise', 'language', 'destroying', 'themselves', 'wretched', 'force', 'boldly', 'phthires', 'strive', 'past', 'grew', 'barbs', 'provide', 'unable', 'moisture', 'lament', 'cave', 'made', 'wounded', 'sweating', 'morsel', 'yet', 'babe', 'potter', 'might', 'tell', 'sparta', 'leaning', 'tired', 'crisa', 'jointed', 'endowed', 'daws', 'claim', 'fewer', 'thongs', 'midway', 'thestor', 'enshroud', 'fiercely', 'moved', 'brandishing', 'quit', 'blew', 'filth', 'early', 'peerless', 'yielding', 'araethyrea', 'nodding', 'automedon', 'great', 'raging', 'mail', 'failing', 'answered', 'through', 'refuse', 'wait', 'larger', 'cooling', 'fighting', 'door', 'greatly', 'reached', 'divided', 'banks', 'course', 'tent', 'sharp', 'menesthes', 'respite', 'largest', 'muscles', 'plunge', 'remain', 'dread', 'hidden', 'lordly', 'heal', 'fight', 'awake', 'quivering', 'epistor', 'girt', 'fountain', 'peers', 'deeming', 'drenched', 'witnesses', 'malicious', 'decks', 'astyanax', 'hyacinth', 'devise', 'excellence', 'leading', 'artemis', 'locusts', 'range', 'cheered', 'excellent', 'divine', 'dexios', 'lesson', 'onset', 'temple ...

# %% [markdown]
# I used intersection to find shared tokens between two files (file_a = "tlg0012.tlg001.perseus-eng3.txt"
# file_b = "tlg0012.tlg001.perseus-eng4.txt"). One thing I might have done differently is it included tokens like '!' which doesn't really tell me anything. Also I think it would be interesting to see how many of each shared word is appeared in each text. This could help tell us about word choice and how different one text might be from another.
